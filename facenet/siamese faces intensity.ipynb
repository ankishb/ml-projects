# %% [markdown]
# https://www.kaggle.com/kmader/image-similarity-with-siamese-networks

# %%
import scipy.misc

# %%
import numpy as np
import os
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import os
os.listdir('data_intensity/')
# Out:
# ['9', '3', '10', '2', '6', '1', '4', '7', '8', '5']

# %%
count_list = []
import os
path = 'data_intensity/'
files = os.listdir(path)
count = 0
for file in os.listdir(path):
    count = 0
    for fl in os.listdir(path+'/'+file):
#         print(fl)
        count += 1
#     print(count)
    count_list.append(count)
print(count_list)
print("total: ", sum(count_list))
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# total:  30

# %%
all_dir = []
import os
path = 'data_intensity'
files = os.listdir(path)
count = 0
for file in os.listdir(path):
    temp_dir = []
    count = 0
    for fl in os.listdir(path+'/'+file):
#         print(path+'/'+file+'/'+fl)
        temp_dir.append(path+'/'+file+'/'+fl)
    all_dir.append(temp_dir)
print(all_dir[1])
# Out:
# ['data_intensity/3/i002ra-mn.jpg', 'data_intensity/3/i002sa-mn.jpg', 'data_intensity/3/i002qa-mn.jpg']

# %%
# def gen_random_batch(in_groups, batch_halfsize = 8):
# out_img_a, out_img_b, out_score = [], [], []
# all_groups = list(range(len(count_list)))
# for match_group in [True, False]:
#     group_idx = np.random.choice(all_groups, size = batch_halfsize)
#     out_img_a += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in group_idx]
#     if match_group:
#         b_group_idx = group_idx
#         out_score += [1]*batch_halfsize
#     else:
#         # anything but the same group
#         non_group_idx = [np.random.choice([i for i in all_groups if i!=c_idx]) for c_idx in group_idx] 
#         b_group_idx = non_group_idx
#         out_score += [0]*batch_halfsize

#     out_img_b += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in b_group_idx]
            
#     return np.stack(out_img_a,0), np.stack(out_img_b,0), np.stack(out_score,0)

# %%
out_a, out_b, out_score = [], [], []
all_groups = list(range(len(count_list)))
batch_half = 4
for match in [True,False]:
#     print(i," case")
    gp_idx = np.random.choice(all_groups, size=batch_half)
    print(gp_idx)
#     out_a += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))]]
#     for c_idx in gp_idx:
# #         print(count_list[c_idx])
#         temp = all_dir[c_idx][np.random.choice(range(count_list[c_idx]))]
#         print(temp)
    
    out_a += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))] for c_idx in gp_idx]
    
    if match:
        b_gp_idx = gp_idx
        out_score += [1]*batch_half
    else:
        non_gp = [np.random.choice([i for i in all_groups if i != c_idx]) for c_idx in gp_idx]
        b_gp_idx = non_gp
        out_score += [0]*batch_half
    print(b_gp_idx)
    out_b += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))] for c_idx in b_gp_idx]
    
print(out_a)
print(out_b)
print(out_score)
# Out:
# [2 7 1 6]
# [2 7 1 6]
# [2 4 9 1]
# [9, 3, 4, 3]
# ['data_intensity/10/i010sa-mn.jpg', 'data_intensity/7/i007ra-fn.jpg', 'data_intensity/3/i002qa-mn.jpg', 'data_intensity/4/i003sa-fn.jpg', 'data_intensity/10/i010ra-mn.jpg', 'data_intensity/6/i006ra-mn.jpg', 'data_intensity/5/i004ra-mn.jpg', 'data_intensity/3/i002ra-mn.jpg']
# ['data_intensity/10/i010qa-mn.jpg', 'data_intensity/7/i007qa-fn.jpg', 'data_intensity/3/i002qa-mn.jpg', 'data_intensity/4/i003sa-fn.jpg', 'data_intensity/5/i004sa-mn.jpg', 'data_intensity/2/i001sa-mn.jpg', 'data_intensity/6/i006sa-mn.jpg', 'data_intensity/2/i001sa-mn.jpg']
# [1, 1, 1, 1, 0, 0, 0, 0]

# %%
def gen_random_batch(count_list, all_dir, batch_half = 8):
    out_a, out_b, out_score = [], [], []
    all_groups = list(range(len(count_list)))
#     batch_half = 4
    for match in [True,False]:
    #     print(i," case")
        gp_idx = np.random.choice(all_groups, size=batch_half)
#         print(gp_idx)
    #     out_a += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))]]
    #     for c_idx in gp_idx:
    # #         print(count_list[c_idx])
    #         temp = all_dir[c_idx][np.random.choice(range(count_list[c_idx]))]
    #         print(temp)

        out_a += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))] for c_idx in gp_idx]

        if match:
            b_gp_idx = gp_idx
            out_score += [1]*batch_half
        else:
            non_gp = [np.random.choice([i for i in all_groups if i != c_idx]) for c_idx in gp_idx]
            b_gp_idx = non_gp
            out_score += [0]*batch_half
#         print(b_gp_idx)
        out_b += [all_dir[c_idx][np.random.choice(range(count_list[c_idx]))] for c_idx in b_gp_idx]
    
    out_img_a, out_img_b = [], []
    print(len(out_a))
    for f_dir in [out_a, out_b]:
        for file in f_dir:
#             temp = cv2.imread(file)
            temp = scipy.misc.imread(file)
            temp = scipy.misc.imresize(temp,(256,256,3))
            temp = temp.astype(np.float)/255.0
            if f_dir == out_a:
                out_img_a.append(temp)
            else:
                out_img_b.append(temp)
#     print(len(out_img_a), out_img_a[0].shape)
    return np.stack(out_img_a,0), np.stack(out_img_b,0), np.stack(out_score,0)

# %%
a, b, l = gen_random_batch(count_list, all_dir, batch_half = 8)
# Out:
# 16
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
a.shape, b.shape, l.shape
# Out:
# ((16, 256, 256, 3), (16, 256, 256, 3), (16,))

# %%
# x_train = x_train.values.reshape(-1, 28, 28, 1).astype('float32') / 255.
# x_test = x_test.values.reshape(-1, 28, 28, 1).astype('float32') / 255.
# y_train = y_train.values.astype('int')
# y_test = y_test.values.astype('int')
# print('Training', x_train.shape, x_train.max())
# print('Testing', x_test.shape, x_test.max())
# Out:
# Training (42000, 28, 28, 1) 1.0
# Testing (18000, 28, 28, 1) 1.0

# %%
# # reorganize by groups
# train_groups = [x_train[np.where(y_train==i)[0]] for i in np.unique(y_train)]
# test_groups = [x_test[np.where(y_test==i)[0]] for i in np.unique(y_train)]
# print('train groups:', [x.shape[0] for x in train_groups])
# print('test groups:', [x.shape[0] for x in test_groups])
# Out:
# train groups: [4171, 4227, 4221, 4176, 4125, 4189, 4187, 4230, 4236, 4238]
# test groups: [1829, 1773, 1779, 1824, 1875, 1811, 1813, 1770, 1764, 1762]

# %%
import glob

for dir_path, dir_name, dir_files in os.walk('data/train'):
    print("dir path: ", dir_path)
    print("dir name: ",dir_name)
    print("dir files: ", dir_files)
#     for file in dir_files:
#         if glob.glob('*.jpg'):
#             print("True")
# Out:
# dir path:  data/train
# dir name:  ['madonna', 'elton_john', 'jerry_seinfeld', 'ben_afflek', 'mindy_kaling']
# dir files:  []
# dir path:  data/train/madonna
# dir name:  []
# dir files:  ['11.jpg', '17.jpg', '8.jpg', '6.jpg', '9.jpg', '4.jpg', '2.jpg', '7.jpg', '10.jpg', '0.jpg', '12.jpg', '16.jpg', '1.jpg', '14.jpg', '5.jpg', '3.jpg', '13.jpg', '18.jpg', '15.jpg']
# dir path:  data/train/elton_john
# dir name:  []
# dir files:  ['11.jpg', '8.jpg', '6.jpg', '9.jpg', '4.jpg', '2.jpg', '7.jpg', '10.jpg', '0.jpg', '12.jpg', '16.jpg', '1.jpg', '14.jpg', '5.jpg', '3.jpg', '13.jpg', '15.jpg']
# dir path:  data/train/jerry_seinfeld
# dir name:  []
# dir files:  ['11.jpg', '17.jpg', '20.jpg', '8.jpg', '6.jpg', '9.jpg', '4.jpg', '2.jpg', '7.jpg', '10.jpg', '0.jpg', '12.jpg', '16.jpg', '1.jpg', '14.jpg', '5.jpg', '3.jpg', '13.jpg', '18.jpg', '19.jpg', '15.jpg']
# dir path:  data/train/ben_afflek
# dir name:  []
# dir files:  ['11.jpg', '8.jpg', '6.jpg', '9.jpg', '4.jpg', '2.jpg', '7.jpg', '10.jpg', '0.jpg', '12.jpg', '1.jpg', '5.jpg', '3.jpg', '13.jpg']
# dir path:  data/train/mindy_kaling
# dir name:  []
# dir files:  ['11.jpg', '17.jpg', '20.jpg', '8.jpg', '6.jpg', '9.jpg', '21.jpg', '4.jpg', '2.jpg', '7.jpg', '10.jpg', '0.jpg', '12.jpg', '16.jpg', '1.jpg', '14.jpg', '5.jpg', '3.jpg', '13.jpg', '18.jpg', '19.jpg', '15.jpg']

# %%
pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, 3)
fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, m_axs.T):
    ax1.imshow(c_a[:,:,0])
    ax1.set_title('Image A')
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0])
    ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
    ax2.axis('off')
# Out:
# 6
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, 3)
fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, m_axs.T):
    ax1.imshow(c_a[:,:,0])
    ax1.set_title('Image A')
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0])
    ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
    ax2.axis('off')
# Out:
# 6
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Activation, Flatten, Dense, Dropout, GlobalMaxPooling2D
img_in = Input(shape = (256,256,3), name = 'FeatureNet_ImageInput')
n_layer = img_in

n_layer = Conv2D(8, kernel_size = (1,1), activation = 'linear')(n_layer)
n_layer = Conv2D(8, kernel_size = (5,5), activation = 'linear')(n_layer)
# n_layer = BatchNormalization()(n_layer)
n_layer = Activation('relu')(n_layer)
n_layer = MaxPool2D((2,2))(n_layer) #126X126

n_layer = Conv2D(16, kernel_size = (1,1), activation = 'linear')(n_layer)
n_layer = Conv2D(16, kernel_size = (3,3), activation = 'linear')(n_layer)
# n_layer = BatchNormalization()(n_layer)
n_layer = Activation('relu')(n_layer)
n_layer = MaxPool2D((2,2))(n_layer) # 62X62

n_layer = Conv2D(32, kernel_size = (1,1), activation = 'linear')(n_layer)
n_layer = Conv2D(32, kernel_size = (3,3), activation = 'linear')(n_layer)
# n_layer = BatchNormalization()(n_layer)
n_layer = Activation('relu')(n_layer)
n_layer = MaxPool2D((2,2))(n_layer) # 30X30X32

n_layer = Conv2D(64, kernel_size = (1,1), activation = 'linear')(n_layer)
n_layer = Conv2D(64, kernel_size = (3,3), activation = 'linear')(n_layer)
# n_layer = BatchNormalization()(n_layer)
n_layer = Activation('relu')(n_layer)
n_layer = MaxPool2D((2,2))(n_layer) # 14X14X64

n_layer = Conv2D(128, kernel_size = (1,1), activation = 'linear')(n_layer)
n_layer = Conv2D(128, kernel_size = (3,3), activation = 'linear')(n_layer)
# n_layer = BatchNormalization()(n_layer)
n_layer = Activation('relu')(n_layer)
n_layer = MaxPool2D((2,2))(n_layer) # 6X6X128

n_layer = GlobalMaxPooling2D('channels_last')(n_layer)
# n_layer = Conv2D(32, kernel_size = (1,1), activation = 'linear')(n_layer)
# n_layer = Conv2D(32, kernel_size = (3,3), activation = 'linear')(n_layer)
# # n_layer = BatchNormalization()(n_layer)
# n_layer = Activation('relu')(n_layer)
# n_layer = MaxPool2D((2,2))(n_layer) # 


# n_layer = Flatten()(n_layer)
# n_layer = Dense(32, activation = 'linear')(n_layer)
# n_layer = Dropout(0.5)(n_layer)
# n_layer = BatchNormalization()(n_layer)
# n_layer = Activation('relu')(n_layer)
feature_model = Model(inputs = [img_in], outputs = [n_layer], name = 'FeatureGenerationModel')
feature_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FeatureNet_ImageInput (Input (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 8)       32
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 252, 252, 8)       1608
# _________________________________________________________________
# activation_1 (Activation)    (None, 252, 252, 8)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 126, 126, 8)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 126, 126, 16)      144
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 124, 124, 16)      2320
# _________________________________________________________________
# activation_2 (Activation)    (None, 124, 124, 16)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 62, 62, 32)        544
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 60, 60, 32)        9248
# _________________________________________________________________
# activation_3 (Activation)    (None, 60, 60, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 64)        2112
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 128)       8320
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 128)               0
# =================================================================
# Total params: 208,840
# Trainable params: 208,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from keras.models import Model
# from keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Activation, Flatten, Dense, Dropout
# img_in = Input(shape = (64,64,3), name = 'FeatureNet_ImageInput')
# n_layer = img_in
# for i in range(2):
#     n_layer = Conv2D(8*2**i, kernel_size = (3,3), activation = 'linear')(n_layer)
#     n_layer = BatchNormalization()(n_layer)
#     n_layer = Activation('relu')(n_layer)
#     n_layer = Conv2D(16*2**i, kernel_size = (3,3), activation = 'linear')(n_layer)
#     n_layer = BatchNormalization()(n_layer)
#     n_layer = Activation('relu')(n_layer)
#     n_layer = MaxPool2D((2,2))(n_layer)
# n_layer = Flatten()(n_layer)
# n_layer = Dense(32, activation = 'linear')(n_layer)
# n_layer = Dropout(0.5)(n_layer)
# n_layer = BatchNormalization()(n_layer)
# n_layer = Activation('relu')(n_layer)
# feature_model = Model(inputs = [img_in], outputs = [n_layer], name = 'FeatureGenerationModel')
# feature_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# FeatureNet_ImageInput (Input (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 8)         224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 62, 62, 8)         32
# _________________________________________________________________
# activation_1 (Activation)    (None, 62, 62, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 16)        1168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60, 60, 16)        64
# _________________________________________________________________
# activation_2 (Activation)    (None, 60, 60, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                173088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# =================================================================
# Total params: 181,856
# Trainable params: 181,648
# Non-trainable params: 208
# _________________________________________________________________

# %%
from keras.layers import concatenate
img_a_in = Input(shape = (64,64,3), name = 'ImageA_Input')
img_b_in = Input(shape = (64,64,3), name = 'ImageB_Input')
img_a_feat = feature_model(img_a_in)
img_b_feat = feature_model(img_b_in)
combined_features = concatenate([img_a_feat, img_b_feat], name = 'merge_features')
combined_features = Dense(16, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(4, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(1, activation = 'sigmoid')(combined_features)
similarity_model = Model(inputs = [img_a_in, img_b_in], outputs = [combined_features], name = 'Similarity_Model')
similarity_model.summary()

# %%
from keras.layers import concatenate
img_a_in = Input(shape = (256,256,3), name = 'ImageA_Input')
img_b_in = Input(shape = (256,256,3), name = 'ImageB_Input')
img_a_feat = feature_model(img_a_in)
img_b_feat = feature_model(img_b_in)
combined_features = concatenate([img_a_feat, img_b_feat], name = 'merge_features')
combined_features = Dense(32, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)

combined_features = Dense(8, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)

combined_features = Dense(4, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)

combined_features = Dense(1, activation = 'sigmoid')(combined_features)
similarity_model = Model(inputs = [img_a_in, img_b_in], outputs = [combined_features], name = 'Similarity_Model')
similarity_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ImageA_Input (InputLayer)       (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# ImageB_Input (InputLayer)       (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# FeatureGenerationModel (Model)  (None, 128)          208840      ImageA_Input[0][0]
#                                                                  ImageB_Input[0][0]
# __________________________________________________________________________________________________
# merge_features (Concatenate)    (None, 256)          0           FeatureGenerationModel[1][0]
#                                                                  FeatureGenerationModel[2][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           8224        merge_features[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32)           128         dense_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            264         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8)            32          dense_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8)            0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            36          activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4)            16          dense_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4)            0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            5           activation_8[0][0]
# ==================================================================================================
# Total params: 217,545
# Trainable params: 217,457
# Non-trainable params: 88
# __________________________________________________________________________________________________

# %%
# setup the optimization process
similarity_model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['mae'])

# %% [markdown]
# # without training (performing very poor)

# %%
def show_model_output(nb_examples = 3):
    pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, nb_examples)
    pred_sim = similarity_model.predict([pv_a, pv_b])
    fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
    for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim, m_axs.T):
        ax1.imshow(c_a[:,:,0])
        ax1.set_title('Image A\n Actual: %3.0f%%' % (100*c_d))
        ax1.axis('off')
        ax2.imshow(c_b[:,:,0])
        ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
        ax2.axis('off')
    return fig
# a completely untrained model
_ = show_model_output()
# Out:
# 6
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %% [markdown]
# # start training

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('siamese_facenet_intensity.h5', verbose=1, save_best_only=True)

# %%
# results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=8, epochs=30,
#                     callbacks=[earlystopper, checkpointer])

# %%
# make a generator out of the data
def siam_gen(count_list, all_dir, batch_size = 16):
    while True:
        pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, batch_size//2)
        yield [pv_a, pv_b], pv_sim
# we want a constant validation group to have a frame of reference for model performance
valid_a, valid_b, valid_sim = gen_random_batch(count_list, all_dir, 5)
loss_history = similarity_model.fit_generator(siam_gen(count_list, all_dir), 
                               steps_per_epoch = 30,#500,
                               validation_data=([valid_a, valid_b], valid_sim),
                                              epochs = 10,
                                             verbose = True,
                                             callbacks=[earlystopper,checkpointer])
# Out:
# 10
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 16
# Epoch 1/10
# 16
# 16
# 16
# 16
# 16
# 16
# 16
#  1/30 [>.............................] - ETA: 2:24 - loss: 0.6655 - mean_absolute_error: 0.450216
# 16
# 16
# 16
#  2/30 [=>............................] - ETA: 1:43 - loss: 0.7271 - mean_absolute_error: 0.470616
#  3/30 [==>...........................] - ETA: 1:26 - loss: 0.7277 - mean_absolute_error: 0.477016
#  4/30 [===>..........................] - ETA: 1:16 - loss: 0.7267 - mean_absolute_error: 0.481316
#  5/30 [====>.........................] - ETA: 1:09 - loss: 0.7196 - mean_absolute_error: 0.481716
#  6/30 [=====>........................] - ETA: 1:04 - loss: 0.7178 - mean_absolute_error: 0.479616
#  7/30 [======>.......................] - ETA: 59s - loss: 0.7121 - mean_absolute_error: 0.4771 16
#  8/30 [=======>......................] - ETA: 55s - loss: 0.7059 - mean_absolute_error: 0.474716
#  9/30 [========>.....................] - ETA: 52s - loss: 0.6898 - mean_absolute_error: 0.467716
# 10/30 [=========>....................] - ETA: 49s - loss: 0.7054 - mean_absolute_error: 0.474316
# 11/30 [==========>...................] - ETA: 46s - loss: 0.7076 - mean_absolute_error: 0.476116
# 12/30 [===========>..................] - ETA: 43s - loss: 0.7093 - mean_absolute_error: 0.477516
# 13/30 [============>.................] - ETA: 41s - loss: 0.7073 - mean_absolute_error: 0.476916
# 14/30 [=============>................] - ETA: 38s - loss: 0.7003 - mean_absolute_error: 0.473916
# 15/30 [==============>...............] - ETA: 35s - loss: 0.6966 - mean_absolute_error: 0.472316
# 16/30 [===============>..............] - ETA: 33s - loss: 0.6946 - mean_absolute_error: 0.472216
# 17/30 [================>.............] - ETA: 30s - loss: 0.6934 - mean_absolute_error: 0.471716
# 18/30 [=================>............] - ETA: 27s - loss: 0.6922 - mean_absolute_error: 0.471416
# 19/30 [==================>...........] - ETA: 25s - loss: 0.6951 - mean_absolute_error: 0.472216
# 20/30 [===================>..........] - ETA: 23s - loss: 0.6971 - mean_absolute_error: 0.473116
# 21/30 [====================>.........] - ETA: 20s - loss: 0.6976 - mean_absolute_error: 0.473016
# 22/30 [=====================>........] - ETA: 18s - loss: 0.7025 - mean_absolute_error: 0.475216
# 23/30 [======================>.......] - ETA: 16s - loss: 0.7059 - mean_absolute_error: 0.476816
# 24/30 [=======================>......] - ETA: 13s - loss: 0.7024 - mean_absolute_error: 0.475316
# 25/30 [========================>.....] - ETA: 11s - loss: 0.7020 - mean_absolute_error: 0.475016
# 26/30 [=========================>....] - ETA: 9s - loss: 0.7014 - mean_absolute_error: 0.4750 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.6960 - mean_absolute_error: 0.472516
# 28/30 [===========================>..] - ETA: 4s - loss: 0.6982 - mean_absolute_error: 0.473316
# 29/30 [============================>.] - ETA: 2s - loss: 0.7021 - mean_absolute_error: 0.475016
# 30/30 [==============================] - 68s 2s/step - loss: 0.6972 - mean_absolute_error: 0.4725 - val_loss: 4.0611 - val_mean_absolute_error: 0.5006
#
# Epoch 00001: val_loss improved from inf to 4.06106, saving model to siamese_facenet_intensity.h5
# Epoch 2/10
# 16
#  1/30 [>.............................] - ETA: 1:00 - loss: 0.6126 - mean_absolute_error: 0.428516
#  2/30 [=>............................] - ETA: 58s - loss: 0.6407 - mean_absolute_error: 0.4446 16
#  3/30 [==>...........................] - ETA: 56s - loss: 0.6448 - mean_absolute_error: 0.446716
#  4/30 [===>..........................] - ETA: 54s - loss: 0.6645 - mean_absolute_error: 0.455516
#  5/30 [====>.........................] - ETA: 52s - loss: 0.6408 - mean_absolute_error: 0.446416
#  6/30 [=====>........................] - ETA: 50s - loss: 0.6299 - mean_absolute_error: 0.440116
#  7/30 [======>.......................] - ETA: 47s - loss: 0.6274 - mean_absolute_error: 0.440316
#  8/30 [=======>......................] - ETA: 45s - loss: 0.6230 - mean_absolute_error: 0.438316
#  9/30 [========>.....................] - ETA: 43s - loss: 0.6206 - mean_absolute_error: 0.436416
# 10/30 [=========>....................] - ETA: 41s - loss: 0.6145 - mean_absolute_error: 0.433816
# 11/30 [==========>...................] - ETA: 39s - loss: 0.6073 - mean_absolute_error: 0.429916
# 12/30 [===========>..................] - ETA: 37s - loss: 0.6057 - mean_absolute_error: 0.429416
# 13/30 [============>.................] - ETA: 35s - loss: 0.6054 - mean_absolute_error: 0.428416
# 14/30 [=============>................] - ETA: 33s - loss: 0.6017 - mean_absolute_error: 0.426716
# 15/30 [==============>...............] - ETA: 31s - loss: 0.5954 - mean_absolute_error: 0.423216
# 16/30 [===============>..............] - ETA: 29s - loss: 0.5873 - mean_absolute_error: 0.418916
# 17/30 [================>.............] - ETA: 27s - loss: 0.5782 - mean_absolute_error: 0.413916
# 18/30 [=================>............] - ETA: 25s - loss: 0.5816 - mean_absolute_error: 0.415916
# 19/30 [==================>...........] - ETA: 23s - loss: 0.5825 - mean_absolute_error: 0.416416
# 20/30 [===================>..........] - ETA: 21s - loss: 0.5818 - mean_absolute_error: 0.416316
# 21/30 [====================>.........] - ETA: 19s - loss: 0.5801 - mean_absolute_error: 0.415116
# 22/30 [=====================>........] - ETA: 16s - loss: 0.5880 - mean_absolute_error: 0.418716
# 23/30 [======================>.......] - ETA: 14s - loss: 0.5848 - mean_absolute_error: 0.417016
# 24/30 [=======================>......] - ETA: 12s - loss: 0.5833 - mean_absolute_error: 0.415716
# 25/30 [========================>.....] - ETA: 10s - loss: 0.5821 - mean_absolute_error: 0.414916
# 26/30 [=========================>....] - ETA: 8s - loss: 0.5803 - mean_absolute_error: 0.4139 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.5793 - mean_absolute_error: 0.413516
# 28/30 [===========================>..] - ETA: 4s - loss: 0.5778 - mean_absolute_error: 0.412416
# 29/30 [============================>.] - ETA: 2s - loss: 0.5757 - mean_absolute_error: 0.411316
# 30/30 [==============================] - 63s 2s/step - loss: 0.5770 - mean_absolute_error: 0.4118 - val_loss: 2.7703 - val_mean_absolute_error: 0.5128
#
# Epoch 00002: val_loss improved from 4.06106 to 2.77026, saving model to siamese_facenet_intensity.h5
# Epoch 3/10
# 16
#  1/30 [>.............................] - ETA: 59s - loss: 0.4739 - mean_absolute_error: 0.355416
#  2/30 [=>............................] - ETA: 58s - loss: 0.5462 - mean_absolute_error: 0.390916
#  3/30 [==>...........................] - ETA: 56s - loss: 0.5534 - mean_absolute_error: 0.394516
#  4/30 [===>..........................] - ETA: 54s - loss: 0.5590 - mean_absolute_error: 0.395016
#  5/30 [====>.........................] - ETA: 51s - loss: 0.5431 - mean_absolute_error: 0.388216
#  6/30 [=====>........................] - ETA: 49s - loss: 0.5517 - mean_absolute_error: 0.394016
#  7/30 [======>.......................] - ETA: 47s - loss: 0.5412 - mean_absolute_error: 0.388016
#  8/30 [=======>......................] - ETA: 45s - loss: 0.5392 - mean_absolute_error: 0.386516
#  9/30 [========>.....................] - ETA: 43s - loss: 0.5519 - mean_absolute_error: 0.392616
# 10/30 [=========>....................] - ETA: 41s - loss: 0.5391 - mean_absolute_error: 0.385916
# 11/30 [==========>...................] - ETA: 39s - loss: 0.5340 - mean_absolute_error: 0.383316
# 12/30 [===========>..................] - ETA: 37s - loss: 0.5361 - mean_absolute_error: 0.384916
# 13/30 [============>.................] - ETA: 35s - loss: 0.5419 - mean_absolute_error: 0.388516
# 14/30 [=============>................] - ETA: 33s - loss: 0.5402 - mean_absolute_error: 0.387116
# 15/30 [==============>...............] - ETA: 31s - loss: 0.5403 - mean_absolute_error: 0.387816
# 16/30 [===============>..............] - ETA: 29s - loss: 0.5437 - mean_absolute_error: 0.390416
# 17/30 [================>.............] - ETA: 27s - loss: 0.5402 - mean_absolute_error: 0.388816
# 18/30 [=================>............] - ETA: 25s - loss: 0.5366 - mean_absolute_error: 0.387216
# 19/30 [==================>...........] - ETA: 23s - loss: 0.5354 - mean_absolute_error: 0.386816
# 20/30 [===================>..........] - ETA: 21s - loss: 0.5437 - mean_absolute_error: 0.391216
# 21/30 [====================>.........] - ETA: 19s - loss: 0.5486 - mean_absolute_error: 0.393516
# 22/30 [=====================>........] - ETA: 17s - loss: 0.5502 - mean_absolute_error: 0.394316
# 23/30 [======================>.......] - ETA: 15s - loss: 0.5458 - mean_absolute_error: 0.392116
# 24/30 [=======================>......] - ETA: 13s - loss: 0.5433 - mean_absolute_error: 0.391116
# 25/30 [========================>.....] - ETA: 10s - loss: 0.5391 - mean_absolute_error: 0.388816
# 26/30 [=========================>....] - ETA: 8s - loss: 0.5417 - mean_absolute_error: 0.3898 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.5527 - mean_absolute_error: 0.394416
# 28/30 [===========================>..] - ETA: 4s - loss: 0.5496 - mean_absolute_error: 0.392916
# 29/30 [============================>.] - ETA: 2s - loss: 0.5475 - mean_absolute_error: 0.391816
# 30/30 [==============================] - 66s 2s/step - loss: 0.5466 - mean_absolute_error: 0.3913 - val_loss: 2.5248 - val_mean_absolute_error: 0.5065
#
# Epoch 00003: val_loss improved from 2.77026 to 2.52478, saving model to siamese_facenet_intensity.h5
# Epoch 4/10
# 16
#  1/30 [>.............................] - ETA: 1:01 - loss: 0.6012 - mean_absolute_error: 0.415416
#  2/30 [=>............................] - ETA: 58s - loss: 0.5260 - mean_absolute_error: 0.3801 16
#  3/30 [==>...........................] - ETA: 56s - loss: 0.5023 - mean_absolute_error: 0.369816
#  4/30 [===>..........................] - ETA: 54s - loss: 0.5181 - mean_absolute_error: 0.376016
#  5/30 [====>.........................] - ETA: 52s - loss: 0.5158 - mean_absolute_error: 0.374416
#  6/30 [=====>........................] - ETA: 49s - loss: 0.5196 - mean_absolute_error: 0.375716
#  7/30 [======>.......................] - ETA: 47s - loss: 0.5204 - mean_absolute_error: 0.377216
#  8/30 [=======>......................] - ETA: 45s - loss: 0.5281 - mean_absolute_error: 0.383416
#  9/30 [========>.....................] - ETA: 43s - loss: 0.5260 - mean_absolute_error: 0.382116
# 10/30 [=========>....................] - ETA: 41s - loss: 0.5293 - mean_absolute_error: 0.383516
# 11/30 [==========>...................] - ETA: 39s - loss: 0.5306 - mean_absolute_error: 0.385216
# 12/30 [===========>..................] - ETA: 37s - loss: 0.5383 - mean_absolute_error: 0.388416
# 13/30 [============>.................] - ETA: 35s - loss: 0.5423 - mean_absolute_error: 0.390016
# 14/30 [=============>................] - ETA: 33s - loss: 0.5428 - mean_absolute_error: 0.389816
# 15/30 [==============>...............] - ETA: 31s - loss: 0.5442 - mean_absolute_error: 0.391016
# 16/30 [===============>..............] - ETA: 29s - loss: 0.5462 - mean_absolute_error: 0.392216
# 17/30 [================>.............] - ETA: 27s - loss: 0.5421 - mean_absolute_error: 0.389316
# 18/30 [=================>............] - ETA: 25s - loss: 0.5425 - mean_absolute_error: 0.389516
# 19/30 [==================>...........] - ETA: 22s - loss: 0.5372 - mean_absolute_error: 0.386616
# 20/30 [===================>..........] - ETA: 20s - loss: 0.5340 - mean_absolute_error: 0.384716
# 21/30 [====================>.........] - ETA: 18s - loss: 0.5281 - mean_absolute_error: 0.381616
# 22/30 [=====================>........] - ETA: 16s - loss: 0.5300 - mean_absolute_error: 0.382816
# 23/30 [======================>.......] - ETA: 14s - loss: 0.5290 - mean_absolute_error: 0.382116
# 24/30 [=======================>......] - ETA: 12s - loss: 0.5276 - mean_absolute_error: 0.381616
# 25/30 [========================>.....] - ETA: 10s - loss: 0.5247 - mean_absolute_error: 0.380116
# 26/30 [=========================>....] - ETA: 8s - loss: 0.5200 - mean_absolute_error: 0.3776 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.5202 - mean_absolute_error: 0.377816
# 28/30 [===========================>..] - ETA: 4s - loss: 0.5171 - mean_absolute_error: 0.376116
# 29/30 [============================>.] - ETA: 2s - loss: 0.5168 - mean_absolute_error: 0.376316
# 30/30 [==============================] - 64s 2s/step - loss: 0.5137 - mean_absolute_error: 0.3747 - val_loss: 2.3959 - val_mean_absolute_error: 0.5229
#
# Epoch 00004: val_loss improved from 2.52478 to 2.39586, saving model to siamese_facenet_intensity.h5
# Epoch 5/10
# 16
#  1/30 [>.............................] - ETA: 1:02 - loss: 0.4515 - mean_absolute_error: 0.339716
#  2/30 [=>............................] - ETA: 1:00 - loss: 0.5380 - mean_absolute_error: 0.385316
#  3/30 [==>...........................] - ETA: 58s - loss: 0.5652 - mean_absolute_error: 0.3981 16
#  4/30 [===>..........................] - ETA: 56s - loss: 0.5792 - mean_absolute_error: 0.405316
#  5/30 [====>.........................] - ETA: 53s - loss: 0.5827 - mean_absolute_error: 0.405316
#  6/30 [=====>........................] - ETA: 51s - loss: 0.5697 - mean_absolute_error: 0.399016
#  7/30 [======>.......................] - ETA: 49s - loss: 0.5570 - mean_absolute_error: 0.393916
#  8/30 [=======>......................] - ETA: 47s - loss: 0.5565 - mean_absolute_error: 0.392216
#  9/30 [========>.....................] - ETA: 44s - loss: 0.5597 - mean_absolute_error: 0.394216
# 10/30 [=========>....................] - ETA: 42s - loss: 0.5471 - mean_absolute_error: 0.387716
# 11/30 [==========>...................] - ETA: 40s - loss: 0.5402 - mean_absolute_error: 0.384316
# 12/30 [===========>..................] - ETA: 38s - loss: 0.5482 - mean_absolute_error: 0.387716
# 13/30 [============>.................] - ETA: 36s - loss: 0.5513 - mean_absolute_error: 0.389916
# 14/30 [=============>................] - ETA: 34s - loss: 0.5542 - mean_absolute_error: 0.391516
# 15/30 [==============>...............] - ETA: 32s - loss: 0.5624 - mean_absolute_error: 0.395316
# 16/30 [===============>..............] - ETA: 29s - loss: 0.5509 - mean_absolute_error: 0.389616
# 17/30 [================>.............] - ETA: 27s - loss: 0.5462 - mean_absolute_error: 0.387716
# 18/30 [=================>............] - ETA: 25s - loss: 0.5426 - mean_absolute_error: 0.386016
# 19/30 [==================>...........] - ETA: 23s - loss: 0.5514 - mean_absolute_error: 0.390516
# 20/30 [===================>..........] - ETA: 21s - loss: 0.5534 - mean_absolute_error: 0.391916
# 21/30 [====================>.........] - ETA: 19s - loss: 0.5527 - mean_absolute_error: 0.391116
# 22/30 [=====================>........] - ETA: 17s - loss: 0.5480 - mean_absolute_error: 0.389016
# 23/30 [======================>.......] - ETA: 14s - loss: 0.5458 - mean_absolute_error: 0.388016
# 24/30 [=======================>......] - ETA: 12s - loss: 0.5415 - mean_absolute_error: 0.385716
# 25/30 [========================>.....] - ETA: 10s - loss: 0.5379 - mean_absolute_error: 0.383916
# 26/30 [=========================>....] - ETA: 8s - loss: 0.5339 - mean_absolute_error: 0.3820 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.5294 - mean_absolute_error: 0.379716
# 28/30 [===========================>..] - ETA: 4s - loss: 0.5284 - mean_absolute_error: 0.379216
# 29/30 [============================>.] - ETA: 2s - loss: 0.5285 - mean_absolute_error: 0.379516
# 30/30 [==============================] - 64s 2s/step - loss: 0.5313 - mean_absolute_error: 0.3811 - val_loss: 1.3555 - val_mean_absolute_error: 0.4467
#
# Epoch 00005: val_loss improved from 2.39586 to 1.35553, saving model to siamese_facenet_intensity.h5
# Epoch 6/10
# 16
#  1/30 [>.............................] - ETA: 1:02 - loss: 0.4448 - mean_absolute_error: 0.334216
#  2/30 [=>............................] - ETA: 59s - loss: 0.4562 - mean_absolute_error: 0.3423 16
#  3/30 [==>...........................] - ETA: 57s - loss: 0.4512 - mean_absolute_error: 0.339416
#  4/30 [===>..........................] - ETA: 54s - loss: 0.4894 - mean_absolute_error: 0.361516
#  5/30 [====>.........................] - ETA: 52s - loss: 0.4789 - mean_absolute_error: 0.357516
#  6/30 [=====>........................] - ETA: 50s - loss: 0.4686 - mean_absolute_error: 0.352716
#  7/30 [======>.......................] - ETA: 48s - loss: 0.4586 - mean_absolute_error: 0.347516
#  8/30 [=======>......................] - ETA: 46s - loss: 0.4695 - mean_absolute_error: 0.354116
#  9/30 [========>.....................] - ETA: 44s - loss: 0.4727 - mean_absolute_error: 0.355116
# 10/30 [=========>....................] - ETA: 41s - loss: 0.4811 - mean_absolute_error: 0.359816
# 11/30 [==========>...................] - ETA: 39s - loss: 0.4736 - mean_absolute_error: 0.355916
# 12/30 [===========>..................] - ETA: 37s - loss: 0.4725 - mean_absolute_error: 0.354816
# 13/30 [============>.................] - ETA: 35s - loss: 0.4684 - mean_absolute_error: 0.352816
# 14/30 [=============>................] - ETA: 33s - loss: 0.4692 - mean_absolute_error: 0.353116
# 15/30 [==============>...............] - ETA: 31s - loss: 0.4703 - mean_absolute_error: 0.353216
# 16/30 [===============>..............] - ETA: 29s - loss: 0.4722 - mean_absolute_error: 0.353916
# 17/30 [================>.............] - ETA: 27s - loss: 0.4685 - mean_absolute_error: 0.351616
# 18/30 [=================>............] - ETA: 25s - loss: 0.4688 - mean_absolute_error: 0.351816
# 19/30 [==================>...........] - ETA: 23s - loss: 0.4635 - mean_absolute_error: 0.348816
# 20/30 [===================>..........] - ETA: 20s - loss: 0.4693 - mean_absolute_error: 0.350716
# 21/30 [====================>.........] - ETA: 18s - loss: 0.4680 - mean_absolute_error: 0.349716
# 22/30 [=====================>........] - ETA: 16s - loss: 0.4708 - mean_absolute_error: 0.350816
# 23/30 [======================>.......] - ETA: 14s - loss: 0.4721 - mean_absolute_error: 0.351116
# 24/30 [=======================>......] - ETA: 12s - loss: 0.4710 - mean_absolute_error: 0.350616
# 25/30 [========================>.....] - ETA: 10s - loss: 0.4736 - mean_absolute_error: 0.351416
# 26/30 [=========================>....] - ETA: 8s - loss: 0.4693 - mean_absolute_error: 0.3491 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.4702 - mean_absolute_error: 0.349416
# 28/30 [===========================>..] - ETA: 4s - loss: 0.4661 - mean_absolute_error: 0.347116
# 29/30 [============================>.] - ETA: 2s - loss: 0.4650 - mean_absolute_error: 0.346716
# 30/30 [==============================] - 63s 2s/step - loss: 0.4659 - mean_absolute_error: 0.3472 - val_loss: 0.7213 - val_mean_absolute_error: 0.4009
#
# Epoch 00006: val_loss improved from 1.35553 to 0.72135, saving model to siamese_facenet_intensity.h5
# Epoch 7/10
# 16
#  1/30 [>.............................] - ETA: 1:02 - loss: 0.5236 - mean_absolute_error: 0.381816
#  2/30 [=>............................] - ETA: 59s - loss: 0.5257 - mean_absolute_error: 0.3752 16
#  3/30 [==>...........................] - ETA: 56s - loss: 0.5199 - mean_absolute_error: 0.375216
#  4/30 [===>..........................] - ETA: 54s - loss: 0.4972 - mean_absolute_error: 0.362516
#  5/30 [====>.........................] - ETA: 51s - loss: 0.4748 - mean_absolute_error: 0.350616
#  6/30 [=====>........................] - ETA: 49s - loss: 0.4529 - mean_absolute_error: 0.338816
#  7/30 [======>.......................] - ETA: 48s - loss: 0.4549 - mean_absolute_error: 0.338116
#  8/30 [=======>......................] - ETA: 46s - loss: 0.4604 - mean_absolute_error: 0.340716
#  9/30 [========>.....................] - ETA: 44s - loss: 0.4446 - mean_absolute_error: 0.332616
# 10/30 [=========>....................] - ETA: 42s - loss: 0.4411 - mean_absolute_error: 0.331216
# 11/30 [==========>...................] - ETA: 39s - loss: 0.4510 - mean_absolute_error: 0.334516
# 12/30 [===========>..................] - ETA: 37s - loss: 0.4559 - mean_absolute_error: 0.336716
# 13/30 [============>.................] - ETA: 35s - loss: 0.4609 - mean_absolute_error: 0.339416
# 14/30 [=============>................] - ETA: 33s - loss: 0.4628 - mean_absolute_error: 0.340416
# 15/30 [==============>...............] - ETA: 31s - loss: 0.4597 - mean_absolute_error: 0.339116
# 16/30 [===============>..............] - ETA: 29s - loss: 0.4615 - mean_absolute_error: 0.340416
# 17/30 [================>.............] - ETA: 27s - loss: 0.4626 - mean_absolute_error: 0.341016
# 18/30 [=================>............] - ETA: 25s - loss: 0.4614 - mean_absolute_error: 0.340716
# 19/30 [==================>...........] - ETA: 23s - loss: 0.4572 - mean_absolute_error: 0.338416
# 20/30 [===================>..........] - ETA: 21s - loss: 0.4657 - mean_absolute_error: 0.342716
# 21/30 [====================>.........] - ETA: 18s - loss: 0.4622 - mean_absolute_error: 0.341016
# 22/30 [=====================>........] - ETA: 16s - loss: 0.4689 - mean_absolute_error: 0.344316
# 23/30 [======================>.......] - ETA: 14s - loss: 0.4716 - mean_absolute_error: 0.346116
# 24/30 [=======================>......] - ETA: 12s - loss: 0.4747 - mean_absolute_error: 0.347716
# 25/30 [========================>.....] - ETA: 10s - loss: 0.4754 - mean_absolute_error: 0.348016
# 26/30 [=========================>....] - ETA: 8s - loss: 0.4715 - mean_absolute_error: 0.3461 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.4693 - mean_absolute_error: 0.345116
# 28/30 [===========================>..] - ETA: 4s - loss: 0.4710 - mean_absolute_error: 0.345916
# 29/30 [============================>.] - ETA: 2s - loss: 0.4742 - mean_absolute_error: 0.347416
# 30/30 [==============================] - 63s 2s/step - loss: 0.4718 - mean_absolute_error: 0.3464 - val_loss: 0.8477 - val_mean_absolute_error: 0.4608
#
# Epoch 00007: val_loss did not improve from 0.72135
# Epoch 8/10
# 16
#  1/30 [>.............................] - ETA: 1:01 - loss: 0.4345 - mean_absolute_error: 0.331116
#  2/30 [=>............................] - ETA: 59s - loss: 0.4246 - mean_absolute_error: 0.3243 16
#  3/30 [==>...........................] - ETA: 59s - loss: 0.4221 - mean_absolute_error: 0.322516
#  4/30 [===>..........................] - ETA: 58s - loss: 0.4533 - mean_absolute_error: 0.332016
#  5/30 [====>.........................] - ETA: 56s - loss: 0.4862 - mean_absolute_error: 0.346116
#  6/30 [=====>........................] - ETA: 54s - loss: 0.4994 - mean_absolute_error: 0.353116
#  7/30 [======>.......................] - ETA: 52s - loss: 0.5036 - mean_absolute_error: 0.356416
#  8/30 [=======>......................] - ETA: 50s - loss: 0.5048 - mean_absolute_error: 0.356516
#  9/30 [========>.....................] - ETA: 49s - loss: 0.4982 - mean_absolute_error: 0.353616
# 10/30 [=========>....................] - ETA: 47s - loss: 0.5007 - mean_absolute_error: 0.354816
# 11/30 [==========>...................] - ETA: 45s - loss: 0.5035 - mean_absolute_error: 0.356716
# 12/30 [===========>..................] - ETA: 43s - loss: 0.4993 - mean_absolute_error: 0.354616
# 13/30 [============>.................] - ETA: 40s - loss: 0.5017 - mean_absolute_error: 0.355816
# 14/30 [=============>................] - ETA: 37s - loss: 0.4948 - mean_absolute_error: 0.352516
# 15/30 [==============>...............] - ETA: 35s - loss: 0.4874 - mean_absolute_error: 0.348816
# 16/30 [===============>..............] - ETA: 33s - loss: 0.4803 - mean_absolute_error: 0.345316
# 17/30 [================>.............] - ETA: 30s - loss: 0.4913 - mean_absolute_error: 0.350416
# 18/30 [=================>............] - ETA: 28s - loss: 0.4907 - mean_absolute_error: 0.349716
# 19/30 [==================>...........] - ETA: 25s - loss: 0.4884 - mean_absolute_error: 0.348716
# 20/30 [===================>..........] - ETA: 23s - loss: 0.4863 - mean_absolute_error: 0.347416
# 21/30 [====================>.........] - ETA: 20s - loss: 0.4786 - mean_absolute_error: 0.343316
# 22/30 [=====================>........] - ETA: 18s - loss: 0.4771 - mean_absolute_error: 0.342616
# 23/30 [======================>.......] - ETA: 16s - loss: 0.4746 - mean_absolute_error: 0.340916
# 24/30 [=======================>......] - ETA: 13s - loss: 0.4711 - mean_absolute_error: 0.339016
# 25/30 [========================>.....] - ETA: 11s - loss: 0.4726 - mean_absolute_error: 0.340316
# 26/30 [=========================>....] - ETA: 9s - loss: 0.4697 - mean_absolute_error: 0.3388 16
# 27/30 [==========================>...] - ETA: 7s - loss: 0.4659 - mean_absolute_error: 0.336616
# 28/30 [===========================>..] - ETA: 4s - loss: 0.4689 - mean_absolute_error: 0.338016
# 29/30 [============================>.] - ETA: 2s - loss: 0.4675 - mean_absolute_error: 0.337416
# 30/30 [==============================] - 73s 2s/step - loss: 0.4693 - mean_absolute_error: 0.3383 - val_loss: 0.7925 - val_mean_absolute_error: 0.4237
# Epoch 00008: val_loss did not improve from 0.72135
# Epoch 9/10
# 16
#  1/30 [>.............................] - ETA: 1:07 - loss: 0.4228 - mean_absolute_error: 0.298516
#  2/30 [=>............................] - ETA: 1:03 - loss: 0.4494 - mean_absolute_error: 0.316416
#  3/30 [==>...........................] - ETA: 1:02 - loss: 0.4851 - mean_absolute_error: 0.335916
#  4/30 [===>..........................] - ETA: 1:03 - loss: 0.4814 - mean_absolute_error: 0.336816
#  5/30 [====>.........................] - ETA: 59s - loss: 0.4645 - mean_absolute_error: 0.3277 16
#  6/30 [=====>........................] - ETA: 57s - loss: 0.4427 - mean_absolute_error: 0.317516
#  7/30 [======>.......................] - ETA: 55s - loss: 0.4340 - mean_absolute_error: 0.313816
#  8/30 [=======>......................] - ETA: 54s - loss: 0.4564 - mean_absolute_error: 0.324116
#  9/30 [========>.....................] - ETA: 53s - loss: 0.4481 - mean_absolute_error: 0.320516
# 10/30 [=========>....................] - ETA: 51s - loss: 0.4545 - mean_absolute_error: 0.324216
# 11/30 [==========>...................] - ETA: 50s - loss: 0.4480 - mean_absolute_error: 0.322016
# 12/30 [===========>..................] - ETA: 48s - loss: 0.4450 - mean_absolute_error: 0.320816
# 13/30 [============>.................] - ETA: 46s - loss: 0.4398 - mean_absolute_error: 0.318616
# 14/30 [=============>................] - ETA: 43s - loss: 0.4412 - mean_absolute_error: 0.319716
# 15/30 [==============>...............] - ETA: 41s - loss: 0.4401 - mean_absolute_error: 0.319916
# 16/30 [===============>..............] - ETA: 38s - loss: 0.4439 - mean_absolute_error: 0.322416
# 17/30 [================>.............] - ETA: 36s - loss: 0.4344 - mean_absolute_error: 0.317516
# 18/30 [=================>............] - ETA: 33s - loss: 0.4350 - mean_absolute_error: 0.318216
# 19/30 [==================>...........] - ETA: 30s - loss: 0.4381 - mean_absolute_error: 0.321016
# 20/30 [===================>..........] - ETA: 27s - loss: 0.4383 - mean_absolute_error: 0.321116
# 21/30 [====================>.........] - ETA: 24s - loss: 0.4407 - mean_absolute_error: 0.322516
# 22/30 [=====================>........] - ETA: 21s - loss: 0.4414 - mean_absolute_error: 0.323416
# 23/30 [======================>.......] - ETA: 18s - loss: 0.4356 - mean_absolute_error: 0.320416
# 24/30 [=======================>......] - ETA: 15s - loss: 0.4311 - mean_absolute_error: 0.317916
# 25/30 [========================>.....] - ETA: 13s - loss: 0.4298 - mean_absolute_error: 0.317216
# 26/30 [=========================>....] - ETA: 10s - loss: 0.4384 - mean_absolute_error: 0.320716
# 27/30 [==========================>...] - ETA: 7s - loss: 0.4366 - mean_absolute_error: 0.3200 16
# 28/30 [===========================>..] - ETA: 5s - loss: 0.4343 - mean_absolute_error: 0.319016
# 29/30 [============================>.] - ETA: 2s - loss: 0.4327 - mean_absolute_error: 0.317616
# 30/30 [==============================] - 77s 3s/step - loss: 0.4289 - mean_absolute_error: 0.3154 - val_loss: 1.5419 - val_mean_absolute_error: 0.4349
#
# Epoch 00009: val_loss did not improve from 0.72135
# Epoch 10/10
# 16
#  1/30 [>.............................] - ETA: 1:03 - loss: 0.6203 - mean_absolute_error: 0.425416
#  2/30 [=>............................] - ETA: 1:05 - loss: 0.5143 - mean_absolute_error: 0.363316
#  3/30 [==>...........................] - ETA: 1:01 - loss: 0.4660 - mean_absolute_error: 0.337316
#  4/30 [===>..........................] - ETA: 59s - loss: 0.4237 - mean_absolute_error: 0.3145 16
#  5/30 [====>.........................] - ETA: 56s - loss: 0.4245 - mean_absolute_error: 0.315716
#  6/30 [=====>........................] - ETA: 54s - loss: 0.4279 - mean_absolute_error: 0.316416
#  7/30 [======>.......................] - ETA: 52s - loss: 0.4162 - mean_absolute_error: 0.310116
#  8/30 [=======>......................] - ETA: 49s - loss: 0.4330 - mean_absolute_error: 0.319216
#  9/30 [========>.....................] - ETA: 47s - loss: 0.4308 - mean_absolute_error: 0.316916
# 10/30 [=========>....................] - ETA: 44s - loss: 0.4246 - mean_absolute_error: 0.313816
# 11/30 [==========>...................] - ETA: 42s - loss: 0.4291 - mean_absolute_error: 0.316216
# 12/30 [===========>..................] - ETA: 39s - loss: 0.4246 - mean_absolute_error: 0.313716
# 13/30 [============>.................] - ETA: 37s - loss: 0.4257 - mean_absolute_error: 0.314516
# 14/30 [=============>................] - ETA: 34s - loss: 0.4213 - mean_absolute_error: 0.312116
# 15/30 [==============>...............] - ETA: 32s - loss: 0.4164 - mean_absolute_error: 0.310016
# 16/30 [===============>..............] - ETA: 30s - loss: 0.4136 - mean_absolute_error: 0.308716
# 17/30 [================>.............] - ETA: 28s - loss: 0.4083 - mean_absolute_error: 0.305916
# 18/30 [=================>............] - ETA: 26s - loss: 0.4097 - mean_absolute_error: 0.306216
# 19/30 [==================>...........] - ETA: 23s - loss: 0.4081 - mean_absolute_error: 0.305616
# 20/30 [===================>..........] - ETA: 21s - loss: 0.4046 - mean_absolute_error: 0.303616
# 21/30 [====================>.........] - ETA: 19s - loss: 0.4015 - mean_absolute_error: 0.301716
# 22/30 [=====================>........] - ETA: 17s - loss: 0.3959 - mean_absolute_error: 0.298516
# 23/30 [======================>.......] - ETA: 15s - loss: 0.3940 - mean_absolute_error: 0.297216
# 24/30 [=======================>......] - ETA: 12s - loss: 0.3954 - mean_absolute_error: 0.297916
# 25/30 [========================>.....] - ETA: 10s - loss: 0.3960 - mean_absolute_error: 0.298016
# 26/30 [=========================>....] - ETA: 8s - loss: 0.3936 - mean_absolute_error: 0.2967 16
# 27/30 [==========================>...] - ETA: 6s - loss: 0.3924 - mean_absolute_error: 0.296416
# 28/30 [===========================>..] - ETA: 4s - loss: 0.3932 - mean_absolute_error: 0.296716
# 29/30 [============================>.] - ETA: 2s - loss: 0.3950 - mean_absolute_error: 0.297416
# 30/30 [==============================] - 65s 2s/step - loss: 0.3973 - mean_absolute_error: 0.2983 - val_loss: 0.5261 - val_mean_absolute_error: 0.3777
#
# Epoch 00010: val_loss improved from 0.72135 to 0.52614, saving model to siamese_facenet_intensity.h5

# %% [markdown]
# ### model still suffer(need more epochs and large batch size)

# %%
from keras.models import load_model

# %%
def show_model_output(nb_examples = 3):
    similarity_model = load_model('siamese_facenet_intensity.h5')
    pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, nb_examples)
    pred_sim = similarity_model.predict([pv_a, pv_b])
    fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
    for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim, m_axs.T):
        ax1.imshow(c_a[:,:,0])
        ax1.set_title('Image A\n Actual: %3.0f%%' % (100*c_d))
        ax1.axis('off')
        ax2.imshow(c_b[:,:,0])
        ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
        ax2.axis('off')
    return fig
# a completely untrained model


# Predict on train, val and test
# model = load_model('siamese_facenet_intensity.h5')
# preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
# preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
# preds_test = model.predict(X_test, verbose=1)

# %%
_ = show_model_output()
# Out:
# 6
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %% [markdown]
# # use bigger batchsize

# %%
# we want a constant validation group to have a frame of reference for model performance
valid_a, valid_b, valid_sim = gen_random_batch(count_list, all_dir, 16)
loss_history = similarity_model.fit_generator(siam_gen(count_list, all_dir), 
                               steps_per_epoch = 100,#500,
                               validation_data=([valid_a, valid_b], valid_sim),
                                              epochs = 50,
                                             verbose = True,
                                             callbacks=[earlystopper,checkpointer])# make a generator out of the data
# def siam_gen(count_list, all_dir, batch_size = 5):
#     while True:
#         pv_a, pv_b, pv_sim = gen_random_batch(count_list, all_dir, batch_size//2)
#         yield [pv_a, pv_b], pv_sim
# # we want a constant validation group to have a frame of reference for model performance
# valid_a, valid_b, valid_sim = gen_random_batch(count_list, all_dir, 16)
# loss_history = similarity_model.fit_generator(siam_gen(count_list, all_dir), 
#                                steps_per_epoch = 100,
#                                validation_data=([valid_a, valid_b], valid_sim),
#                                               epochs = 50,
#                                              verbose = True)
# Out:
# 32
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 16Epoch 1/50
#
# 16
# 16
# 16
# 16
#   1/100 [..............................] - ETA: 4:56 - loss: 0.3332 - mean_absolute_error: 0.259116
# 16
# 16
# 16
#   2/100 [..............................] - ETA: 4:26 - loss: 0.3647 - mean_absolute_error: 0.274816
# 16
# 16
#   3/100 [..............................] - ETA: 4:15 - loss: 0.3273 - mean_absolute_error: 0.255416
# 16
#   4/100 [>.............................] - ETA: 4:02 - loss: 0.3522 - mean_absolute_error: 0.268916
#   5/100 [>.............................] - ETA: 3:52 - loss: 0.3791 - mean_absolute_error: 0.284916
#   6/100 [>.............................] - ETA: 3:43 - loss: 0.3732 - mean_absolute_error: 0.280916
#  71/100 [====================>.........] - ETA: 1:16 - loss: 0.0998 - mean_absolute_error: 0.068916
#  72/100 [====================>.........] - ETA: 1:14 - loss: 0.0995 - mean_absolute_error: 0.068816
#  73/100 [====================>.........] - ETA: 1:11 - loss: 0.0986 - mean_absolute_error: 0.068416
#  74/100 [=====================>........] - ETA: 1:08 - loss: 0.0979 - mean_absolute_error: 0.068016
#  75/100 [=====================>........] - ETA: 1:06 - loss: 0.0972 - mean_absolute_error: 0.067716
#  76/100 [=====================>........] - ETA: 1:03 - loss: 0.0966 - mean_absolute_error: 0.067416
#  77/100 [======================>.......] - ETA: 1:00 - loss: 0.0959 - mean_absolute_error: 0.067016
#  78/100 [======================>.......] - ETA: 58s - loss: 0.0950 - mean_absolute_error: 0.0665 16
#  79/100 [======================>.......] - ETA: 55s - loss: 0.0944 - mean_absolute_error: 0.066216
#  80/100 [=======================>......] - ETA: 52s - loss: 0.0936 - mean_absolute_error: 0.065716
#  81/100 [=======================>......] - ETA: 50s - loss: 0.0927 - mean_absolute_error: 0.065216
#  82/100 [=======================>......] - ETA: 47s - loss: 0.0923 - mean_absolute_error: 0.065116
#  83/100 [=======================>......] - ETA: 45s - loss: 0.0924 - mean_absolute_error: 0.065316
#  84/100 [========================>.....] - ETA: 42s - loss: 0.0917 - mean_absolute_error: 0.064916
#  85/100 [========================>.....] - ETA: 39s - loss: 0.0909 - mean_absolute_error: 0.064416
#  86/100 [========================>.....] - ETA: 37s - loss: 0.0903 - mean_absolute_error: 0.064116
#  87/100 [=========================>....] - ETA: 34s - loss: 0.0898 - mean_absolute_error: 0.063816
#  88/100 [=========================>....] - ETA: 31s - loss: 0.0892 - mean_absolute_error: 0.063516
#  89/100 [=========================>....] - ETA: 29s - loss: 0.0892 - mean_absolute_error: 0.063716
#  90/100 [==========================>...] - ETA: 26s - loss: 0.0890 - mean_absolute_error: 0.063616
#  91/100 [==========================>...] - ETA: 23s - loss: 0.0882 - mean_absolute_error: 0.063216
#  92/100 [==========================>...] - ETA: 21s - loss: 0.0878 - mean_absolute_error: 0.063016
#  93/100 [==========================>...] - ETA: 18s - loss: 0.0871 - mean_absolute_error: 0.062616
#  94/100 [===========================>..] - ETA: 15s - loss: 0.0865 - mean_absolute_error: 0.062216
#  95/100 [===========================>..] - ETA: 13s - loss: 0.0865 - mean_absolute_error: 0.062416
#  96/100 [===========================>..] - ETA: 10s - loss: 0.0860 - mean_absolute_error: 0.062116
#  97/100 [============================>.] - ETA: 7s - loss: 0.0854 - mean_absolute_error: 0.0617 16
#  98/100 [============================>.] - ETA: 5s - loss: 0.0849 - mean_absolute_error: 0.061516
#  99/100 [============================>.] - ETA: 2s - loss: 0.0849 - mean_absolute_error: 0.061716
# 100/100 [==============================] - 261s 3s/step - loss: 0.0843 - mean_absolute_error: 0.0612 - val_loss: 0.1343 - val_mean_absolute_error: 0.0923
#
# Epoch 00011: val_loss did not improve from 0.12652
# Epoch 00011: early stopping

# %%
_ = show_model_output()
# Out:
# 6
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ankish/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
