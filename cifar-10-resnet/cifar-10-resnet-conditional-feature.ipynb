# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

from keras.layers import RepeatVector, Reshape, Concatenate, multiply

batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 120
data_augmentation = True
num_classes = 10

subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3
version = 2
depth = n * 9 + 2

model_type = 'ResNet%dv%d' % (depth, version)


import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x_train = np.load('data/x_train.npy')
y_train = np.load('data/y_train.npy')
x_test = np.load('data/x_test.npy')
y_test = np.load('data/y_test.npy')

# print('x_train shape:', x_train.shape)
# print(x_train.shape[0], 'train samples')
# print(x_test.shape[0], 'test samples')

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

input_shape = x_train.shape[1:]

# if subtract_pixel_mean:
#     x_train_mean = np.mean(x_train, axis=0)
#     x_train -= x_train_mean
#     x_test -= x_train_mean

# print('x_train shape:', x_train.shape)
# print(x_train.shape[0], 'train samples')
# print(x_test.shape[0], 'test samples')
# print('y_train shape:', y_train.shape)

x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# Using TensorFlow backend.
# ((50000, 32, 32, 3), (50000, 10), (10000, 32, 32, 3), (10000, 10))

# %%
model_type
# Out:
# 'ResNet29v2'

# %%
# epochs = 120


def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):

    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x





def resnet_v2(input_shape, depth, num_classes=10):

    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    enc_feat = Input(shape=(256,))
    
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # out-size = (None, 8, 8, 256)
    
    
    # start attention block
#     res_feat = Input(shape=(hh,hh,cc))
#     enc_feat = Input(shape=(cc,))
    res_feat = x
    enc_feat_c = RepeatVector(64)(enc_feat)
#     enc_feat_c = K.repeat_elements(enc_feat, 64, axis=1)
    enc_feat_c = Reshape(target_shape=(8,8,256))(enc_feat_c)
    
    x = keras.layers.concatenate([res_feat, enc_feat_c], axis=-1) #(8,8,512)
#     print(x)
#     print(Conv2D(256,(1, 1), padding='same')(x))
    x = Conv2D(256,(1, 1), #gfhfghfg
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
    x = Activation('relu')(x)
#     print(x)
    # softmax to calculate weights
    x = Reshape(target_shape=(64,256))(x)
#     print(x)
    x = Dense(1, activation='softmax')(x) #(8,8,1)
#     print(x)
    x = Reshape(target_shape=(8,8,1))(x)
#     print(x)
#     x = Dense(1)(x) #(8,8,1)
#     print(x)
    # weighted multiply
    x = multiply([x, res_feat]) # (8,8,256)
#     print(x)
    # skip connection
    x = keras.layers.concatenate([x, res_feat], axis=-1)
#     print(x)
#     print(x)
    x = Conv2D(256,(1, 1), 
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
#     print(x)
#     print(x)
#     att_feat = Model(inputs=[res_feat, enc_feat], outputs=x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(256,(3, 3), 
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = AveragePooling2D(pool_size=8)(x)
    x = Flatten()(x)
    
    final_out = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)


    model = Model(inputs=[inputs, enc_feat], outputs=final_out)
    
    
#     x = AveragePooling2D(pool_size=8)(x)
#     y = Flatten()(x)
#     outputs = Dense(num_classes,
#                     activation='softmax',
#                     kernel_initializer='he_normal')(y)

    # Instantiate model.
#     model = Model(inputs=inputs, outputs=x)
    return model


resnet = resnet_v2(input_shape=input_shape, depth=depth)
resnet.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   448         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 16)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   272         activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 16)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 16)   2320        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 16)   64          conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 16)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 64)   1088        activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 64)   1088        activation_34[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 64)   0           conv2d_72[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 64)   256         add_10[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 32, 32, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 16)   1040        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 16)   64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 32, 32, 16)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 16)   2320        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 16)   64          conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 16)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 64)   1088        activation_37[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 64)   0           add_10[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 64)   256         add_11[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 16)   1040        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 16)   64          conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 64)   1088        activation_40[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 64)   0           add_11[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 64)   256         add_12[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 64)   4160        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 64)   256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 128)  8320        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 128)  8320        activation_43[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 128)  0           conv2d_82[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 128)  512         add_13[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 128)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 64)   8256        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 64)   256         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 16, 64)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 64)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 16, 64)   256         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 128)  8320        activation_46[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 128)  0           add_13[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 128)  512         add_14[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 64)   8256        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 64)   256         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 64)   256         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 64)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 128)  8320        activation_49[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 128)  0           add_14[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 128)  512         add_15[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 128)    16512       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 128)    147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 128)    512         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 256)    33024       add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 256)    33024       activation_52[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           conv2d_92[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 128)    32896       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 8, 8, 128)    147584      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 8, 8, 256)    33024       activation_55[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           add_16[0][0]
#                                                                  conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 256)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 8, 8, 128)    32896       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 128)    512         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 128)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 8, 8, 128)    147584      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 128)    512         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8, 8, 128)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 8, 8, 256)    33024       activation_58[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           add_17[0][0]
#                                                                  conv2d_98[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 256)          0
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 8, 8, 256)    1024        add_18[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 64, 256)      0           input_8[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 8, 8, 256)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 8, 8, 256)    0           repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 512)    0           activation_59[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 8, 8, 256)    131328      concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8, 8, 256)    0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 64, 256)      0           activation_60[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64, 1)        257         reshape_5[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 8, 8, 1)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 8, 8, 256)    0           reshape_6[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 512)    0           multiply_2[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 8, 8, 256)    131328      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 8, 8, 256)    1024        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 8, 8, 256)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 8, 8, 256)    590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 8, 8, 256)    1024        conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 8, 8, 256)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 256)    0           activation_62[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 1,704,043
# Trainable params: 1,697,803
# Non-trainable params: 6,240
# __________________________________________________________________________________________________

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

def _encoder():
    input_img = Input(shape=(32, 32, 3), name='encoded_feature')

    x = Conv2D(8, (3, 3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    encoded = MaxPooling2D((2, 2), padding='same')(x)
    
    model1 = Model(input_img, encoded)
    
    return model1



enc         = _encoder()
enc.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoded_feature (InputLayer) (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 8)         224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 16)        1168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 64)          0
# =================================================================
# Total params: 24,528
# Trainable params: 24,528
# Non-trainable params: 0
# _________________________________________________________________

# %%
def _decoder():
    input_img = Input(shape=(2, 2, 64), name='decoded_feature')
    
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
    
    model2 = Model(input_img, decoded)
    return model2

dec = _decoder()
dec.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoded_feature (InputLayer) (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 32)          18464
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 16)          4624
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 8)         1160
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 3)         219
# =================================================================
# Total params: 61,395
# Trainable params: 61,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
input_img   = Input(shape=(32,32,3), name='autoencoder')
enc         = enc(input_img)
decoded     = dec(enc)
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# autoencoder (InputLayer)     (None, 32, 32, 3)         0
# _________________________________________________________________
# model_1 (Model)              (None, 2, 2, 64)          24528
# _________________________________________________________________
# model_2 (Model)              (None, 32, 32, 3)         61395
# =================================================================
# Total params: 85,923
# Trainable params: 85,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
# earlystopper = EarlyStopping(patience=3, verbose=1)
# checkpointer = ModelCheckpoint('autoencoder.h5', verbose=1, 
#                                save_best_only=True, 
#                                mode='auto', period=1)

# %%
def lr_schedule_auto(epoch):
    lr = 1e-3
    if epoch > 30:
        lr *= 0.5e-3
    elif epoch > 20:
        lr *= 1e-2
    elif epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_autoencoder.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint_auto = ModelCheckpoint(filepath=filepath,
                                  monitor='val_loss',
                                  verbose=1,
                                  save_best_only=True)

lr_scheduler_auto = LearningRateScheduler(lr_schedule_auto)

lr_reducer_auto = ReduceLROnPlateau(factor=np.sqrt(0.1),
                                    cooldown=0,
                                    patience=5,
                                    min_lr=0.5e-6)

callbacks = [checkpoint_auto, lr_reducer_auto, lr_scheduler_auto]

# %%
autoencoder.fit(x_train, x_train,
                epochs=2,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=callbacks)#,
#                 callbacks=[TensorBoard(log_dir='autoencoder/')])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/2
# Learning rate:  0.001
# 50000/50000 [==============================] - 8s 154us/step - loss: 0.6933 - val_loss: 0.6933
#
# Epoch 00001: val_loss improved from inf to 0.69327, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_autoencoder.001.h5
# Epoch 2/2
# Learning rate:  0.001
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.6932 - val_loss: 0.6932
#
# Epoch 00002: val_loss improved from 0.69327 to 0.69324, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_autoencoder.002.h5

# %%
fig, ax = plt.subplots(1,1, figsize=(16,4))
ax.plot(range(10),autoencoder.history.history['loss'], range(10),autoencoder.history.history['val_loss'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f6f3c20c310>,
#  <matplotlib.lines.Line2D at 0x7f6f3c336990>]

# %%
fig, ax = plt.subplots(1,1, figsize=(16,4))

ax.plot(range(50),autoencoder.history.history['loss'], range(50),autoencoder.history.history['val_loss'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f93ace14610>,
#  <matplotlib.lines.Line2D at 0x7f93acd9d1d0>]

# %%
plt.imshow(x_test[2])

# %%
temp = x_test[2]#+0.5
pred = autoencoder.predict(temp.reshape(-1,32,32,3))
plt.imshow(pred[0])

# %%
# temp = np.where(temp>0.5,1,0)
plt.imshow(temp)

# %%
temp = x_test[6]+0.5
pred = enc(temp.reshape(-1,32,32,3))
print(pred.shape)
plt.imshow(pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-af6abd362ce3> in <module>()
#       1 temp = x_test[6]+0.5
# ----> 2 pred = enc(temp.reshape(-1,32,32,3))
#       3 print(pred.shape)
#       4 plt.imshow(pred)
#
# TypeError: 'Tensor' object is not callable

# %%
def resnet_v2(encoder_model, input_shape, depth, num_classes=10):

    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    enc_feat = Input(shape=(256,))
    
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # out-size = (None, 8, 8, 256)
    
    
    # start attention block
#     res_feat = Input(shape=(hh,hh,cc))
#     enc_feat = Input(shape=(cc,))
    res_feat = x
    enc_feat_c = RepeatVector(64)(enc_feat)
#     enc_feat_c = K.repeat_elements(enc_feat, 64, axis=1)
    enc_feat_c = Reshape(target_shape=(8,8,256))(enc_feat_c)
    
    x = keras.layers.concatenate([res_feat, enc_feat_c], axis=-1) #(8,8,512)
#     print(x)
#     print(Conv2D(256,(1, 1), padding='same')(x))
    x = Conv2D(256,(1, 1), #gfhfghfg
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
    x = Activation('relu')(x)
#     print(x)
    # softmax to calculate weights
    x = Reshape(target_shape=(64,256))(x)
#     print(x)
    x = Dense(1, activation='softmax')(x) #(8,8,1)
#     print(x)
    x = Reshape(target_shape=(8,8,1))(x)
#     print(x)
#     x = Dense(1)(x) #(8,8,1)
#     print(x)
    # weighted multiply
    x = multiply([x, res_feat]) # (8,8,256)
#     print(x)
    # skip connection
    x = keras.layers.concatenate([x, res_feat], axis=-1)
#     print(x)
#     print(x)
    x = Conv2D(256,(1, 1), 
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
#     print(x)
#     print(x)
#     att_feat = Model(inputs=[res_feat, enc_feat], outputs=x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(256,(3, 3), 
               padding='same',
               kernel_initializer='he_normal')(x) #(8,8,256)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = AveragePooling2D(pool_size=8)(x)
    x = Flatten()(x)
    
    final_out = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)


    model = Model(inputs=[inputs, enc_feat], outputs=final_out)
    
    
#     x = AveragePooling2D(pool_size=8)(x)
#     y = Flatten()(x)
#     outputs = Dense(num_classes,
#                     activation='softmax',
#                     kernel_initializer='he_normal')(y)

    # Instantiate model.
#     model = Model(inputs=inputs, outputs=x)
    return model


resnet = resnet_v2(input_shape=input_shape, depth=depth)
resnet.summary()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# print(model_type)

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        width_shift_range=0.1,
        height_shift_range=0.1,
        fill_mode='nearest',
        horizontal_flip=True,
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    resnet_model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,steps_per_epoch=int(1500/4),
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/120
# Learning rate:  0.001
# 375/375 [==============================] - 34s 89ms/step - loss: 2.0231 - acc: 0.4488 - val_loss: 1.9742 - val_acc: 0.4512
#
# Epoch 00001: val_acc improved from -inf to 0.45120, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.001.h5
# Epoch 2/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 1.5501 - acc: 0.5942 - val_loss: 1.6276 - val_acc: 0.5580
#
# Epoch 00002: val_acc improved from 0.45120 to 0.55800, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.002.h5
# Epoch 3/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 1.3303 - acc: 0.6589 - val_loss: 1.9159 - val_acc: 0.5146
#
# Epoch 00003: val_acc did not improve from 0.55800
# Epoch 4/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 1.1735 - acc: 0.7105 - val_loss: 1.2833 - val_acc: 0.6591
#
# Epoch 00004: val_acc improved from 0.55800 to 0.65910, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.004.h5
# Epoch 5/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 1.0655 - acc: 0.7434 - val_loss: 1.5374 - val_acc: 0.6184
#
# Epoch 00005: val_acc did not improve from 0.65910
# Epoch 6/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.9916 - acc: 0.7656 - val_loss: 1.1793 - val_acc: 0.7103
#
# Epoch 00006: val_acc improved from 0.65910 to 0.71030, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.006.h5
# Epoch 7/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.9474 - acc: 0.7771 - val_loss: 1.0662 - val_acc: 0.7404
#
# Epoch 00007: val_acc improved from 0.71030 to 0.74040, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.007.h5
# Epoch 8/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.8864 - acc: 0.7964 - val_loss: 0.9381 - val_acc: 0.7787
#
# Epoch 00008: val_acc improved from 0.74040 to 0.77870, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.008.h5
# Epoch 9/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.8498 - acc: 0.8052 - val_loss: 1.3200 - val_acc: 0.6958
#
# Epoch 00009: val_acc did not improve from 0.77870
# Epoch 10/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.8172 - acc: 0.8136 - val_loss: 1.0900 - val_acc: 0.7252
#
# Epoch 00010: val_acc did not improve from 0.77870
# Epoch 11/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.7897 - acc: 0.8228 - val_loss: 0.9835 - val_acc: 0.7690
#
# Epoch 00011: val_acc did not improve from 0.77870
# Epoch 12/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.7683 - acc: 0.8301 - val_loss: 1.2966 - val_acc: 0.6845
#
# Epoch 00012: val_acc did not improve from 0.77870
# Epoch 13/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.7366 - acc: 0.8395 - val_loss: 1.1556 - val_acc: 0.7196
#
# Epoch 00013: val_acc did not improve from 0.77870
# Epoch 14/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.7224 - acc: 0.8416 - val_loss: 0.9442 - val_acc: 0.7775
#
# Epoch 00014: val_acc did not improve from 0.77870
# Epoch 15/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.7062 - acc: 0.8448 - val_loss: 0.9017 - val_acc: 0.7809
#
# Epoch 00015: val_acc improved from 0.77870 to 0.78090, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.015.h5
# Epoch 16/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.6881 - acc: 0.8500 - val_loss: 1.0154 - val_acc: 0.7655
#
# Epoch 00016: val_acc did not improve from 0.78090
# Epoch 17/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.6699 - acc: 0.8566 - val_loss: 0.9362 - val_acc: 0.7880
#
# Epoch 00017: val_acc improved from 0.78090 to 0.78800, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.017.h5
# Epoch 18/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.6606 - acc: 0.8581 - val_loss: 0.8456 - val_acc: 0.8025
#
# Epoch 00018: val_acc improved from 0.78800 to 0.80250, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.018.h5
# Epoch 19/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.6377 - acc: 0.8672 - val_loss: 0.8425 - val_acc: 0.8067
#
# Epoch 00019: val_acc improved from 0.80250 to 0.80670, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.019.h5
# Epoch 20/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.6362 - acc: 0.8644 - val_loss: 0.9277 - val_acc: 0.7792
#
# Epoch 00020: val_acc did not improve from 0.80670
# Epoch 21/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.6241 - acc: 0.8694 - val_loss: 1.0641 - val_acc: 0.7435
#
# Epoch 00021: val_acc did not improve from 0.80670
# Epoch 22/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.6132 - acc: 0.8730 - val_loss: 0.9090 - val_acc: 0.7824
#
# Epoch 00022: val_acc did not improve from 0.80670
# Epoch 23/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.6059 - acc: 0.8739 - val_loss: 0.8138 - val_acc: 0.8124
#
# Epoch 00023: val_acc improved from 0.80670 to 0.81240, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.023.h5
# Epoch 24/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5958 - acc: 0.8774 - val_loss: 0.7877 - val_acc: 0.8151
#
# Epoch 00024: val_acc improved from 0.81240 to 0.81510, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.024.h5
# Epoch 25/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5861 - acc: 0.8806 - val_loss: 0.8818 - val_acc: 0.7925
#
# Epoch 00025: val_acc did not improve from 0.81510
# Epoch 26/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5798 - acc: 0.8814 - val_loss: 0.7625 - val_acc: 0.8296
#
# Epoch 00026: val_acc improved from 0.81510 to 0.82960, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.026.h5
# Epoch 27/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5672 - acc: 0.8868 - val_loss: 0.8768 - val_acc: 0.8006
#
# Epoch 00027: val_acc did not improve from 0.82960
# Epoch 28/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5651 - acc: 0.8863 - val_loss: 0.8602 - val_acc: 0.8042
#
# Epoch 00028: val_acc did not improve from 0.82960
# Epoch 29/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5553 - acc: 0.8898 - val_loss: 0.8547 - val_acc: 0.8033
#
# Epoch 00029: val_acc did not improve from 0.82960
# Epoch 30/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5396 - acc: 0.8935 - val_loss: 0.7345 - val_acc: 0.8344
#
# Epoch 00030: val_acc improved from 0.82960 to 0.83440, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.030.h5
# Epoch 31/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5435 - acc: 0.8941 - val_loss: 0.6723 - val_acc: 0.8476
#
# Epoch 00031: val_acc improved from 0.83440 to 0.84760, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.031.h5
# Epoch 32/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5417 - acc: 0.8935 - val_loss: 0.8371 - val_acc: 0.8049
#
# Epoch 00032: val_acc did not improve from 0.84760
# Epoch 33/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5276 - acc: 0.8969 - val_loss: 0.8034 - val_acc: 0.8144
#
# Epoch 00033: val_acc did not improve from 0.84760
# Epoch 34/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5283 - acc: 0.8992 - val_loss: 0.7692 - val_acc: 0.8251
#
# Epoch 00034: val_acc did not improve from 0.84760
# Epoch 35/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.5181 - acc: 0.9022 - val_loss: 0.7207 - val_acc: 0.8383
#
# Epoch 00035: val_acc did not improve from 0.84760
# Epoch 36/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5216 - acc: 0.9002 - val_loss: 0.8878 - val_acc: 0.7994
#
# Epoch 00036: val_acc did not improve from 0.84760
# Epoch 37/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.5143 - acc: 0.8997 - val_loss: 0.7090 - val_acc: 0.8431
#
# Epoch 00037: val_acc did not improve from 0.84760
# Epoch 38/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5059 - acc: 0.9055 - val_loss: 0.9223 - val_acc: 0.7913
#
# Epoch 00038: val_acc did not improve from 0.84760
# Epoch 39/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.5023 - acc: 0.9047 - val_loss: 0.6986 - val_acc: 0.8523
#
# Epoch 00039: val_acc improved from 0.84760 to 0.85230, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.039.h5
# Epoch 40/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.5020 - acc: 0.9053 - val_loss: 0.8061 - val_acc: 0.8371
#
# Epoch 00040: val_acc did not improve from 0.85230
# Epoch 41/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4978 - acc: 0.9067 - val_loss: 0.6823 - val_acc: 0.8507
#
# Epoch 00041: val_acc did not improve from 0.85230
# Epoch 42/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4919 - acc: 0.9084 - val_loss: 1.0096 - val_acc: 0.7656
#
# Epoch 00042: val_acc did not improve from 0.85230
# Epoch 43/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4913 - acc: 0.9076 - val_loss: 0.8086 - val_acc: 0.8213
#
# Epoch 00043: val_acc did not improve from 0.85230
# Epoch 44/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4846 - acc: 0.9104 - val_loss: 0.7208 - val_acc: 0.8428
#
# Epoch 00044: val_acc did not improve from 0.85230
# Epoch 45/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4786 - acc: 0.9130 - val_loss: 0.7428 - val_acc: 0.8393
#
# Epoch 00045: val_acc did not improve from 0.85230
# Epoch 46/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4862 - acc: 0.9093 - val_loss: 0.6757 - val_acc: 0.8547
#
# Epoch 00046: val_acc improved from 0.85230 to 0.85470, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.046.h5
# Epoch 47/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4742 - acc: 0.9133 - val_loss: 0.7973 - val_acc: 0.8170
#
# Epoch 00047: val_acc did not improve from 0.85470
# Epoch 48/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4756 - acc: 0.9123 - val_loss: 0.9140 - val_acc: 0.7965
#
# Epoch 00048: val_acc did not improve from 0.85470
# Epoch 49/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4713 - acc: 0.9146 - val_loss: 0.7331 - val_acc: 0.8425
#
# Epoch 00049: val_acc did not improve from 0.85470
# Epoch 50/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4693 - acc: 0.9147 - val_loss: 0.7359 - val_acc: 0.8444
#
# Epoch 00050: val_acc did not improve from 0.85470
# Epoch 51/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4603 - acc: 0.9185 - val_loss: 0.7563 - val_acc: 0.8361
#
# Epoch 00051: val_acc did not improve from 0.85470
# Epoch 52/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4615 - acc: 0.9166 - val_loss: 0.8650 - val_acc: 0.8074
#
# Epoch 00052: val_acc did not improve from 0.85470
# Epoch 53/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4611 - acc: 0.9170 - val_loss: 0.8236 - val_acc: 0.8106
#
# Epoch 00053: val_acc did not improve from 0.85470
# Epoch 54/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4587 - acc: 0.9183 - val_loss: 0.7134 - val_acc: 0.8417
#
# Epoch 00054: val_acc did not improve from 0.85470
# Epoch 55/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4568 - acc: 0.9184 - val_loss: 0.7629 - val_acc: 0.8431
#
# Epoch 00055: val_acc did not improve from 0.85470
# Epoch 56/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4532 - acc: 0.9191 - val_loss: 0.7447 - val_acc: 0.8419
#
# Epoch 00056: val_acc did not improve from 0.85470
# Epoch 57/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4500 - acc: 0.9222 - val_loss: 0.6320 - val_acc: 0.8615
#
# Epoch 00057: val_acc improved from 0.85470 to 0.86150, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.057.h5
# Epoch 58/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4436 - acc: 0.9228 - val_loss: 0.7885 - val_acc: 0.8330
#
# Epoch 00058: val_acc did not improve from 0.86150
# Epoch 59/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4504 - acc: 0.9200 - val_loss: 0.8355 - val_acc: 0.8185
#
# Epoch 00059: val_acc did not improve from 0.86150
# Epoch 60/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4482 - acc: 0.9208 - val_loss: 0.6649 - val_acc: 0.8615
#
# Epoch 00060: val_acc did not improve from 0.86150
# Epoch 61/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4398 - acc: 0.9238 - val_loss: 0.8182 - val_acc: 0.8320
#
# Epoch 00061: val_acc did not improve from 0.86150
# Epoch 62/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4438 - acc: 0.9228 - val_loss: 0.7186 - val_acc: 0.8536
#
# Epoch 00062: val_acc did not improve from 0.86150
# Epoch 63/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4369 - acc: 0.9244 - val_loss: 0.8618 - val_acc: 0.8237
#
# Epoch 00063: val_acc did not improve from 0.86150
# Epoch 64/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4385 - acc: 0.9242 - val_loss: 0.7842 - val_acc: 0.8363
#
# Epoch 00064: val_acc did not improve from 0.86150
# Epoch 65/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4342 - acc: 0.9247 - val_loss: 0.6446 - val_acc: 0.8728
#
# Epoch 00065: val_acc improved from 0.86150 to 0.87280, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.065.h5
# Epoch 66/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4360 - acc: 0.9263 - val_loss: 0.6585 - val_acc: 0.8626
#
# Epoch 00066: val_acc did not improve from 0.87280
# Epoch 67/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4308 - acc: 0.9260 - val_loss: 0.8592 - val_acc: 0.8167
#
# Epoch 00067: val_acc did not improve from 0.87280
# Epoch 68/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4313 - acc: 0.9258 - val_loss: 0.6650 - val_acc: 0.8590
#
# Epoch 00068: val_acc did not improve from 0.87280
# Epoch 69/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4244 - acc: 0.9281 - val_loss: 0.6507 - val_acc: 0.8671
#
# Epoch 00069: val_acc did not improve from 0.87280
# Epoch 70/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4290 - acc: 0.9267 - val_loss: 0.7537 - val_acc: 0.8420
#
# Epoch 00070: val_acc did not improve from 0.87280
# Epoch 71/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4267 - acc: 0.9272 - val_loss: 0.7485 - val_acc: 0.8500
#
# Epoch 00071: val_acc did not improve from 0.87280
# Epoch 72/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4248 - acc: 0.9271 - val_loss: 0.6327 - val_acc: 0.8684
#
# Epoch 00072: val_acc did not improve from 0.87280
# Epoch 73/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4262 - acc: 0.9257 - val_loss: 0.9252 - val_acc: 0.8078
#
# Epoch 00073: val_acc did not improve from 0.87280
# Epoch 74/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4215 - acc: 0.9296 - val_loss: 0.6783 - val_acc: 0.8587
#
# Epoch 00074: val_acc did not improve from 0.87280
# Epoch 75/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4111 - acc: 0.9313 - val_loss: 0.7001 - val_acc: 0.8602
#
# Epoch 00075: val_acc did not improve from 0.87280
# Epoch 76/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4196 - acc: 0.9293 - val_loss: 0.6233 - val_acc: 0.8725
#
# Epoch 00076: val_acc did not improve from 0.87280
# Epoch 77/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4151 - acc: 0.9298 - val_loss: 0.6825 - val_acc: 0.8607
#
# Epoch 00077: val_acc did not improve from 0.87280
# Epoch 78/120
# Learning rate:  0.001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.4172 - acc: 0.9302 - val_loss: 0.7525 - val_acc: 0.8433
#
# Epoch 00078: val_acc did not improve from 0.87280
# Epoch 79/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.4102 - acc: 0.9317 - val_loss: 0.7659 - val_acc: 0.8478
#
# Epoch 00079: val_acc did not improve from 0.87280
# Epoch 80/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4147 - acc: 0.9296 - val_loss: 0.7856 - val_acc: 0.8399
#
# Epoch 00080: val_acc did not improve from 0.87280
# Epoch 81/120
# Learning rate:  0.001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.4099 - acc: 0.9307 - val_loss: 0.7356 - val_acc: 0.8512
#
# Epoch 00081: val_acc did not improve from 0.87280
# Epoch 82/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.3429 - acc: 0.9559 - val_loss: 0.5045 - val_acc: 0.9098
#
# Epoch 00082: val_acc improved from 0.87280 to 0.90980, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.082.h5
# Epoch 83/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.3130 - acc: 0.9671 - val_loss: 0.5029 - val_acc: 0.9105
#
# Epoch 00083: val_acc improved from 0.90980 to 0.91050, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.083.h5
# Epoch 84/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2998 - acc: 0.9711 - val_loss: 0.4994 - val_acc: 0.9130
#
# Epoch 00084: val_acc improved from 0.91050 to 0.91300, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.084.h5
# Epoch 85/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2916 - acc: 0.9726 - val_loss: 0.4986 - val_acc: 0.9133
#
# Epoch 00085: val_acc improved from 0.91300 to 0.91330, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.085.h5
# Epoch 86/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2795 - acc: 0.9770 - val_loss: 0.4895 - val_acc: 0.9181
#
# Epoch 00086: val_acc improved from 0.91330 to 0.91810, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.086.h5
# Epoch 87/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2742 - acc: 0.9771 - val_loss: 0.4917 - val_acc: 0.9161
#
# Epoch 00087: val_acc did not improve from 0.91810
# Epoch 88/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2701 - acc: 0.9780 - val_loss: 0.5014 - val_acc: 0.9129
#
# Epoch 00088: val_acc did not improve from 0.91810
# Epoch 89/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2613 - acc: 0.9809 - val_loss: 0.5048 - val_acc: 0.9135
#
# Epoch 00089: val_acc did not improve from 0.91810
# Epoch 90/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2577 - acc: 0.9811 - val_loss: 0.4955 - val_acc: 0.9154
#
# Epoch 00090: val_acc did not improve from 0.91810
# Epoch 91/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2539 - acc: 0.9814 - val_loss: 0.5086 - val_acc: 0.9127
#
# Epoch 00091: val_acc did not improve from 0.91810
# Epoch 92/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2482 - acc: 0.9822 - val_loss: 0.4997 - val_acc: 0.9154
#
# Epoch 00092: val_acc did not improve from 0.91810
# Epoch 93/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2442 - acc: 0.9828 - val_loss: 0.4934 - val_acc: 0.9146
#
# Epoch 00093: val_acc did not improve from 0.91810
# Epoch 94/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2414 - acc: 0.9840 - val_loss: 0.5045 - val_acc: 0.9152
#
# Epoch 00094: val_acc did not improve from 0.91810
# Epoch 95/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2348 - acc: 0.9851 - val_loss: 0.4944 - val_acc: 0.9187
#
# Epoch 00095: val_acc improved from 0.91810 to 0.91870, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.095.h5
# Epoch 96/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2337 - acc: 0.9843 - val_loss: 0.4983 - val_acc: 0.9153
#
# Epoch 00096: val_acc did not improve from 0.91870
# Epoch 97/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.2297 - acc: 0.9854 - val_loss: 0.5084 - val_acc: 0.9136
#
# Epoch 00097: val_acc did not improve from 0.91870
# Epoch 98/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2259 - acc: 0.9859 - val_loss: 0.5119 - val_acc: 0.9122
#
# Epoch 00098: val_acc did not improve from 0.91870
# Epoch 99/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.2231 - acc: 0.9869 - val_loss: 0.5094 - val_acc: 0.9153
#
# Epoch 00099: val_acc did not improve from 0.91870
# Epoch 100/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2191 - acc: 0.9872 - val_loss: 0.4954 - val_acc: 0.9192
#
# Epoch 00100: val_acc improved from 0.91870 to 0.91920, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.100.h5
# Epoch 101/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2169 - acc: 0.9875 - val_loss: 0.5082 - val_acc: 0.9151
#
# Epoch 00101: val_acc did not improve from 0.91920
# Epoch 102/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2138 - acc: 0.9876 - val_loss: 0.5053 - val_acc: 0.9158
#
# Epoch 00102: val_acc did not improve from 0.91920
# Epoch 103/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2101 - acc: 0.9886 - val_loss: 0.5030 - val_acc: 0.9198
#
# Epoch 00103: val_acc improved from 0.91920 to 0.91980, saving model to /home/ankish1/ankish_save/conditional-feature/saved_models/cifar10_ResNet29v2_model.103.h5
# Epoch 104/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2076 - acc: 0.9893 - val_loss: 0.5060 - val_acc: 0.9166
#
# Epoch 00104: val_acc did not improve from 0.91980
# Epoch 105/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2068 - acc: 0.9885 - val_loss: 0.5086 - val_acc: 0.9162
#
# Epoch 00105: val_acc did not improve from 0.91980
# Epoch 106/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.2033 - acc: 0.9888 - val_loss: 0.5114 - val_acc: 0.9159
#
# Epoch 00106: val_acc did not improve from 0.91980
# Epoch 107/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2020 - acc: 0.9891 - val_loss: 0.5222 - val_acc: 0.9141
#
# Epoch 00107: val_acc did not improve from 0.91980
# Epoch 108/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2007 - acc: 0.9891 - val_loss: 0.5005 - val_acc: 0.9198
#
# Epoch 00108: val_acc did not improve from 0.91980
# Epoch 109/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1966 - acc: 0.9900 - val_loss: 0.5066 - val_acc: 0.9184
#
# Epoch 00109: val_acc did not improve from 0.91980
# Epoch 110/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.1942 - acc: 0.9909 - val_loss: 0.5253 - val_acc: 0.9140
#
# Epoch 00110: val_acc did not improve from 0.91980
# Epoch 111/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1956 - acc: 0.9896 - val_loss: 0.5183 - val_acc: 0.9145
#
# Epoch 00111: val_acc did not improve from 0.91980
# Epoch 112/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1899 - acc: 0.9911 - val_loss: 0.5156 - val_acc: 0.9157
#
# Epoch 00112: val_acc did not improve from 0.91980
# Epoch 113/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1902 - acc: 0.9906 - val_loss: 0.5233 - val_acc: 0.9127
#
# Epoch 00113: val_acc did not improve from 0.91980
# Epoch 114/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1855 - acc: 0.9920 - val_loss: 0.5068 - val_acc: 0.9175
#
# Epoch 00114: val_acc did not improve from 0.91980
# Epoch 115/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1870 - acc: 0.9910 - val_loss: 0.5000 - val_acc: 0.9189
#
# Epoch 00115: val_acc did not improve from 0.91980
# Epoch 116/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 66ms/step - loss: 0.1853 - acc: 0.9905 - val_loss: 0.5295 - val_acc: 0.9133
#
# Epoch 00116: val_acc did not improve from 0.91980
# Epoch 117/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1818 - acc: 0.9915 - val_loss: 0.5211 - val_acc: 0.9137
#
# Epoch 00117: val_acc did not improve from 0.91980
# Epoch 118/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1808 - acc: 0.9915 - val_loss: 0.5221 - val_acc: 0.9172
#
# Epoch 00118: val_acc did not improve from 0.91980
# Epoch 119/120
# Learning rate:  0.0001
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1786 - acc: 0.9922 - val_loss: 0.5110 - val_acc: 0.9177
#
# Epoch 00119: val_acc did not improve from 0.91980
# Epoch 120/120
# Learning rate:  0.0001
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1771 - acc: 0.9923 - val_loss: 0.5226 - val_acc: 0.9143
#
# Epoch 00120: val_acc did not improve from 0.91980

# %%
model.history.history
# Out:
# {'acc': [0.4488333333333333,
#   0.5942817817817818,
#   0.6588463463264582,
#   0.7104813146479814,
#   0.7433683683484803,
#   0.7656406406605287,
#   0.7771312980044075,
#   0.7963588588787469,
#   0.8051801802000683,
#   0.8135844177709726,
#   0.8228436769705675,
#   0.8301426426625308,
#   0.8394853186122091,
#   0.8415498831966618,
#   0.8448031364896912,
#   0.8500583917051703,
#   0.8566691691890572,
#   0.8581081081081081,
#   0.8672213880746095,
#   0.8644269269269269,
#   0.869411077724523,
#   0.8730814147083052,
#   0.8739364364563246,
#   0.8773982315648983,
#   0.8806041666666666,
#   0.8813813814211576,
#   0.8868034701169154,
#   0.8863238238238238,
#   0.8898481815148482,
#   0.8934976643707738,
#   0.8940815815815816,
#   0.8935602268935602,
#   0.8969177511043058,
#   0.8992534200668654,
#   0.90219386056697,
#   0.9001918585053038,
#   0.8997122122321003,
#   0.9054888221554889,
#   0.9046129462398368,
#   0.9053636970104756,
#   0.9066983650118102,
#   0.9085335335335335,
#   0.9076159492428397,
#   0.910472972972973,
#   0.9129754754754755,
#   0.9092842843041724,
#   0.9133299966235537,
#   0.9122872872673992,
#   0.914625,
#   0.9146646647044409,
#   0.9184392725661631,
#   0.9165832499364713,
#   0.9170003336471122,
#   0.9183350017081112,
#   0.9184809809412048,
#   0.9190231898366351,
#   0.9221930263994692,
#   0.9228812145279931,
#   0.9200450450649331,
#   0.9208166499435404,
#   0.9237779446112779,
#   0.9227769435705008,
#   0.9244035702369036,
#   0.9242158825293277,
#   0.9245912579444794,
#   0.9263013012615251,
#   0.9260719051987957,
#   0.9258425092156187,
#   0.9281364698031365,
#   0.9266558224891558,
#   0.927218885572107,
#   0.9271146146345027,
#   0.9257173840706054,
#   0.9295833333333333,
#   0.9312854520790093,
#   0.9293043042645281,
#   0.9298256589724375,
#   0.9301593259926594,
#   0.9317025358692025,
#   0.929617117097229,
#   0.9306598264931598,
#   0.9558516850581279,
#   0.9671338004472457,
#   0.9710960960563199,
#   0.9726184517453422,
#   0.9769978312042741,
#   0.9770395395395396,
#   0.9780196863530197,
#   0.9808558558558559,
#   0.9810643977708406,
#   0.981398064731398,
#   0.9821696696298935,
#   0.9828578578180817,
#   0.9839631297964632,
#   0.9851101100703339,
#   0.984296796836573,
#   0.98544377715022,
#   0.9858958333333333,
#   0.9869244244443125,
#   0.9871746746746747,
#   0.9874874875073756,
#   0.9876334668001334,
#   0.9886344678409107,
#   0.9893018018216899,
#   0.9884884884884885,
#   0.9888013013013013,
#   0.9891349683414111,
#   0.9891349683414111,
#   0.9900525525923287,
#   0.9908867200533867,
#   0.989572906259461,
#   0.9910744077808507,
#   0.9905739072405739,
#   0.9920337003869218,
#   0.9909909909512148,
#   0.9904696363427459,
#   0.9914706373039707,
#   0.9914914915113796,
#   0.9921796796796797,
#   0.9922839506172839],
#  'loss': [2.0231266508102417,
#   1.5497367664858386,
#   1.3303481756467441,
#   1.1736083104684427,
#   1.0655886849284688,
#   0.9914397168724307,
#   0.9474529113855448,
#   0.8864199815092383,
#   0.8498347134720615,
#   0.8172355235557697,
#   0.7895827219810014,
#   0.7681525971120224,
#   0.7366021502045819,
#   0.7224521511468961,
#   0.7062804146850352,
#   0.6879846283225644,
#   0.6697370705303846,
#   0.6605735525394385,
#   0.6374713413151336,
#   0.6362021010360361,
#   0.6240757527174773,
#   0.6132045548519851,
#   0.6058597483354924,
#   0.5958137689410029,
#   0.5860702783266704,
#   0.5797494010086811,
#   0.5671856861572724,
#   0.5650684402551419,
#   0.5552364864029564,
#   0.5396863223116598,
#   0.5434242277333129,
#   0.5418283265055439,
#   0.5274668014721748,
#   0.5281622003307731,
#   0.5181165817263607,
#   0.5216288224712864,
#   0.5142414416119699,
#   0.5057277343135537,
#   0.5024204461086103,
#   0.5019038459401072,
#   0.4977572784648166,
#   0.49172022593669745,
#   0.4912972884711958,
#   0.4845662881900837,
#   0.4786631989506908,
#   0.4862100301204143,
#   0.47416871849759484,
#   0.4754818728418003,
#   0.4713224542140961,
#   0.4693025442950917,
#   0.46036345040078236,
#   0.46147588405523216,
#   0.4611176236255749,
#   0.45864261774806764,
#   0.4567451573706962,
#   0.45322460437322165,
#   0.44998815687529276,
#   0.4434523448213801,
#   0.45046514905131496,
#   0.44812319423502434,
#   0.4398257357798937,
#   0.4437837427582071,
#   0.4367986198938565,
#   0.4384496201763242,
#   0.4343285029993321,
#   0.43597376042300157,
#   0.43080831523692564,
#   0.4313259588944184,
#   0.42437936814578325,
#   0.4289479117951156,
#   0.4267620987243003,
#   0.424678082978443,
#   0.4262324289098994,
#   0.4214605604012807,
#   0.4110066037815254,
#   0.4196388314058274,
#   0.4150629488078204,
#   0.41725898090306224,
#   0.41012603016666543,
#   0.41456435712767237,
#   0.40985050033759307,
#   0.34292668703798057,
#   0.3129795679140775,
#   0.2997444467441933,
#   0.2916085875487781,
#   0.27947378234144127,
#   0.27427045807545686,
#   0.27012095786568957,
#   0.261375859509041,
#   0.2577050145681914,
#   0.2538962662965805,
#   0.24815986236612678,
#   0.24407486636956055,
#   0.24141440968394956,
#   0.23479293875985438,
#   0.23366904577932082,
#   0.22974839499782712,
#   0.22590422574679056,
#   0.2230546736780866,
#   0.21910535458886787,
#   0.21690342228512866,
#   0.21384692458081014,
#   0.21001851389636428,
#   0.2075573479309852,
#   0.20681907417060616,
#   0.20331092966390443,
#   0.20187531167521333,
#   0.2006662551774794,
#   0.1965830432581114,
#   0.1941932456559804,
#   0.1956178919052656,
#   0.18992957342534134,
#   0.19019378520346977,
#   0.185520574863171,
#   0.18693840613574397,
#   0.1852374977376567,
#   0.1818454671311784,
#   0.18077087838887612,
#   0.17864894101748596,
#   0.17705263720479136],
#  'lr': [0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.001,
#   0.0003162278,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3.1622774e-05,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04],
#  'val_acc': [0.4512,
#   0.558,
#   0.5146,
#   0.6591,
#   0.6184,
#   0.7103,
#   0.7404,
#   0.7787,
#   0.6958,
#   0.7252,
#   0.769,
#   0.6845,
#   0.7196,
#   0.7775,
#   0.7809,
#   0.7655,
#   0.788,
#   0.8025,
#   0.8067,
#   0.7792,
#   0.7435,
#   0.7824,
#   0.8124,
#   0.8151,
#   0.7925,
#   0.8296,
#   0.8006,
#   0.8042,
#   0.8033,
#   0.8344,
#   0.8476,
#   0.8049,
#   0.8144,
#   0.8251,
#   0.8383,
#   0.7994,
#   0.8431,
#   0.7913,
#   0.8523,
#   0.8371,
#   0.8507,
#   0.7656,
#   0.8213,
#   0.8428,
#   0.8393,
#   0.8547,
#   0.817,
#   0.7965,
#   0.8425,
#   0.8444,
#   0.8361,
#   0.8074,
#   0.8106,
#   0.8417,
#   0.8431,
#   0.8419,
#   0.8615,
#   0.833,
#   0.8185,
#   0.8615,
#   0.832,
#   0.8536,
#   0.8237,
#   0.8363,
#   0.8728,
#   0.8626,
#   0.8167,
#   0.859,
#   0.8671,
#   0.842,
#   0.85,
#   0.8684,
#   0.8078,
#   0.8587,
#   0.8602,
#   0.8725,
#   0.8607,
#   0.8433,
#   0.8478,
#   0.8399,
#   0.8512,
#   0.9098,
#   0.9105,
#   0.913,
#   0.9133,
#   0.9181,
#   0.9161,
#   0.9129,
#   0.9135,
#   0.9154,
#   0.9127,
#   0.9154,
#   0.9146,
#   0.9152,
#   0.9187,
#   0.9153,
#   0.9136,
#   0.9122,
#   0.9153,
#   0.9192,
#   0.9151,
#   0.9158,
#   0.9198,
#   0.9166,
#   0.9162,
#   0.9159,
#   0.9141,
#   0.9198,
#   0.9184,
#   0.914,
#   0.9145,
#   0.9157,
#   0.9127,
#   0.9175,
#   0.9189,
#   0.9133,
#   0.9137,
#   0.9172,
#   0.9177,
#   0.9143],
#  'val_loss': [1.9742008758544922,
#   1.6275889318466186,
#   1.9159384214401245,
#   1.2832901262283325,
#   1.5374419471740723,
#   1.1792990692138672,
#   1.0662222124099732,
#   0.9380812585830689,
#   1.32002953414917,
#   1.0899700588226318,
#   0.9834986033439637,
#   1.2966240930557251,
#   1.1556272840499877,
#   0.9442348690986633,
#   0.9016872562408448,
#   1.0153935359954833,
#   0.9362041946411133,
#   0.8456424606323242,
#   0.8425469201087952,
#   0.9276600670814514,
#   1.0641323935508729,
#   0.9090133412361145,
#   0.8138298846244812,
#   0.7877408852577209,
#   0.8818083012580872,
#   0.7625448427200318,
#   0.8768039169311523,
#   0.8602410598754883,
#   0.854733565235138,
#   0.7344560872077942,
#   0.6723265970230102,
#   0.837104174232483,
#   0.8033629453659058,
#   0.7691612268924714,
#   0.7206518524169921,
#   0.8877853693962097,
#   0.7089952816963195,
#   0.9222603055477142,
#   0.6986288426399231,
#   0.8060817509174347,
#   0.682289764213562,
#   1.009591718196869,
#   0.8086231889724731,
#   0.7207880823135376,
#   0.7428314752578735,
#   0.6757287113189697,
#   0.7973006946563721,
#   0.9140133244514466,
#   0.7330590837478638,
#   0.7358919492721557,
#   0.7562826734542847,
#   0.8649570950508118,
#   0.8236403618812561,
#   0.7133600660324096,
#   0.7629197607994079,
#   0.7446933191299439,
#   0.632029418182373,
#   0.7885135999202728,
#   0.8355123805999756,
#   0.6648637441635132,
#   0.8181772772789001,
#   0.7185760165214539,
#   0.8618320404052734,
#   0.7842306435108185,
#   0.6446206084251404,
#   0.6585146026611328,
#   0.8591756593704224,
#   0.6650412045478821,
#   0.6506941736221313,
#   0.7537412568092346,
#   0.7485041986465454,
#   0.6326821261882782,
#   0.9251513829231263,
#   0.6783160581588745,
#   0.7000644751548767,
#   0.6232710853099823,
#   0.6824563697814942,
#   0.7524777807712555,
#   0.7658678905487061,
#   0.7856441387176514,
#   0.7356035587787628,
#   0.5044750347137451,
#   0.5028979661941528,
#   0.49940107769966124,
#   0.49857479887008666,
#   0.48946366944313047,
#   0.491659680891037,
#   0.5013817922592163,
#   0.5047936882019043,
#   0.49550390572547914,
#   0.5085592190742493,
#   0.4996910503387451,
#   0.493394984292984,
#   0.5045426853656769,
#   0.4943679696559906,
#   0.4983192997455597,
#   0.5083797122955322,
#   0.511932479095459,
#   0.5093541767120361,
#   0.4954479258060455,
#   0.5081724985599518,
#   0.5053313967227936,
#   0.5030083994865417,
#   0.5060481800079346,
#   0.508609428358078,
#   0.511354559803009,
#   0.522188205909729,
#   0.5005037321090698,
#   0.5066369156837464,
#   0.5253071592330932,
#   0.5183402532577515,
#   0.5156153860092163,
#   0.5233386806488037,
#   0.5068309512138367,
#   0.5000041328430176,
#   0.5294980830192566,
#   0.521079461479187,
#   0.5220742968082428,
#   0.510963489484787,
#   0.5226242725849152]}

# %%
fig, ax = plt.subplots(1,2, figsize=(16,4))

ax[0].plot(range(120),model.history.history['loss'], range(120),model.history.history['val_loss'])
ax[1].plot(range(120),model.history.history['acc'], range(120),model.history.history['val_acc'])
# Out:
# [<matplotlib.lines.Line2D at 0x7f96782667d0>,
#  <matplotlib.lines.Line2D at 0x7f9678222e10>]

# %%
plt.plot(model.history.history['lr'])

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 267us/step
# Test loss: 0.5226242788314819
# Test accuracy: 0.9143
