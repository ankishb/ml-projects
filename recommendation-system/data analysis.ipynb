# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.listdir('data')
# Out:
# ['test_submissions_NeDLEvX.csv',
#  'train_ps0mmDv_9yr6iGN.zip',
#  'sample_submissions_wbscxqU.csv',
#  'train']

# %%
os.listdir('data/train')
# Out:
# ['problem_data.csv', 'user_data.csv', 'train_submissions.csv']

# %%
problems = pd.read_csv('data/train/problem_data.csv')
users = pd.read_csv('data/train/user_data.csv')
results = pd.read_csv('data/train/train_submissions.csv')

# %%
problems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6544 entries, 0 to 6543
# Data columns (total 4 columns):
# problem_id    6544 non-null object
# level_type    6411 non-null object
# points        2627 non-null float64
# tags          3060 non-null object
# dtypes: float64(1), object(3)
# memory usage: 204.6+ KB

# %%
problems.head()
# Out:
#   problem_id level_type  points                                 tags
# 0  prob_3649          H     NaN                                  NaN
# 1  prob_6191          A     NaN                                  NaN
# 2  prob_2020          F     NaN                                  NaN
# 3   prob_313          A   500.0                greedy,implementation
# 4   prob_101          A   500.0  constructive algorithms,greedy,math

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3571 entries, 0 to 3570
# Data columns (total 11 columns):
# user_id                      3571 non-null object
# submission_count             3571 non-null int64
# problem_solved               3571 non-null int64
# contribution                 3571 non-null int64
# country                      2418 non-null object
# follower_count               3571 non-null int64
# last_online_time_seconds     3571 non-null int64
# max_rating                   3571 non-null float64
# rating                       3571 non-null float64
# rank                         3571 non-null object
# registration_time_seconds    3571 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 307.0+ KB

# %%
users.head()
# Out:
#      user_id  submission_count  problem_solved  contribution  country  \
# 0  user_3311                47              40             0      NaN
# 1  user_3028                63              52             0    India
# 2  user_2268               226             203            -8    Egypt
# 3   user_480               611             490             1  Ukraine
# 4   user_650               504             479            12   Russia
#
#    follower_count  last_online_time_seconds  max_rating   rating  \
# 0               4                1504111645     348.337  330.849
# 1              17                1498998165     405.677  339.450
# 2              24                1505566052     307.339  284.404
# 3              94                1505257499     525.803  471.330
# 4               4                1496613433     548.739  486.525
#
#            rank  registration_time_seconds
# 0  intermediate                 1466686436
# 1  intermediate                 1441893325
# ...

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155295 entries, 0 to 155294
# Data columns (total 3 columns):
# user_id           155295 non-null object
# problem_id        155295 non-null object
# attempts_range    155295 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 3.6+ MB

# %%
results.head()
# Out:
#      user_id problem_id  attempts_range
# 0   user_232  prob_6507               1
# 1  user_3568  prob_2994               3
# 2  user_1600  prob_5071               1
# 3  user_2256   prob_703               1
# 4  user_2321   prob_356               1

# %% [markdown]
# ### attempts_range==== no_of_attemps
#     1====1-1
#     2====2-3
#     3====4-5
#     4====6-7
#     5====8-9
#     6====>10

# %%
os.listdir('data')
# Out:
# ['test_submissions_NeDLEvX.csv',
#  'train_ps0mmDv_9yr6iGN.zip',
#  'sample_submissions_wbscxqU.csv',
#  'train']

# %%
test = pd.read_csv('data/test_submissions_NeDLEvX.csv')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66555 entries, 0 to 66554
# Data columns (total 3 columns):
# ID            66555 non-null object
# user_id       66555 non-null object
# problem_id    66555 non-null object
# dtypes: object(3)
# memory usage: 1.5+ MB

# %%
problems['points'].unique()
# Out:
# array([      nan,  5.00e+02,  5.00e+00,  1.00e+03,  2.00e+03,  1.50e+03,
#         2.75e+03,  1.75e+03,  2.50e+03,  8.00e+00,  7.50e+02,  2.25e+03,
#         3.00e+03,  1.25e+03,  1.00e+01, -1.00e+00,  2.50e+02,  5.00e+03,
#         3.25e+03,  4.00e+01,  6.00e+01,  3.50e+03,  3.00e+00,  2.00e+01,
#         4.00e+00,  3.00e+01,  1.20e+01,  5.00e+01,  7.00e+01,  6.00e+00,
#         1.10e+01])

# %%
problems.head()
# Out:
#   problem_id level_type  points                                 tags
# 0  prob_3649          H     NaN                                  NaN
# 1  prob_6191          A     NaN                                  NaN
# 2  prob_2020          F     NaN                                  NaN
# 3   prob_313          A   500.0                greedy,implementation
# 4   prob_101          A   500.0  constructive algorithms,greedy,math

# %%
problems.isnull().sum()
# Out:
# problem_id       0
# level_type     133
# points        3917
# tags          3484
# dtype: int64

# %%
problems.shape, users.shape
# Out:
# ((6544, 4), (3571, 11))

# %%
users.isnull().sum()
# Out:
# user_id                         0
# submission_count                0
# problem_solved                  0
# contribution                    0
# country                      1153
# follower_count                  0
# last_online_time_seconds        0
# max_rating                      0
# rating                          0
# rank                            0
# registration_time_seconds       0
# dtype: int64

# %%
users.columns
# Out:
# Index(['user_id', 'submission_count', 'problem_solved', 'contribution',
#        'country', 'follower_count', 'last_online_time_seconds', 'max_rating',
#        'rating', 'rank', 'registration_time_seconds'],
#       dtype='object')

# %%
#columns to be dropped
cols = ['country','last_online_time_seconds','registration_time_seconds']
users.drop(cols,axis=1,inplace=True)

# %%
users.head()
# Out:
#      user_id  submission_count  problem_solved  contribution  follower_count  \
# 0  user_3311                47              40             0               4
# 1  user_3028                63              52             0              17
# 2  user_2268               226             203            -8              24
# 3   user_480               611             490             1              94
# 4   user_650               504             479            12               4
#
#    max_rating   rating          rank
# 0     348.337  330.849  intermediate
# 1     405.677  339.450  intermediate
# 2     307.339  284.404      beginner
# 3     525.803  471.330      advanced
# 4     548.739  486.525      advanced

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
users['rank_enc'] = enc.fit_transform(users['rank'])

# %%
users.head()
# Out:
#      user_id  submission_count  problem_solved  contribution  follower_count  \
# 0  user_3311                47              40             0               4
# 1  user_3028                63              52             0              17
# 2  user_2268               226             203            -8              24
# 3   user_480               611             490             1              94
# 4   user_650               504             479            12               4
#
#    max_rating   rating          rank  rank_enc
# 0     348.337  330.849  intermediate         3
# 1     405.677  339.450  intermediate         3
# 2     307.339  284.404      beginner         1
# 3     525.803  471.330      advanced         0
# 4     548.739  486.525      advanced         0

# %%
users['contribution_abs'] = users['contribution'].map(lambda x: np.abs(x))

# %%
users.head()
# Out:
#      user_id  submission_count  problem_solved  contribution  follower_count  \
# 0  user_3311                47              40             0               4
# 1  user_3028                63              52             0              17
# 2  user_2268               226             203            -8              24
# 3   user_480               611             490             1              94
# 4   user_650               504             479            12               4
#
#    max_rating   rating          rank  rank_enc  contribution_abs
# 0     348.337  330.849  intermediate         3                 0
# 1     405.677  339.450  intermediate         3                 0
# 2     307.339  284.404      beginner         1                 8
# 3     525.803  471.330      advanced         0                 1
# 4     548.739  486.525      advanced         0                12

# %%
users.to_csv('cleaned_users.csv')

# %%
problems.isnull().sum()
# Out:
# problem_id       0
# level_type     133
# points        3917
# tags          3484
# dtype: int64

# %%
problems.head()
# Out:
#   problem_id level_type  points                                 tags
# 0  prob_3649          H     NaN                                  NaN
# 1  prob_6191          A     NaN                                  NaN
# 2  prob_2020          F     NaN                                  NaN
# 3   prob_313          A   500.0                greedy,implementation
# 4   prob_101          A   500.0  constructive algorithms,greedy,math

# %%
problems['level_type'].unique()
# Out:
# array(['H', 'A', 'F', 'E', 'B', 'D', 'C', 'K', 'I', nan, 'G', 'J', 'M',
#        'L', 'N'], dtype=object)

# %%
dicts = []
# problems['tags'].map(lambda x: dicts.append(x))

# %%
dicts
# Out:
# []

# %%
# store = []
# for i in dicts:
#     if not pd.isnull(i):
#         store.append(i)

# %%
# new_store = []
# for i in store:
#     for j in i.split():
#         new_store.append(j)

# %%
from nltk import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf
from sklearn.feature_extraction.text import CountVectorizer as countvec
from keras.preprocessing import sequence, text
# Out:
# Using TensorFlow backend.

# %%
# problems['tag_dict'] = problems['tags'].map(lambda x: x.split())
# problems['tags'].map(lambda x: x if not pd.isnull(x) else '')
problems['tag_dict'] = problems['tags'].map(lambda x: x.split(',') if not pd.isnull(x) else '')

# %%
new_store = []
for i in problems['tag_dict']:
    for j in i:
        new_store.append(j)

# %%
# ''.join(problems['tag_dict'][3]).split(',')
new_store
# Out:
# ['greedy',
#  'implementation',
#  'constructive algorithms',
#  'greedy',
#  'math',
#  'brute force',
#  'dfs and similar',
#  'dsu',
#  'graphs',
#  'implementation',
#  'math',
#  'math',
#  'number theory',
#  'brute force',
#  'dp',
#  'number theory',
#  'brute force',
#  'dfs and similar',
#  'graphs',
#  'implementation',
#  'data structures',
#  'expression parsing',
#  'math',
#  'dfs and similar',
#  'greedy',
#  'bitmasks',
#  'brute force',
#  'dfs and similar',
#  'expression parsing',
#  'implementation',
#  'constructive algorithms',
#  'divide and conquer',
#  'implementation',
#  'brute force',
#  'implementation',
#  'sortings',
#  'greedy',
#  'shortest paths',
#  'combinatorics',
#  'constructive algorithms',
#  'dfs and similar',
#  'graphs',
#  'brute force',
#  'math',
#  'strings',
#  'implementation',
#  'dfs and similar',
#  'combinatorics',
#  'dp',
#  'number theory',
#  'dfs and similar',
#  'dsu',
#  'brute force',
#  'implementation',
#  'sortings',
# ...

# %%
problems['tags'].map(lambda x: i.lower() for i in x.split(',') if not pd.isnull(i) else '')
# data = [line.strip() for line in open("C:\corpus\TermList.txt", 'r')]
# texts = [[word.lower() for word in text.split()] for text in data]
# Out:
#   File "<ipython-input-37-8579ce565f83>", line 1
#     problems['tags'].map(lambda x: i.lower() for i in x.split(',') if not pd.isnull(i) else '')
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
problems['tag_dict'] = problems['tags'].map(lambda x: x.split(',') if not pd.isnull(x) else '')
problems['tag_dict'].head()
# Out:
# 0
# 1
# 2
# 3                   [greedy, implementation]
# 4    [constructive algorithms, greedy, math]
# Name: tag_dict, dtype: object

# %%
tfv = tfidf(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3), use_idf=1,smooth_idf=1,sublinear_tf=1,
            stop_words = 'english')

# Fitting TF-IDF to both training and test sets (semi-supervised learning)
tfv.fit(new_store)
# temp = tfv.transform(problems['tag_dict'])
# temp = tfv.fit_transform(problems['tag_dict'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=3,
#         ngram_range=(1, 3), norm='l2', preprocessor=None, smooth_idf=1,
#         stop_words='english', strip_accents='unicode', sublinear_tf=1,
#         token_pattern='\\w{1,}', tokenizer=None, use_idf=1,
#         vocabulary=None)

# %%
tfv.transform(problems['tag_dict'][4])
# Out:
# <3x70 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
problems['tag_vect'] = problems['tag_dict'].map(lambda x: tfv.transform(x) if x != '' else 0)

# %%
problems['tag_vect'][3],problems['tag_vect'][4],problems['tag_vect'][7]

# %%
problems['tags'].map(lambda x: x if not pd.isnull(x) else '')[3]
# Out:
# 'greedy,implementation'

# %%
tfv.transform(problems['tags'].map(lambda x: x.split(',') if not pd.isnull(x) else '')[3])
# Out:
# <2x70 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
problems['tag_dict'].map(lambda x: ' '.join(x))[3]
# Out:
# 'greedy implementation'

# %%
tfv.transform(problems['tag_dict'].map(lambda x: ' '.join(x))[3])
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-61-e5029caf2abb> in <module>()
# ----> 1 tfv.transform(problems['tag_dict'].map(lambda x: ' '.join(x))[3])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents, copy)
#    1609         check_is_fitted(self, '_tfidf', 'The tfidf vector is not fitted')
#    1610
# -> 1611         X = super(TfidfVectorizer, self).transform(raw_documents)
#    1612         return self._tfidf.transform(X, copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1055         if isinstance(raw_documents, six.string_types):
#    1056             raise ValueError(
# -> 1057                 "Iterable over raw text documents expected, "
#    1058                 "string object received.")
#    1059
#
# ...

# %%
problems
# Out:
#      problem_id level_type  points  \
# 0     prob_3649          H     NaN
# 1     prob_6191          A     NaN
# 2     prob_2020          F     NaN
# 3      prob_313          A   500.0
# 4      prob_101          A   500.0
# 5     prob_1479          E     NaN
# 6     prob_2940          B     NaN
# 7     prob_3059          B     5.0
# 8     prob_1958          D     NaN
# 9     prob_6154          C     NaN
# 10    prob_4069          B  1000.0
# 11    prob_4926          A   500.0
# 12    prob_3154          K     NaN
# 13    prob_1538          A     NaN
# 14    prob_3750          B  1000.0
# 15    prob_4440          I     NaN
# 16    prob_4569          A     NaN
# 17    prob_4189          D     NaN
# 18     prob_526          D  2000.0
# 19    prob_5498          I     NaN
# 20    prob_3216          F     NaN
# 21    prob_1412          C  1500.0
# 22    prob_5088          B     NaN
# 23    prob_5693          D  2000.0
# 24      prob_75          A   500.0
# ...

# %%
tfv.transform(["math,number"])
# Out:
# <1x70 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
tfv.transform(problems['tag_dict'].map(lambda x: [','.join(x)]))
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# <ipython-input-79-a948a88dfb33> in <module>()
# ----> 1 tfv.transform(problems['tag_dict'].map(lambda x: [','.join(x)]))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents, copy)
#    1609         check_is_fitted(self, '_tfidf', 'The tfidf vector is not fitted')
#    1610
# -> 1611         X = super(TfidfVectorizer, self).transform(raw_documents)
#    1612         return self._tfidf.transform(X, copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1064
#    1065         # use the same matrix-building strategy as fit_transform
# -> 1066         _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1067         if self.binary:
#    1068             X.data.fill(1)
#
# ...

# %%
problems['tag_vect'] = problems['tag_vect'].map(lambda x: np.zeros((1,70)))

# %%
for idx,i in enumerate(problems['tag_dict']):
#     print(tfv.transform([','.join(i)]).shape)
    problems.loc[idx,'tag_vect'] = np.array(tfv.transform([','.join(i)]))

# %%
problems['tag_vect'][4]
# Out:
# array(<1x70 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>, dtype=object)

# %%
problems.head()
# Out:
#   problem_id level_type  points                                 tags  \
# 0  prob_3649          H     NaN                                  NaN
# 1  prob_6191          A     NaN                                  NaN
# 2  prob_2020          F     NaN                                  NaN
# 3   prob_313          A   500.0                greedy,implementation
# 4   prob_101          A   500.0  constructive algorithms,greedy,math
#
#                                   tag_dict  \
# 0
# 1
# 2
# 3                 [greedy, implementation]
# 4  [constructive algorithms, greedy, math]
#
#                                             tag_vect
# 0
# 1
# 2
# 3    (0, 35)\t0.643835105031232\n  (0, 33)\t0.765...
# 4    (0, 37)\t0.4053203601812274\n  (0, 33)\t0.40...

# %%
problems.to_csv('problems_features.csv')

# %%
# problems.loc[1,'tag_vect'] = 100
