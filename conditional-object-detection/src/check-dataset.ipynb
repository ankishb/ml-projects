# %% [markdown]
# # Conclusion:
#     All images of training and testing `csv` present in the `train/images` folder. So read all the image from the same folder.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
level3_tr = pd.read_csv('/home/ankish1/ankish_save/yolo/data/level3_data/training_set.csv')
level3_ts = pd.read_csv('/home/ankish1/ankish_save/yolo/data/level3_data/test.csv')

print("check size of training and testing: ", level3_tr.shape, level3_ts.shape)

tr_img_dir_pr = []
tr_img_dir_ab = []
tr_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(tr_dir)
count = 0
for img in level3_tr.image_name.values:
    if img in all_img_dir:
        tr_img_dir_pr.append(tr_dir + img)
    else:
        count += 1
        tr_img_dir_ab.append(ts_dir + img)

print("=="*20)
print("total image found in training set present in images folder: ", len(tr_img_dir_pr))
print("count of not found images in training set : ",count)

ts_img_dir_pr = []
ts_img_dir_ab = []
ts_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(ts_dir)
count = 0
for img in level3_ts.image_name.values:
    if img in all_img_dir:
        ts_img_dir_pr.append(ts_dir + img)
    else:
        count += 1
        ts_img_dir_ab.append(ts_dir + img)
        
print("=="*20)
print("total image found in training set present in images folder: ", len(ts_img_dir_pr))

print("count of not found images in testing set : ",count)
# Out:
# ('check size of training and testing: ', (24000, 5), (24045, 5))
# ...
# ('total image found in training set present in images folder: ', 24000)
# ('count of not found images in training set : ', 0)
# ...
# ('total image found in training set present in images folder: ', 24045)
# ('count of not found images in testing set : ', 0)

# %%
(40/60.0) * 200
# Out:
# 133.33333333333331

# %%
level3_tr = pd.read_csv('/home/ankish1/ankish_save/yolo/data/training.csv')
level3_ts = pd.read_csv('/home/ankish1/ankish_save/yolo/data/test.csv')

print("check size of training and testing: ", level3_tr.shape, level3_ts.shape)

tr_img_dir_pr = []
tr_img_dir_ab = []
tr_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(tr_dir)
count = 0
for img in level3_tr.image_name.values:
    if img in all_img_dir:
        tr_img_dir_pr.append(tr_dir + img)
    else:
        count += 1
        tr_img_dir_ab.append(ts_dir + img)

print("=="*20)
print("total image found in training set present in images folder: ", len(tr_img_dir_pr))
print("count of not found images in training set : ",count)

ts_img_dir_pr = []
ts_img_dir_ab = []
ts_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(ts_dir)
count = 0
for img in level3_ts.image_name.values:
    if img in all_img_dir:
        ts_img_dir_pr.append(ts_dir + img)
    else:
        count += 1
        ts_img_dir_ab.append(ts_dir + img)
        
print("=="*20)
print("total image found in training set present in images folder: ", len(ts_img_dir_pr))

print("count of not found images in testing set : ",count)
# Out:
# ('check size of training and testing: ', (14000, 5), (12815, 5))
# ...
# ('total image found in training set present in images folder: ', 14000)
# ('count of not found images in training set : ', 0)
# ...
# ('total image found in training set present in images folder: ', 12815)
# ('count of not found images in testing set : ', 0)

# %%
level3_tr = pd.read_csv('/home/ankish1/ankish_save/yolo/data/level3_data/training_set.csv')
level2_tr = pd.read_csv('/home/ankish1/ankish_save/yolo/data/training.csv')

# %%
level3_tr.head()
# Out:
#                                           image_name   x1   x2   y1   y2
# 0             JPEG_20160517_140621_1000651031832.png   78  446   83  422
# 1                   1473231510890DeeplearnS11456.png   73  567  146  351
# 2                         1476881557883Untitled1.png   13  561  124  362
# 3  1474264827890cobalt-beyond-the-sea-maxi-dress3...    0  640  140  330
# 4             JPEG_20160711_113321_1000235741992.png  217  442   65  465

# %%
level2_tr.head()
# Out:
#                                           image_name   x1   x2   y1   y2
# 0             JPEG_20160706_121146_1000145715002.png  115  495  143  325
# 1             JPEG_20161119_174038_1000690577600.png   23  457   61  409
# 2  147444927651111470309333776-Roadster-Men-Casua...   37  601   13  470
# 3                   147772332675720161028_161611.png   27  602  162  385
# 4                   1473315333651DeeplearnS11638.png   60  586  174  325

# %%
count_2 = level2_tr.image_name.value_counts()
count_3 = level3_tr.image_name.value_counts()

# %%
for i,c in enumerate(count_3):
    if c != 1:
        print(i)

# %%
level_combine = pd.concat([level2_tr, level3_tr], axis=0)
count_combine = level_combine.image_name.value_counts()

count = 0
for i,c in enumerate(count_combine):
    if c != 2:
#         print(i)
        count += 1
count
# Out:
# 23940

# %%
level2_tr = pd.read_csv('/home/ankish1/ankish_save/yolo/data/training.csv')
level2_ts = pd.read_csv('/home/ankish1/ankish_save/yolo/data/test.csv')

level2_tr.shape, level2_ts.shape
# Out:
# ((14000, 5), (12815, 5))

# %%
len(os.listdir('/home/ankish1/ankish_save/yolo/data/train/images/'))
# Out:
# 56791

# %%
len(os.listdir('/home/ankish1/ankish_save/yolo/data/test/'))
# Out:
# 12815

# %%
tr_img_dir = []
tr_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(tr_dir)
count = 0
for img in level3_tr.image_name.values:
    if img in all_img_dir:
        tr_img_dir.append(tr_dir + img)
    else:
        print(img)
        count += 1
        
count
# Out:
# 0

# %%
ts_img_dir_pr = []
ts_img_dir_ab = []
ts_dir = '/home/ankish1/ankish_save/yolo/data/test/'
all_img_dir = os.listdir(ts_dir)
count = 0
for img in level3_ts.image_name.values:
    if img in all_img_dir:
        ts_img_dir_pr.append(ts_dir + img)
    else:
#         print(img)
        count += 1
        ts_img_dir_ab.append(ts_dir + img)
        
count
# Out:
# 17590

# %%
level3_ts.image_name.shape[0] - count
# Out:
# 6455

# %%
ts_dir = '/home/ankish1/ankish_save/yolo/data/train/images/'
all_img_dir = os.listdir(ts_dir)
count = 0
for img in level3_ts.image_name.values:
    if img in all_img_dir:
        count += 1
#     else:
#         print(img)
#         count += 1
        
count
# Out:
# 24045

# %%
level3_ts.image_name[:5]
# Out:
# 0                 1467891670691DSC_0582.png
# 1                 1475151786691DSC00560.png
# 2                 1480334114405_R2A3620.png
# 3    JPEG_20160712_161047_1000606860114.png
# 4      JPEG_20160403_174522_-1137349501.png
# Name: image_name, dtype: object

# %%
from PIL import Image
Image.open(ts_dir+'1467891670691DSC_0582.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x7FB5D0A05C50>
