# %%
import pandas as pd

# %%
df = pd.read_csv('data/fast_route.csv', 
                usecols=['id','total_distance','total_travel_time','number_of_steps'])
df.to_csv('fast_route_small.csv')

# %%
df1 = df.loc[:50000-1]
df1.to_csv('fast_route_small_data.csv')

# %% [markdown]
# #

# %%
reset_selective df1
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
reset_selective df
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
df = pd.read_csv('small_data_set/fast_route1.csv', index_col=0)
df1 = pd.read_csv('small_data_set/fast_route1.csv', index_col=0)

# %%
df
# Out:
#               id  total_distance  total_travel_time  number_of_steps
# 0      id2875421          2009.1              164.9                5
# 1      id2377394          2513.2              332.0                6
# 2      id3504673          1779.4              235.8                4
# 3      id2181028          1614.9              140.1                5
# 4      id0801584          1393.5              189.4                5
# 5      id1813257          1705.1              138.8                5
# 6      id1301050          1310.7              160.6                2
# 7      id0012891          6786.8              601.8               13
# 8      id1436371          3935.0              535.4                6
# 9      id1299289          5596.6              514.8                9
# 10     id1187965          2276.6              207.9                4
# 11     id0799785          1337.9              132.4                4
# 12     id2900608          8017.6              807.7               10
# ...

# %%
df1
# Out:
#               id  total_distance  total_travel_time  number_of_steps
# 0      id2875421          2009.1              164.9                5
# 1      id2377394          2513.2              332.0                6
# 2      id3504673          1779.4              235.8                4
# 3      id2181028          1614.9              140.1                5
# 4      id0801584          1393.5              189.4                5
# 5      id1813257          1705.1              138.8                5
# 6      id1301050          1310.7              160.6                2
# 7      id0012891          6786.8              601.8               13
# 8      id1436371          3935.0              535.4                6
# 9      id1299289          5596.6              514.8                9
# 10     id1187965          2276.6              207.9                4
# 11     id0799785          1337.9              132.4                4
# 12     id2900608          8017.6              807.7               10
# ...

# %%
# anotehr way 
# pd.read_csv(io.StringIO(df.to_csv()), index_col=0)
