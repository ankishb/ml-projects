# %%
import pickle 
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu
# Out:
# Using TensorFlow backend.

# %%
def load_doc(file_name):
    with open(file_name,'r') as f:
        text = f.read()
    return text

# %%
temp = load_doc('data_use/Flickr8k_text/Flickr8k.token_small.txt')
print(temp)
del temp
# Out:
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the stairs to her playhouse .
# 1000268201_693b08cb0e.jpg#4	A little girl in a pink dress going into a wooden cabin .
# 1001773457_577c3a7d70.jpg#4	Two dogs on pavement moving toward each other .
# 1002674143_1b742ab4b8.jpg#0	A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl .

# %% [markdown]
# ## function to load all the image identifiers
# ### we return a set ==>> to ensure there is no duplicate

# %%
def load_set_of_images(file_name):
    doc = load_doc(file_name)
    images_list = list()
    for line in doc.split('\n'):
        if len(line) < 1: #skip empty lines
            continue
        identifiers = line.split('.')[0]
        images_list.append(identifiers)
    return set(images_list)

# %% [markdown]
# ## prepare a dictionary which contain image:caption
#  ## descriptions = {'3242718240_3358f2d6e6': sentence1. sentence2. sentence3.}

# %%
def load_clean_descriptions(file_name, images_list):
    doc = load_doc(file_name)
    descriptions = dict()
    for line in doc.split('\n'):
        tokens = line.split()
        image_id, image_description = tokens[0],tokens[1:]
        for image_id in images_list:
            if image_id not in descriptions:
                descriptions[image_id] = list()
            # break sentences by the dot and add ssss and eeee and join them
            desc = 'ssss ' + ' '.join(image_description) + ' eeee'
            descriptions[image_id].append(desc)
    return descriptions

# %% [markdown]
# ## Load image features in dict

# %%
def load_photo_features(file_name,dataset):
    all_features = pickle.load(open(file_name,'rb'))
    features_dict = dict()
    for image_id in dataset:
        features_dict[image_id] = all_features[image_id]
    return features_dict

# %%
def collect_all_sentences(descriptions):
    all_descriptions = list()
    for key in descriptions.keys():
        for desc in descriptions[key]:
            all_descriptions.append(desc)
    return all_descriptions

# %%
def create_tokenizer(descriptions):
    all_sentences = collect_all_sentences(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(all_sentences)
    return tokenizer

# %%
def max_length(descriptions):
    all_lines = collect_all_sentences(descriptions)
    return np.max(len(line.split()) for line in all_lines)

# %% [markdown]
# ## tokenizer.word_index
#
# ### return a uniquely assigned integer to words

# %%
def find_word_for_integer(integer,tokenizer):
    for word,word_integer in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %% [markdown]
# # Didn't like this method===>> FIND BETTER

# %%
# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo):
	X1, X2, y = list(), list(), list()
	# walk through each description for the image
	for desc in desc_list:
		# encode the sequence
		seq = tokenizer.texts_to_sequences([desc])[0]
		# split one sequence into multiple X,y pairs
		for i in range(1, len(seq)):
			# split into input and output pair
			in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence
			in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence
			out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
			X1.append(photo)
			X2.append(in_seq)
			y.append(out_seq)
	return array(X1), array(X2), array(y)

# %% [markdown]
# # BETTER APPROACH ==> TimeDistributed layer

# %%
# model = Sequential()
# model.add(Embedding(vocabulary, hidden_size, input_length=num_steps))
# model.add(LSTM(hidden_size, return_sequences=True))
# model.add(LSTM(hidden_size, return_sequences=True))
# if use_dropout:
#     model.add(Dropout(0.5))
# model.add(TimeDistributed(Dense(vocabulary)))
# model.add(Activation('softmax'))

# %%
# define the captioning model
def define_model(vocab_size, max_length):
    # feature extractor model
    inputs1 = Input(shape=(1000,))
#     fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(64, activation='relu')(fe1) #256
    # sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 64, mask_zero=True)(inputs2)#256
#     se2 = Dropout(0.5)(se1)
    se3 = LSTM(64)(se2)#256
    # decoder model
    decoder1 = add([fe2, se3])
    decoder2 = Dense(64, activation='relu')(decoder1)#256
    outputs = Dense(vocab_size, activation='softmax')(decoder2)
    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    # compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    # summarize model
    model.summary()
#     plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
def data_generator(photos,descriptions,tokenizer,max_length):
    while 1:
        for key,desc_list in descriptions.items():
            photo = photos[key]
            in_img, in_seq, out_seq = create_sequences(tokenizer, max_length, desc_list, photo)
            yield [[in_img,in_seq], out_seq]

# %%
import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)
# Out:
# [('Tokenizer', 1056),
#  ('collect_all_sentences', 136),
#  ('corpus_bleu', 136),
#  ('create_sequences', 136),
#  ('create_tokenizer', 136),
#  ('data_generator', 136),
#  ('define_model', 136),
#  ('find_word_for_integer', 136),
#  ('load_clean_descriptions', 136),
#  ('load_doc', 136),
#  ('load_model', 136),
#  ('load_photo_features', 136),
#  ('load_set_of_images', 136),
#  ('max_length', 136),
#  ('pad_sequences', 136),
#  ('np', 80)]

# %%
# load training dataset (6K)
filename = 'data_use/Flickr8k_text/Flickr_8k.trainImages.txt'
train = load_doc(filename)
print('Dataset: %d' % len(train))
# Out:
# Dataset: 154678

# %%
train = train[:10000]
len(train)
# Out:
# 10000

# %%
import os
os.listdir()
# Out:
# ['y.npy',
#  'model_preparation.ipynb',
#  '21_Machine_Translation.ipynb',
#  'new_small_descriptions.pkl',
#  '.ipynb_checkpoints',
#  'X1.npy',
#  'resnet50_complete.h5',
#  'descriptions.txt',
#  'attention_idea.ipynb',
#  'prepare_image_feature.ipynb',
#  'prepare_text_data.ipynb',
#  'prepare_dataset.py',
#  'prepare_dataset.py~',
#  'resnet50_weights.h5',
#  '22_Image_Captioning.ipynb',
#  'final_model_progressive_loading.ipynb',
#  'loading_testing.ipynb',
#  'data_use',
#  'Y.npy',
#  'progressive_loading_captioning.ipynb',
#  'X2.npy',
#  'features.pkl',
#  'data',
#  'final_image_captioning_working.ipynb',
#  'resnet50_testing_layers.ipynb',
#  'image_captioning.ipynb']

# %%
file_name = 'new_small_descriptions.pkl'
desc = pickle.load(open(file_name,'rb'))

# %%
desc
# Out:
# {'3242718240_3358f2d6e6': 'the six children are laughing',
#  '1355450069_c0675b0706': 'there is rock climber holding on and climbing to the top of very large rock',
#  '724702877_f2a938766b': 'small dog catches tennis ball in its mouth indoors',
#  '3067500667_0fce8f28d4': 'player hits the ball at cricket game',
#  '1452361926_6d8c535e32': 'the child sits in toy car and drinks from sippy cup',
#  '1525153022_06c48dbe52': 'the dog runs through the water',
#  '282960970_574aa1ba49': 'this person is sitting in saddle',
#  '119534510_d52b3781a3': 'person sitting on concrete landing next to body of water',
#  '241347460_81d5d62bf6': 'the football player in red kicks off the ball',
#  '3540416981_4e74f08cbb': 'the white dog is running in the green grass',
#  '2333816000_7105d0ffac': 'the man climbing the rock is wearing blue helmet',
#  '2533642917_a5eace85e6': 'little boy kneedeep in water',
#  '521658170_a837af87e9': 'three dogs trying to get stick from their owner',
#  '3537201804_ce07aff237': 'two kids sit in the middle of playground toy that spins around them',
#  '2170187328_65c2f11891': 'there is kid jumping off diving board into pool',
#  '2861100960_457ceda7fa': 'the man is wearing straw hat and smoking cigarette',
#  '3498240367_cbd8c6efbf': 'two young kids putting their heads in the bodies of king and queen',
#  '1288909046_d2b2b62607': 'dog takes leap of faith as he jumps into pool to grab an orange toy',
#  '3275704430_a75828048f': 'the man with brown hair in the black sweater is covering his face with his hands',
#  '3315353266_70f0bbb1c3': 'man plays his guitar with the case open for donations',
#  '418667611_b9995000f4': 'waist down picture of surfer riding small wave',
#  '241347204_007d83e252': 'the red and white football team is talking with the officials',
#  '3204686006_88f04547b9': 'four people in various stage of sledding on snowy hill while dog playfully chases one of them',
#  '3016178284_ec50a09e8c': 'boy in helmet riding his bike in marathon',
#  '3364796213_b8948913b5': 'people ride bikes and carry black flags along road where others are gathered',
#  '857914283_270d7d1c87': 'two little boys are playing together on the bed',
#  '3614542901_29877fc342': 'old lady with black dress and hat points out something to bride',
#  '2866696346_4dcccbd3a5': 'two men skateboards at high speed',
#  '2098646162_e3b3bbf14c': 'two dogs are staring at grey and white cat',
#  '3256603992_67312b5a36': 'man standing in the midst of plants is giving two thumbs up',
#  '109738763_90541ef30d': 'the man is up in the air',
#  '3546474710_903c3c9fd3': 'the gutarist upfront is under spotlight and the drummer in the back is under one too',
#  '544257613_d9a1fea3f7': 'strawberry haired guy flashes his blue eyes and big smile at the camera',
#  '2149982207_5345633bbf': 'young boy riding in green boat',
#  '3321063116_4e5deeac83': 'three dogs running towards fence in the snow',
#  '2533414541_362bf043bb': 'the blue and white car is in the road with onlookers nearby',
#  '3356938707_d95ba97430': 'two men wearing eyeglasses standing together',
#  '3215117062_6e07a86352': 'two people watch tv from over white ledge',
#  '3271385712_ffd34f2de5': 'two people looking at each other third person is not attentive',
#  '186890605_ddff5b694e': 'there is man swinging off rope swing into lake',
#  '2268729848_d418451226': 'kids riding the subway',
#  '2053777548_108e54c826': 'the dog jumps to catch the ball',
#  '3461049169_e068ae4f25': 'young girl standing in front of fountain with woman to her side',
#  '2918880895_e61f74f2f0': 'two men each have one arm around each other and are in formal dresswear',
#  '1414820925_3504c394e1': 'guy in red shorts jumping up in front of volleyball net',
#  '2947452329_08f2d2a467': 'soccer player wipes face with blue jersey',
#  '2587846523_b177c9a3e3': 'the man is throwing tennis ball for the brown dog to fetch',
#  '400851260_5911898657': 'man walking through the deep snow at dusk',
#  '3176278670_195eea071c': 'people standing at carnival game of balloons and stuffed animals on wall',
#  '2632381125_de32bdfdf6': 'two large dogs fighting over frisbee in the water',
#  '3051754615_3d6494c2ae': 'rowers racing furiously',
#  '929679367_ff8c7df2ee': 'whitefooted beagle plays with tennis ball on garden path',
#  '3529211822_1dabdb3a9c': 'the brown dog eats from bowl on the wooden table as black dog jumps off',
#  '488196964_49159f11fd': 'very wet dog coming toward the camera through mossy pond with ball',
#  '1244485675_822e6efe60': 'the young asian boy looks at his reflection in the park',
#  '2119302248_72493d458c': 'the woman in glasses is wearing black headdress',
#  '3126225245_96cd2c053f': 'young boy with blonde hair swipes at bubbles in the air',
#  '2750832671_4b39f06acf': 'black dog playing with white and blue toy',
#  '3518443604_6da641f07d': 'two people wearing jeans huddle near wooden door sheilding their faces from the camera',
#  '2900048238_74bd69d87d': 'young man in blue shirt sits in front of group of blue and white umbrellas',
#  '3501206996_477be0f318': 'the young boy wearing brown coat is playing soccer',
#  '2766726291_b83eb5d315': 'young boy blows into hose while sitting on the deck',
#  '3525453732_f74a38f111': 'the bird has its wings spread as it flies',
#  '2410153942_ba4a136358': 'this offroading driver has tipped his truck',
#  '2465691083_894fc48af6': 'black and tan dog swimming toward shore of pond',
#  '1377668044_36398401dd': 'the dog is jumping for the item the man is holding above his head',
#  '2539933563_17ff0758c7': 'woman standing with drink in her hand next to tent',
#  '3533145793_5d69f72e41': 'several young girls on colorful mats stretching upwards',
#  '2305437797_e6c3460190': 'the dog is fetching stick in water',
#  '3712742641_641282803e': 'the black and white dog is swimming in the river',
#  '2313230479_13f87c6bf3': 'two dogs are running together through the grass',
#  '3584196366_a4b43d6644': 'group of white birds take flight while one black bird stands on the sand',
#  '2661294481_b86058b504': 'many people hold signs and march down the street',
#  '241046599_28b0ca7b9f': 'the dog is wearing purple cape',
#  '2273038287_3004a72a34': 'black dog running with his tongue out',
#  '2242863004_3a9f82a31f': 'german sheppard dog bting large red ball',
#  '3522349685_f046f0e250': 'young girl in ponytail pets furry cat',
#  '1482960952_95f2d419cb': 'three old ladies walking and carrying purses',
#  '2732625904_4fbb653434': 'girl wearing pink rides yellow bike near white fence',
#  '1115679311_245eff2f4b': 'an animal is running on the beach',
#  '3497502407_ec566442c9': 'woman stands on circular ledge surrounding tall tree',
#  '2078311270_f01c9eaf4c': 'two women walking near some trees in warm darkcolored garments one with hat one with an upraised collar',
#  '3143980056_7a64a94b58': 'the baby pinches the woman cheek',
#  '3033612929_764d977bd5': 'two dogs walking with their toys',
#  '1468103286_96a6e07029': 'new york yankee warming up',
#  '3367053761_8ec5834bf3': 'two people are sitting at desks by the windows in library',
#  '3585487286_ef9a8d4c56': 'two white dogs are running and jumping along beach with the ocean behind them',
#  '2564888404_b57f89d3c7': 'two dogs running side by side in water',
#  '2749124446_d4432787b5': 'two horses are neck to neck at race',
#  '1337792872_d01a390b33': 'the little girl is wearing denim dress and holding brown teddy bear',
#  '2684489465_32ba1d0344': 'the white dog is leaping over red and green fence on an obstacle course',
#  '359173181_a75c950aeb': 'the brown furry animal is walking in the snowy grass with tree behind him',
#  '3648988742_888a16f600': 'young girl in pink hat taking pictures',
#  '3211210739_3dea005fde': 'the gymnast does flip over the bar',
#  '3028404926_2bd27e3e83': 'young boy turning crank in the street',
#  '3418504074_083f0bb68d': 'the little black and white dog is in the snow whit red ball',
#  '3730457171_e66dde8c91': 'little girl riding her toy on the sidewalk',
#  '278002800_3817135105': 'man in black is eating baked good near two elderly men',
#  '3567061016_62768dcce1': 'hawk is flying trailing lines from its legs',
#  '384465370_9918873f9a': 'two people riding their bikes on hill',
#  '1827560917_c8d3c5627f': 'small black and white dog in harness is looking at the camera',
#  '1517807181_ca6588f2a0': 'two young girls run across field as they fly kite in the cloudcovered sky',
#  '3520321387_710ab74cda': 'mother and son grin for the camera',
#  '1499495021_d295ce577c': 'man and woman fishing in the ocean',
#  '2396100671_3a9d67f03d': 'young boy sits on his bike wearing dragon costume',
#  '2461616306_3ee7ac1b4b': 'the young boy is jumping into the pool on his belly',
#  '3431860810_44277cd360': 'wooly dog on beach looks toward another dog in the water',
#  '2225241766_f1e7132e3e': 'man laying on platform outside on some rocks',
#  '3262075846_5695021d84': 'men play rugby',
#  '2369840118_a1c4240ab7': 'young boy dressed in green holds baby goat in arms',
#  '2319808437_bbbdc317c0': 'two boys watch third boy kicking some snow',
#  '536721406_884ab8fece': 'the dog barks madly at the bull in the pen',
#  '519059913_4906fe4050': 'young boy jumping upsidedown into pool',
#  '2258662398_2797d0eca8': 'young surfer rides wave',
#  '2647229826_e0e0c65ef1': 'six children near water fountain',
#  '965444691_fe7e85bf0e': 'the man is holding baby near carnival game',
#  '2893374123_087f98d58a': 'motorcyclist rides down ramp held up by colorful barrels',
#  '823697339_aadbeef495': 'two women one with red hair stand outside store',
#  '263850317_5bb3a18a08': 'girl wearing mini dress and long sleve white jacket with pink bag walking through crowded area',
#  '3439331800_e71e1d808f': 'four young men dance onstage',
#  '3326588088_172d1b2584': 'two men wearing white suits play guitar onstage',
#  '2461631708_decc5b8c87': 'young boys in orange life vests sit on raft',
#  '1174525839_7c1e6cfa86': 'the girls is jumping into the air on the beach',
#  '3239021459_a6b71bb400': 'the young man is flying through the air on his green snowboard',
#  '3168841415_c0705a327a': 'the little kid runs to grab the blue frisbee that is flying through the air',
#  '419116771_642800891d': 'three dogs look on as two dogs attack third dog in the streets',
#  '746787916_ceb103069f': 'small show dog just ran through an orange flexible tube',
#  '1975171469_84e425f61b': 'young child plays an arcade game',
#  '2701603045_6cbdc4ce7c': 'the boy is wading through the blue ocean',
#  '3217187564_0ffd89dec1': 'three race dogs run to finish race',
#  '3718007650_e5930b4509': 'the back of woman in costume little girl looks at her',
#  '1332823164_c70a5d930e': 'woman standing on the shore of beach',
#  '2380740486_8cd5d4601a': 'girl with two ducks on cliff overlooking the water',
#  '2193980605_4221c6474d': 'six people jump for ball',
#  '2321466753_5606a10721': 'young child is holding onto the back of wicker chair',
#  '3225226381_9fe306fb9e': 'two dogs running one brown and one grey',
#  '3613424631_3ae537624f': 'man with bike sitting next to rubble',
#  '2992808092_5f677085b7': 'two teenagers participate in game of field hockey',
#  '1819261140_6c022f4b1d': 'person at table dressed in black costume',
#  '3383037991_8f07784b81': 'the large brown dog sat on the bed surronded by wrapping paper',
#  '288025239_5e59ba9c3b': 'the hiker pokes out of her tent to find that snow is everywhere',
#  '3518755601_cebf11e515': 'three young women wearing wetsuits on beach two gesturing at camera',
#  '3409947123_a8d07edecf': 'the people are standing around at carnival',
#  '2572101672_4d699c8713': 'the man is standing next to bird cage',
#  '3105315670_5f86f73753': 'the woman is wearing brown hat and black coat and is on sidewalk',
#  '479807465_cf42f39d00': 'young dirt bikers try to get dirt bike up sandy hill',
#  '3561433412_3985208d53': 'wolflike dog chasing white wiffle ball through green field',
#  '2449289139_08fc1092c1': 'the dog runs in the park',
#  '3295671644_0e10891b6d': 'the little dog with big ears is in the field',
#  '124195430_d14028660f': 'thin brown horse standing and small black horse sitting on sand',
#  '2258951972_92763fddab': 'two large gray dogs running through grassy field',
#  '2500567791_101d5ddee3': 'dog chasing brown cow and black cow',
#  '3203908917_53e53c03d1': 'the man is wearing red shirt and red flannel handkerchief while watching flag burn',
#  '2229509318_be3fef006b': 'woman is standing in front of dog that standing on its hind legs',
#  '252578659_9e404b6430': 'three sheep graze on the grassy field with dog walking behind them',
#  '2832978253_8fcc72da3b': 'person wearing red and white climbs foggy mountain',
#  '1082252566_8c79beef93': 'three dogs of various sizes',
#  '3148647065_2d6cd88cf6': 'pale brown dog runs in blurred rural scene',
#  '3710674892_857b8056f7': 'child with green apple in his mouth is wearing red life jacket',
#  '3561537309_e271d57492': 'the young boy opens his arms as waves come crashing near him',
#  '2991771557_d98fa0a69f': 'snowboarder wearing green hat is riding along metal railing',
#  '3454355269_6185e29f95': 'man in safety gear riding bike on rocky trail',
#  '2423085253_6c19149855': 'the girl is running on the grass next to colorful toy',
#  '3483140026_e14f64fdf5': 'smiling construction worker with white helmet',
#  '387830531_e89c192b92': 'two dogs playing with each other',
#  '3533451027_b078e4631b': 'the man in the black and white shirt is running with ball',
#  '3726168984_1fa2c8965b': 'two dogs play with bottle',
#  '2693425189_47740c22ed': 'little boy wearing blue shorts is holding yellow noodle over pool',
#  '1019604187_d087bf9a5f': 'white dog running after yellow ball',
#  '510531976_90bbee22a2': 'the break dancer is wearing white shirt and grey pants',
#  '3404870997_7b0cd755de': 'people are watching boy on skateboard at the top of skate ramp',
#  '2918653119_f535fc25c4': 'rollerblader in green shirt and hat slides down green handrail next to steps',
#  '2521770311_3086ca90de': 'young boy with samll cardboard box atop his head',
#  '525538142_7348f0bce7': 'two young boys are wrestling in sand pit',
#  '310260324_7f941814bc': 'several men in front of white building',
#  '3682428916_69ce66d375': 'small plane with spinning propeller on ground pilot seen through windows',
#  '3564312955_716e86c48b': 'little girl in swimsuit lies on stomach in water smiles at camera',
#  '3622929632_26fb800000': 'the dog has ball in its mouth',
#  '2801851082_8c3c480c0f': 'young blond boy with long hair with large innertube drapped around his body',
#  '3442138291_3e75f4bdb8': 'the young child in the black shirt and jeans ran down the path',
#  '3052196390_c59dd24ca8': 'several girls in swimsuits are playing in sprinkler fountain',
#  '571130875_30051ac02d': 'six women wearing matchin pink dresses in front of crowd',
#  '2518853257_02f30e282e': 'two women on green chairs are looking at book',
#  '3272002857_ace031f564': 'person on horse on the beach',
#  '3560977956_e08d2cd531': 'two people wear life jackets in rowboat',
#  '2439384468_58934deab6': 'two large black dogs one with ball in its mouth are running through tall grass',
#  '468608014_09fd20eb9b': 'two dogs fighting for the same chew toy',
#  '2337377811_8c81b40a64': 'little girl in blue coat and pink hat makes tracks in the snow',
#  '2827964381_408a310809': 'two dogs wrestle in the grass with chain link fence in the background',
#  '72218201_e0e9c7d65b': 'the young runners are racing through the snow',
#  '3564907603_14ccc655f1': 'yound people make goofy faces for the camera',
#  '2423550887_ffc9bbcf71': 'man in red jacket standing in front of lighthouse',
#  '3229282764_a4a515f4e2': 'man and child playing on the beach',
#  '247704641_d883902277': 'the dog walks across the stream on fallen log',
#  '3549464203_8ab9c6160b': 'the girl is at the park playing on the jungle gym',
#  '3606093421_eddd46c2c7': 'two men ride an orange raft to shore',
#  '3356369156_074750c6cc': 'the solitude boat floats on the lake',
#  '2268109835_d6edbe1c2b': 'person uses longhandled net to catch something in the air',
#  '2172493537_128bc8b187': 'three people are wading in shallow water near stone path and spraying fountains',
#  '2655196158_5c878a4af0': 'the gray blue eyed hound puppy is laying on blue carpet chewing on toy',
#  '2623496164_68ffeb5067': 'the person on the bicycle is wearing red',
#  '2269795781_46a296aa21': 'miami tennis player hits the ball with forehand',
#  '275401000_8829250eb3': 'two fluffy dogs jumping to catch tennis ball',
#  '3108378861_d2214d971e': 'woman standing next to man who is sitting on rock',
#  '1160441615_fe6b3c5277': 'three women walk through plant covered atrium hallway',
#  '1689658980_0074d81d28': 'two dogs run out of the ocean lake',
#  '2966552760_e65b22cd26': 'little girl sitting down eating ice cream',
#  '3304556387_203b9d4db0': 'the man is playing in the yard with two dogs',
#  '3150380412_7021e5444a': 'wet blonde dog running through water',
#  '2788945468_74a9618cfa': 'pictures on white brick wall with smiling man standing in front of the wall',
#  '1659358133_95cd1027bd': 'the dog is standing outside on tree stump',
#  '3619630328_2d0865b6f4': 'large brown dog jumps over red hurdle',
#  '3156406419_38fbd52007': 'skier is falling down snowy mountain',
#  '2896483502_6f807bae9e': 'the dog jumps to catch flying disc',
#  '3537520829_aab733e16c': 'skateboarder riding rail',
#  '246231741_882b45c4e1': 'two german sheppard dogs are fighting',
#  '2473738924_eca928d12f': 'two young girls sparring in white martial arts outfits while third person watches from the side',
#  '3185645793_49de805194': 'one person jumping his bike towards the camera while another one in the background is walking his bike away from the camera',
#  '2714699748_c9270dd5aa': 'two dogs wrestle',
#  '3183060123_ea3af6278b': 'the helmeted man rides green kawasaki',
#  '3410902181_b2a3c6eec9': 'girl is performing onstage with hula hoop surrounded by many balloons',
#  '2662816021_ac474e0fde': 'the white dog is standing in the water with stick in its mouth',
#  '765298136_7805fbb079': 'the man in red is propelling down the waterfall',
#  '3154813159_58a195236d': 'the brown and white dog is standing up on its hind legs',
#  '2216695423_1362cb25f3': 'the dogs are playing with stick outside',
#  '2374570771_c395fc224a': 'dog runs through the water',
#  '3552796830_2dd2aa9c2c': 'two soldiers are running down track',
#  '1287073593_f3d2a62455': 'the man is mushing his dogs on snow trail',
#  '496971341_22782195f0': 'two dogs playing with blue and green ball',
#  '2875528143_94d9480fdd': 'the girl in pink does midair leg splits',
#  '2426781076_e3f4d2685c': 'the boy is coming down the amusement slide on his knees',
#  '3394654132_9a8659605c': 'woman holding dog on street',
#  '3102363657_dc95fe6850': 'small boy hugged by person in bee costume blurry urban background',
#  '373394550_1b2296b8c4': 'small boy sleeping on seats and sucking his thumb',
#  '3595408539_a7d8aabc24': 'three young people drink beer at an outdoor party',
#  '3134387321_3a253224c1': 'two women and man pose for the camera',
#  '241347760_d44c8d3a01': 'the american footballer is wearing red and white strip',
#  '3517040752_debec03376': 'two girls are playing softball',
#  '2892995070_39f3c9a56e': 'two dogs are playing together',
#  '3546027589_253553252a': 'the children are talking and playing in the street',
#  '3569284680_44fef444ef': 'two young kids walk up some stairs',
#  '2788652511_4f10060e07': 'the child is on boogie board with waves splashing around',
#  '3452411712_5b42d2a1b5': 'the boy is pushing girl on swing outside',
#  '3198237818_cb5eb302f0': 'muscular man in speedo and curvy blond in bikini walk together at the beach',
#  '2865703567_52de2444f2': 'young man jumps from one balcony to another',
#  '2451285022_59255e7fd9': 'the man wearing tan hat and white shirt holds his brown dog which is wearing an orange collar',
#  '3450874870_c4dcf58fb3': 'two people wearing skis on chairlift',
#  '3490736665_38710f4b91': 'dog stands on his hind legs amid shower of tennis balls',
#  '2496236371_61dec88113': 'the red motorcycle pulls wheelie on the racetrack',
#  '2493974889_50ae29f1e1': 'two kids are walking on path in the woods',
#  '2819254573_9ecb5f4d5e': 'the blonde boy is riding rollercoaster with his mouth wide open',
#  '3649387275_75295baa28': 'the white dog with brown spots is walking through shallow water',
#  '3545427060_c16a8b7dfd': 'three indian children playing in water',
#  '3706356018_28f62290e8': 'little kids are on an amusement park ride',
#  '2060031241_a3ae7a06bb': 'baby sitting on floor and holding game controller over its head',
#  '2710416789_555180e399': 'there is child with glasses and tan skin staring at the camera',
#  '2275029674_6d4891c20e': 'two white puppies play near pool',
#  '225909073_25c3c33a29': 'the german shepherd is walking in the body of water',
#  '3424927725_c4d1fcfac3': 'person sitting on the edge of rock outcropping looking down',
#  '3648081498_76ec091495': 'the skateboarder rides the pipe wall at skater park',
#  '2839807428_efe42423f2': 'dog jumping high in the air to catch frisbee',
#  '2324917982_f3db8c11e9': 'toddler on hardwood floor playing with toys',
#  '241031670_e60f59b8e4': 'three girls take cover under their umbrellas',
#  '3689355450_fd559b816d': 'the person wearing flannel shorts is jumping over fountain',
#  '2495394666_2ef6c37519': 'the brown dog is swimming in the water',
#  '2561849813_ff9caa52ac': 'the baby sits on the sandy beach',
#  '1784309115_0ad6791146': 'woman in pink bikini next to man in brown',
#  '406901451_7eafd7568a': 'tan and black dog opens its mouth for red ball',
#  '1211015912_9f3ee3a995': 'children at park',
#  '3256456935_664a7a5bba': 'the girl with the red belt is kicking pad that the person in black is holding',
#  '3659686168_49c3abcee1': 'two young women sit by fountain',
#  '2187503678_fd743e0a00': 'white dog running away from the orange colored house',
#  '2915538325_59e11276dd': 'the crowd is watching the fiery explosion',
#  '2148991939_3b9fd6c439': 'the black dog leaps off the dock and into the water',
#  '1253264731_e7c689eca5': 'two girls one in overalls holding on to fence with water behind them',
#  '2971298546_dd595cf297': 'runner is running past an outdoor flower stall',
#  '2242178517_2325b85e5f': 'young child shovels snow',
# 3490736665_38710f4b91 dog stands on his hind legs amid shower of tennis balls
# 2496236371_61dec88113 the red motorcycle pulls wheelie on the racetrack
# 2493974889_50ae29f1e1 two kids are walking on path in the woods
# 2819254573_9ecb5f4d5e the blonde boy is riding rollercoaster with his mouth wide open
# 3649387275_75295baa28 the white dog with brown spots is walking through shallow water
# 3545427060_c16a8b7dfd three indian children playing in water
# 3706356018_28f62290e8 little kids are on an amusement park ride
# 2060031241_a3ae7a06bb baby sitting on floor and holding game controller over its head
# 2710416789_555180e399 there is child with glasses and tan skin staring at the camera
# 2275029674_6d4891c20e two white puppies play near pool
# 225909073_25c3c33a29 the german shepherd is walking in the body of water
# 3424927725_c4d1fcfac3 person sitting on the edge of rock outcropping looking down
# 3648081498_76ec091495 the skateboarder rides the pipe wall at skater park
# 2839807428_efe42423f2 dog jumping high in the air to catch frisbee
# 2324917982_f3db8c11e9 toddler on hardwood floor playing with toys
# 241031670_e60f59b8e4 three girls take cover under their umbrellas
# 3689355450_fd559b816d the person wearing flannel shorts is jumping over fountain
# 2495394666_2ef6c37519 the brown dog is swimming in the water
# 2561849813_ff9caa52ac the baby sits on the sandy beach
# 1784309115_0ad6791146 woman in pink bikini next to man in brown
# 406901451_7eafd7568a tan and black dog opens its mouth for red ball
# 1211015912_9f3ee3a995 children at park
# 3256456935_664a7a5bba the girl with the red belt is kicking pad that the person in black is holding
# 3659686168_49c3abcee1 two young women sit by fountain
# 2187503678_fd743e0a00 white dog running away from the orange colored house
# 2915538325_59e11276dd the crowd is watching the fiery explosion
# 2148991939_3b9fd6c439 the black dog leaps off the dock and into the water
# 1253264731_e7c689eca5 two girls one in overalls holding on to fence with water behind them
# 2971298546_dd595cf297 runner is running past an outdoor flower stall
# 2242178517_2325b85e5f young child shovels snow
# 3497238310_2abde3965d some young men playing basketball
# 3119887967_271a097464 the man in the black hat stands behind the man who is pointing his finger

# %%
desc_list
# Out:
# ['3242718240_3358f2d6e6 the six children are laughing',
#  '1355450069_c0675b0706 there is rock climber holding on and climbing to the top of very large rock',
#  '724702877_f2a938766b small dog catches tennis ball in its mouth indoors',
#  '3067500667_0fce8f28d4 player hits the ball at cricket game',
#  '1452361926_6d8c535e32 the child sits in toy car and drinks from sippy cup',
#  '1525153022_06c48dbe52 the dog runs through the water',
#  '282960970_574aa1ba49 this person is sitting in saddle',
#  '119534510_d52b3781a3 person sitting on concrete landing next to body of water',
#  '241347460_81d5d62bf6 the football player in red kicks off the ball',
#  '3540416981_4e74f08cbb the white dog is running in the green grass',
#  '2333816000_7105d0ffac the man climbing the rock is wearing blue helmet',
#  '2533642917_a5eace85e6 little boy kneedeep in water',
#  '521658170_a837af87e9 three dogs trying to get stick from their owner',
#  '3537201804_ce07aff237 two kids sit in the middle of playground toy that spins around them',
#  '2170187328_65c2f11891 there is kid jumping off diving board into pool',
#  '2861100960_457ceda7fa the man is wearing straw hat and smoking cigarette',
#  '3498240367_cbd8c6efbf two young kids putting their heads in the bodies of king and queen',
#  '1288909046_d2b2b62607 dog takes leap of faith as he jumps into pool to grab an orange toy',
#  '3275704430_a75828048f the man with brown hair in the black sweater is covering his face with his hands',
#  '3315353266_70f0bbb1c3 man plays his guitar with the case open for donations',
#  '418667611_b9995000f4 waist down picture of surfer riding small wave',
#  '241347204_007d83e252 the red and white football team is talking with the officials',
#  '3204686006_88f04547b9 four people in various stage of sledding on snowy hill while dog playfully chases one of them',
#  '3016178284_ec50a09e8c boy in helmet riding his bike in marathon',
#  '3364796213_b8948913b5 people ride bikes and carry black flags along road where others are gathered',
#  '857914283_270d7d1c87 two little boys are playing together on the bed',
#  '3614542901_29877fc342 old lady with black dress and hat points out something to bride',
#  '2866696346_4dcccbd3a5 two men skateboards at high speed',
#  '2098646162_e3b3bbf14c two dogs are staring at grey and white cat',
#  '3256603992_67312b5a36 man standing in the midst of plants is giving two thumbs up',
#  '109738763_90541ef30d the man is up in the air',
#  '3546474710_903c3c9fd3 the gutarist upfront is under spotlight and the drummer in the back is under one too',
#  '544257613_d9a1fea3f7 strawberry haired guy flashes his blue eyes and big smile at the camera',
#  '2149982207_5345633bbf young boy riding in green boat',
#  '3321063116_4e5deeac83 three dogs running towards fence in the snow',
#  '2533414541_362bf043bb the blue and white car is in the road with onlookers nearby',
#  '3356938707_d95ba97430 two men wearing eyeglasses standing together',
#  '3215117062_6e07a86352 two people watch tv from over white ledge',
#  '3271385712_ffd34f2de5 two people looking at each other third person is not attentive',
#  '186890605_ddff5b694e there is man swinging off rope swing into lake',
#  '2268729848_d418451226 kids riding the subway',
#  '2053777548_108e54c826 the dog jumps to catch the ball',
#  '3461049169_e068ae4f25 young girl standing in front of fountain with woman to her side',
#  '2918880895_e61f74f2f0 two men each have one arm around each other and are in formal dresswear',
#  '1414820925_3504c394e1 guy in red shorts jumping up in front of volleyball net',
#  '2947452329_08f2d2a467 soccer player wipes face with blue jersey',
#  '2587846523_b177c9a3e3 the man is throwing tennis ball for the brown dog to fetch',
#  '400851260_5911898657 man walking through the deep snow at dusk',
#  '3176278670_195eea071c people standing at carnival game of balloons and stuffed animals on wall',
#  '2632381125_de32bdfdf6 two large dogs fighting over frisbee in the water',
#  '3051754615_3d6494c2ae rowers racing furiously',
#  '929679367_ff8c7df2ee whitefooted beagle plays with tennis ball on garden path',
#  '3529211822_1dabdb3a9c the brown dog eats from bowl on the wooden table as black dog jumps off',
#  '488196964_49159f11fd very wet dog coming toward the camera through mossy pond with ball',
#  '1244485675_822e6efe60 the young asian boy looks at his reflection in the park',
#  '2119302248_72493d458c the woman in glasses is wearing black headdress',
#  '3126225245_96cd2c053f young boy with blonde hair swipes at bubbles in the air',
#  '2750832671_4b39f06acf black dog playing with white and blue toy',
#  '3518443604_6da641f07d two people wearing jeans huddle near wooden door sheilding their faces from the camera',
#  '2900048238_74bd69d87d young man in blue shirt sits in front of group of blue and white umbrellas',
#  '3501206996_477be0f318 the young boy wearing brown coat is playing soccer',
#  '2766726291_b83eb5d315 young boy blows into hose while sitting on the deck',
#  '3525453732_f74a38f111 the bird has its wings spread as it flies',
#  '2410153942_ba4a136358 this offroading driver has tipped his truck',
#  '2465691083_894fc48af6 black and tan dog swimming toward shore of pond',
#  '1377668044_36398401dd the dog is jumping for the item the man is holding above his head',
#  '2539933563_17ff0758c7 woman standing with drink in her hand next to tent',
#  '3533145793_5d69f72e41 several young girls on colorful mats stretching upwards',
#  '2305437797_e6c3460190 the dog is fetching stick in water',
#  '3712742641_641282803e the black and white dog is swimming in the river',
#  '2313230479_13f87c6bf3 two dogs are running together through the grass',
#  '3584196366_a4b43d6644 group of white birds take flight while one black bird stands on the sand',
#  '2661294481_b86058b504 many people hold signs and march down the street',
#  '241046599_28b0ca7b9f the dog is wearing purple cape',
#  '2273038287_3004a72a34 black dog running with his tongue out',
#  '2242863004_3a9f82a31f german sheppard dog bting large red ball',
#  '3522349685_f046f0e250 young girl in ponytail pets furry cat',
#  '1482960952_95f2d419cb three old ladies walking and carrying purses',
#  '2732625904_4fbb653434 girl wearing pink rides yellow bike near white fence',
#  '1115679311_245eff2f4b an animal is running on the beach',
#  '3497502407_ec566442c9 woman stands on circular ledge surrounding tall tree',
#  '2078311270_f01c9eaf4c two women walking near some trees in warm darkcolored garments one with hat one with an upraised collar',
#  '3143980056_7a64a94b58 the baby pinches the woman cheek',
#  '3033612929_764d977bd5 two dogs walking with their toys',
#  '1468103286_96a6e07029 new york yankee warming up',
#  '3367053761_8ec5834bf3 two people are sitting at desks by the windows in library',
#  '3585487286_ef9a8d4c56 two white dogs are running and jumping along beach with the ocean behind them',
#  '2564888404_b57f89d3c7 two dogs running side by side in water',
#  '2749124446_d4432787b5 two horses are neck to neck at race',
#  '1337792872_d01a390b33 the little girl is wearing denim dress and holding brown teddy bear',
#  '2684489465_32ba1d0344 the white dog is leaping over red and green fence on an obstacle course',
#  '359173181_a75c950aeb the brown furry animal is walking in the snowy grass with tree behind him',
#  '3648988742_888a16f600 young girl in pink hat taking pictures',
#  '3211210739_3dea005fde the gymnast does flip over the bar',
#  '3028404926_2bd27e3e83 young boy turning crank in the street',
#  '3418504074_083f0bb68d the little black and white dog is in the snow whit red ball',
#  '3730457171_e66dde8c91 little girl riding her toy on the sidewalk',
#  '278002800_3817135105 man in black is eating baked good near two elderly men',
#  '3567061016_62768dcce1 hawk is flying trailing lines from its legs',
#  '384465370_9918873f9a two people riding their bikes on hill',
#  '1827560917_c8d3c5627f small black and white dog in harness is looking at the camera',
#  '1517807181_ca6588f2a0 two young girls run across field as they fly kite in the cloudcovered sky',
#  '3520321387_710ab74cda mother and son grin for the camera',
#  '1499495021_d295ce577c man and woman fishing in the ocean',
#  '2396100671_3a9d67f03d young boy sits on his bike wearing dragon costume',
#  '2461616306_3ee7ac1b4b the young boy is jumping into the pool on his belly',
#  '3431860810_44277cd360 wooly dog on beach looks toward another dog in the water',
#  '2225241766_f1e7132e3e man laying on platform outside on some rocks',
#  '3262075846_5695021d84 men play rugby',
#  '2369840118_a1c4240ab7 young boy dressed in green holds baby goat in arms',
#  '2319808437_bbbdc317c0 two boys watch third boy kicking some snow',
#  '536721406_884ab8fece the dog barks madly at the bull in the pen',
#  '519059913_4906fe4050 young boy jumping upsidedown into pool',
#  '2258662398_2797d0eca8 young surfer rides wave',
#  '2647229826_e0e0c65ef1 six children near water fountain',
#  '965444691_fe7e85bf0e the man is holding baby near carnival game',
#  '2893374123_087f98d58a motorcyclist rides down ramp held up by colorful barrels',
#  '823697339_aadbeef495 two women one with red hair stand outside store',
#  '263850317_5bb3a18a08 girl wearing mini dress and long sleve white jacket with pink bag walking through crowded area',
#  '3439331800_e71e1d808f four young men dance onstage',
#  '3326588088_172d1b2584 two men wearing white suits play guitar onstage',
#  '2461631708_decc5b8c87 young boys in orange life vests sit on raft',
#  '1174525839_7c1e6cfa86 the girls is jumping into the air on the beach',
#  '3239021459_a6b71bb400 the young man is flying through the air on his green snowboard',
#  '3168841415_c0705a327a the little kid runs to grab the blue frisbee that is flying through the air',
#  '419116771_642800891d three dogs look on as two dogs attack third dog in the streets',
#  '746787916_ceb103069f small show dog just ran through an orange flexible tube',
#  '1975171469_84e425f61b young child plays an arcade game',
#  '2701603045_6cbdc4ce7c the boy is wading through the blue ocean',
#  '3217187564_0ffd89dec1 three race dogs run to finish race',
#  '3718007650_e5930b4509 the back of woman in costume little girl looks at her',
#  '1332823164_c70a5d930e woman standing on the shore of beach',
#  '2380740486_8cd5d4601a girl with two ducks on cliff overlooking the water',
#  '2193980605_4221c6474d six people jump for ball',
#  '2321466753_5606a10721 young child is holding onto the back of wicker chair',
#  '3225226381_9fe306fb9e two dogs running one brown and one grey',
#  '3613424631_3ae537624f man with bike sitting next to rubble',
#  '2992808092_5f677085b7 two teenagers participate in game of field hockey',
#  '1819261140_6c022f4b1d person at table dressed in black costume',
#  '3383037991_8f07784b81 the large brown dog sat on the bed surronded by wrapping paper',
#  '288025239_5e59ba9c3b the hiker pokes out of her tent to find that snow is everywhere',
#  '3518755601_cebf11e515 three young women wearing wetsuits on beach two gesturing at camera',
#  '3409947123_a8d07edecf the people are standing around at carnival',
#  '2572101672_4d699c8713 the man is standing next to bird cage',
#  '3105315670_5f86f73753 the woman is wearing brown hat and black coat and is on sidewalk',
#  '479807465_cf42f39d00 young dirt bikers try to get dirt bike up sandy hill',
#  '3561433412_3985208d53 wolflike dog chasing white wiffle ball through green field',
#  '2449289139_08fc1092c1 the dog runs in the park',
#  '3295671644_0e10891b6d the little dog with big ears is in the field',
#  '124195430_d14028660f thin brown horse standing and small black horse sitting on sand',
#  '2258951972_92763fddab two large gray dogs running through grassy field',
#  '2500567791_101d5ddee3 dog chasing brown cow and black cow',
#  '3203908917_53e53c03d1 the man is wearing red shirt and red flannel handkerchief while watching flag burn',
#  '2229509318_be3fef006b woman is standing in front of dog that standing on its hind legs',
#  '252578659_9e404b6430 three sheep graze on the grassy field with dog walking behind them',
#  '2832978253_8fcc72da3b person wearing red and white climbs foggy mountain',
#  '1082252566_8c79beef93 three dogs of various sizes',
#  '3148647065_2d6cd88cf6 pale brown dog runs in blurred rural scene',
#  '3710674892_857b8056f7 child with green apple in his mouth is wearing red life jacket',
#  '3561537309_e271d57492 the young boy opens his arms as waves come crashing near him',
#  '2991771557_d98fa0a69f snowboarder wearing green hat is riding along metal railing',
#  '3454355269_6185e29f95 man in safety gear riding bike on rocky trail',
#  '2423085253_6c19149855 the girl is running on the grass next to colorful toy',
#  '3483140026_e14f64fdf5 smiling construction worker with white helmet',
#  '387830531_e89c192b92 two dogs playing with each other',
#  '3533451027_b078e4631b the man in the black and white shirt is running with ball',
#  '3726168984_1fa2c8965b two dogs play with bottle',
#  '2693425189_47740c22ed little boy wearing blue shorts is holding yellow noodle over pool',
#  '1019604187_d087bf9a5f white dog running after yellow ball',
#  '510531976_90bbee22a2 the break dancer is wearing white shirt and grey pants',
#  '3404870997_7b0cd755de people are watching boy on skateboard at the top of skate ramp',
#  '2918653119_f535fc25c4 rollerblader in green shirt and hat slides down green handrail next to steps',
#  '2521770311_3086ca90de young boy with samll cardboard box atop his head',
#  '525538142_7348f0bce7 two young boys are wrestling in sand pit',
#  '310260324_7f941814bc several men in front of white building',
#  '3682428916_69ce66d375 small plane with spinning propeller on ground pilot seen through windows',
#  '3564312955_716e86c48b little girl in swimsuit lies on stomach in water smiles at camera',
#  '3622929632_26fb800000 the dog has ball in its mouth',
#  '2801851082_8c3c480c0f young blond boy with long hair with large innertube drapped around his body',
#  '3442138291_3e75f4bdb8 the young child in the black shirt and jeans ran down the path',
#  '3052196390_c59dd24ca8 several girls in swimsuits are playing in sprinkler fountain',
#  '571130875_30051ac02d six women wearing matchin pink dresses in front of crowd',
#  '2518853257_02f30e282e two women on green chairs are looking at book',
#  '3272002857_ace031f564 person on horse on the beach',
#  '3560977956_e08d2cd531 two people wear life jackets in rowboat',
#  '2439384468_58934deab6 two large black dogs one with ball in its mouth are running through tall grass',
#  '468608014_09fd20eb9b two dogs fighting for the same chew toy',
#  '2337377811_8c81b40a64 little girl in blue coat and pink hat makes tracks in the snow',
#  '2827964381_408a310809 two dogs wrestle in the grass with chain link fence in the background',
#  '72218201_e0e9c7d65b the young runners are racing through the snow',
#  '3564907603_14ccc655f1 yound people make goofy faces for the camera',
#  '2423550887_ffc9bbcf71 man in red jacket standing in front of lighthouse',
#  '3229282764_a4a515f4e2 man and child playing on the beach',
#  '247704641_d883902277 the dog walks across the stream on fallen log',
#  '3549464203_8ab9c6160b the girl is at the park playing on the jungle gym',
#  '3606093421_eddd46c2c7 two men ride an orange raft to shore',
#  '3356369156_074750c6cc the solitude boat floats on the lake',
#  '2268109835_d6edbe1c2b person uses longhandled net to catch something in the air',
#  '2172493537_128bc8b187 three people are wading in shallow water near stone path and spraying fountains',
#  '2655196158_5c878a4af0 the gray blue eyed hound puppy is laying on blue carpet chewing on toy',
#  '2623496164_68ffeb5067 the person on the bicycle is wearing red',
#  '2269795781_46a296aa21 miami tennis player hits the ball with forehand',
#  '275401000_8829250eb3 two fluffy dogs jumping to catch tennis ball',
#  '3108378861_d2214d971e woman standing next to man who is sitting on rock',
#  '1160441615_fe6b3c5277 three women walk through plant covered atrium hallway',
#  '1689658980_0074d81d28 two dogs run out of the ocean lake',
#  '2966552760_e65b22cd26 little girl sitting down eating ice cream',
#  '3304556387_203b9d4db0 the man is playing in the yard with two dogs',
#  '3150380412_7021e5444a wet blonde dog running through water',
#  '2788945468_74a9618cfa pictures on white brick wall with smiling man standing in front of the wall',
#  '1659358133_95cd1027bd the dog is standing outside on tree stump',
#  '3619630328_2d0865b6f4 large brown dog jumps over red hurdle',
#  '3156406419_38fbd52007 skier is falling down snowy mountain',
#  '2896483502_6f807bae9e the dog jumps to catch flying disc',
#  '3537520829_aab733e16c skateboarder riding rail',
#  '246231741_882b45c4e1 two german sheppard dogs are fighting',
#  '2473738924_eca928d12f two young girls sparring in white martial arts outfits while third person watches from the side',
#  '3185645793_49de805194 one person jumping his bike towards the camera while another one in the background is walking his bike away from the camera',
#  '2714699748_c9270dd5aa two dogs wrestle',
#  '3183060123_ea3af6278b the helmeted man rides green kawasaki',
#  '3410902181_b2a3c6eec9 girl is performing onstage with hula hoop surrounded by many balloons',
#  '2662816021_ac474e0fde the white dog is standing in the water with stick in its mouth',
#  '765298136_7805fbb079 the man in red is propelling down the waterfall',
#  '3154813159_58a195236d the brown and white dog is standing up on its hind legs',
#  '2216695423_1362cb25f3 the dogs are playing with stick outside',
#  '2374570771_c395fc224a dog runs through the water',
#  '3552796830_2dd2aa9c2c two soldiers are running down track',
#  '1287073593_f3d2a62455 the man is mushing his dogs on snow trail',
#  '496971341_22782195f0 two dogs playing with blue and green ball',
#  '2875528143_94d9480fdd the girl in pink does midair leg splits',
#  '2426781076_e3f4d2685c the boy is coming down the amusement slide on his knees',
#  '3394654132_9a8659605c woman holding dog on street',
#  '3102363657_dc95fe6850 small boy hugged by person in bee costume blurry urban background',
#  '373394550_1b2296b8c4 small boy sleeping on seats and sucking his thumb',
#  '3595408539_a7d8aabc24 three young people drink beer at an outdoor party',
#  '3134387321_3a253224c1 two women and man pose for the camera',
#  '241347760_d44c8d3a01 the american footballer is wearing red and white strip',
#  '3517040752_debec03376 two girls are playing softball',
#  '2892995070_39f3c9a56e two dogs are playing together',
#  '3546027589_253553252a the children are talking and playing in the street',
#  '3569284680_44fef444ef two young kids walk up some stairs',
#  '2788652511_4f10060e07 the child is on boogie board with waves splashing around',
#  '3452411712_5b42d2a1b5 the boy is pushing girl on swing outside',
#  '3198237818_cb5eb302f0 muscular man in speedo and curvy blond in bikini walk together at the beach',
#  '2865703567_52de2444f2 young man jumps from one balcony to another',
#  '2451285022_59255e7fd9 the man wearing tan hat and white shirt holds his brown dog which is wearing an orange collar',
#  '3450874870_c4dcf58fb3 two people wearing skis on chairlift',
#  '3490736665_38710f4b91 dog stands on his hind legs amid shower of tennis balls',
#  '2496236371_61dec88113 the red motorcycle pulls wheelie on the racetrack',
#  '2493974889_50ae29f1e1 two kids are walking on path in the woods',
#  '2819254573_9ecb5f4d5e the blonde boy is riding rollercoaster with his mouth wide open',
#  '3649387275_75295baa28 the white dog with brown spots is walking through shallow water',
#  '3545427060_c16a8b7dfd three indian children playing in water',
#  '3706356018_28f62290e8 little kids are on an amusement park ride',
#  '2060031241_a3ae7a06bb baby sitting on floor and holding game controller over its head',
#  '2710416789_555180e399 there is child with glasses and tan skin staring at the camera',
#  '2275029674_6d4891c20e two white puppies play near pool',
#  '225909073_25c3c33a29 the german shepherd is walking in the body of water',
#  '3424927725_c4d1fcfac3 person sitting on the edge of rock outcropping looking down',
#  '3648081498_76ec091495 the skateboarder rides the pipe wall at skater park',
#  '2839807428_efe42423f2 dog jumping high in the air to catch frisbee',
#  '2324917982_f3db8c11e9 toddler on hardwood floor playing with toys',
#  '241031670_e60f59b8e4 three girls take cover under their umbrellas',
#  '3689355450_fd559b816d the person wearing flannel shorts is jumping over fountain',
#  '2495394666_2ef6c37519 the brown dog is swimming in the water',
#  '2561849813_ff9caa52ac the baby sits on the sandy beach',
#  '1784309115_0ad6791146 woman in pink bikini next to man in brown',
#  '406901451_7eafd7568a tan and black dog opens its mouth for red ball',
#  '1211015912_9f3ee3a995 children at park',
#  '3256456935_664a7a5bba the girl with the red belt is kicking pad that the person in black is holding',
#  '3659686168_49c3abcee1 two young women sit by fountain',
#  '2187503678_fd743e0a00 white dog running away from the orange colored house',
#  '2915538325_59e11276dd the crowd is watching the fiery explosion',
#  '2148991939_3b9fd6c439 the black dog leaps off the dock and into the water',
#  '1253264731_e7c689eca5 two girls one in overalls holding on to fence with water behind them',
#  '2971298546_dd595cf297 runner is running past an outdoor flower stall',
#  '2242178517_2325b85e5f young child shovels snow',
#  '3497238310_2abde3965d some young men playing basketball',
#  '3119887967_271a097464 the man in the black hat stands behind the man who is pointing his finger']

# %%
# descriptions
# file_name = 'descriptions.txt'
images_list = train
doc = load_doc(file_name)

# %%
temp = doc[:100000-17]

# %%
del doc

# %%
# temp
'''
2495394666_2ef6c37519 dog swimming in body of water\n2495394666_2ef6c37519 the brown dog is swimming in the water\n
2561849813_ff9caa52ac baby sits on an empty beach under big blue sky\n2561849813_ff9caa52ac toddler sits on sandy beach\n
2561849813_ff9caa52ac baby sitting at beach\n2561849813_ff9caa52ac the baby sits on the sand in the front of the scene 
while the ocean is in the distance\n2561849813_ff9caa52ac the baby sits on the sandy beach\n1784309115_0ad6791146 girl 
in the bathing suit talking to guy\n1784309115_0ad6791146 woman in bikini is talking to regularly dressed man on bridge\n
'''

# %%
doc = temp
del temp

# %%
doc
# Out:
# '3242718240_3358f2d6e6 group of children dressed in costume pose for picture\n3242718240_3358f2d6e6 group of children stand against building and smile\n3242718240_3358f2d6e6 group of six children stands smiling and laughing in front of wall\n3242718240_3358f2d6e6 group of young children standing in row leaning against wall\n3242718240_3358f2d6e6 the six children are laughing\n1355450069_c0675b0706 man is climbing up wall\n1355450069_c0675b0706 man wearing no shirt climbs the side of large rock\n1355450069_c0675b0706 shirtless man climbing up the rock wall with rope safety lines\n1355450069_c0675b0706 man without shirt is climbing rock\n1355450069_c0675b0706 there is rock climber holding on and climbing to the top of very large rock\n724702877_f2a938766b dog has jumped in the air to catch tennis ball\n724702877_f2a938766b small brown dog jumping up to catch tennis ball\n724702877_f2a938766b small brown dog jumps and catches tennis ball\n724702877_f2a938766b small dog jumping with ball in its mouth\n724702877_f2a938766b small dog catches tennis ball in its mouth indoors\n3067500667_0fce8f28d4 cricket batsman has been bowled out middle stump\n3067500667_0fce8f28d4 cricket player swings his bat but misses\n3067500667_0fce8f28d4 man is standing in front of some red sticks trying to hit ball\n3067500667_0fce8f28d4 man is swinging paddle at unique ball game\n3067500667_0fce8f28d4 player hits the ball at cricket game\n1452361926_6d8c535e32 boy sits in toy car while drinking from his sippy cup\n1452361926_6d8c535e32 toddler drinking from cup in toy car\n1452361926_6d8c535e32 toddler in red toy car drinks from juice cup\n1452361926_6d8c535e32 the boy sits in his toy car sipping from cup\n1452361926_6d8c535e32 the child sits in toy car and drinks from sippy cup\n1525153022_06c48dbe52 black dog is running through the shallow edge of large body of water\n1525153022_06c48dbe52 black dog is running through the water\n1525153022_06c48dbe52 black dog jumps high out of the water\n1525153022_06c48dbe52 black and tan dobbermen running through the ocean\n1525153022_06c48dbe52 the dog runs through the water\n282960970_574aa1ba49 person wearing jeans sits on top of horse saddle\n282960970_574aa1ba49 woman in jeans is sitting on the saddle of horse\n282960970_574aa1ba49 the girl is sitting on top of saddle\n282960970_574aa1ba49 the person is sitting on top of horse\n282960970_574aa1ba49 this person is sitting in saddle\n119534510_d52b3781a3 man in brown shirt sitting on dock and reading\n119534510_d52b3781a3 man is sitting next to the water reading\n119534510_d52b3781a3 man reading book on the dock near post\n119534510_d52b3781a3 person in brown jacket is sitting on pier by the water reading\n119534510_d52b3781a3 person sitting on concrete landing next to body of water\n241347460_81d5d62bf6 football player kicks the ball\n241347460_81d5d62bf6 an oklahoma football player attempts to kick the ball\n241347460_81d5d62bf6 player for the oklahoma sooners football team punts the ball during game\n241347460_81d5d62bf6 oklahoma university kicker kicking the football\n241347460_81d5d62bf6 the football player in red kicks off the ball\n3540416981_4e74f08cbb dog chases stuffed animal attached to string\n3540416981_4e74f08cbb white and black dog chases after decoyanimal on string\n3540416981_4e74f08cbb white dog is chasing stuffed animal being pulled on string\n3540416981_4e74f08cbb the white dog is chasing toy that is attached to string across the grass\n3540416981_4e74f08cbb the white dog is running in the green grass\n2333816000_7105d0ffac man climbing rock face\n2333816000_7105d0ffac man climbs up rock\n2333816000_7105d0ffac man wearing blue helmet is rock climbing\n2333816000_7105d0ffac rock climber scaling stone wall\n2333816000_7105d0ffac the man climbing the rock is wearing blue helmet\n2533642917_a5eace85e6 boy in bathing suit stands in water\n2533642917_a5eace85e6 little boy stands in creek on sunny day\n2533642917_a5eace85e6 toddler wearing colorful sh ...

# %%
descriptions = dict()
count = 0
for line in doc.split('\n'):
#     if count == 20:
#         break
#     print(line)
    tokens = line.split()
#     print(tokens)
    
    image_id, image_description = tokens[0],tokens[1:]
#     print(image_id)
#     print(image_description)
    count += 1
    descriptions[image_id] = image_description
#     for image_id in images_list:
#         if image_id not in descriptions:
#             descriptions[image_id] = list()
#         # break sentences by the dot and add ssss and eeee and join them
#         desc = 'ssss ' + ' '.join(image_description) + ' eeee'
#         descriptions[image_id].append(desc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-c2f0461751e7> in <module>()
#       8 #     print(tokens)
#       9
# ---> 10     image_id, image_description = tokens[0],tokens[1:]
#      11 #     print(image_id)
#      12 #     print(image_description)
#
# IndexError: list index out of range

# %%
collect_keys = []
for key in descriptions.keys():
    collect_keys.append(key)

# %%
len(collect_keys),count
# Out:
# (279, 1393)

# %%
>>> keylist = data[0].keys()
>>> mydata = dict((k,', '.join(set(map(lambda d: d[k], data)))) for k in keylist)

# %%
key_list = descriptions.keys()
dict((key,', '.join((map(lambda d: d['key'], descriptions)))) for key in key_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-d0d903c0f6a5> in <module>()
#       1 key_list = descriptions.keys()
# ----> 2 dict((key,', '.join((map(lambda d: d['key'], descriptions)))) for key in key_list)
#
# <ipython-input-50-d0d903c0f6a5> in <genexpr>(.0)
#       1 key_list = descriptions.keys()
# ----> 2 dict((key,', '.join((map(lambda d: d['key'], descriptions)))) for key in key_list)
#
# <ipython-input-50-d0d903c0f6a5> in <lambda>(d)
#       1 key_list = descriptions.keys()
# ----> 2 dict((key,', '.join((map(lambda d: d['key'], descriptions)))) for key in key_list)
#
# TypeError: string indices must be integers

# %%
count = 0
new_description = dict()
for key,value in descriptions.items():
    print(key,' '.join(value))
    new_description[key] = ' '.join(value)
    count += 1
# Out:
# 3242718240_3358f2d6e6 the six children are laughing
# 1355450069_c0675b0706 there is rock climber holding on and climbing to the top of very large rock
# 724702877_f2a938766b small dog catches tennis ball in its mouth indoors
# 3067500667_0fce8f28d4 player hits the ball at cricket game
# 1452361926_6d8c535e32 the child sits in toy car and drinks from sippy cup
# 1525153022_06c48dbe52 the dog runs through the water
# 282960970_574aa1ba49 this person is sitting in saddle
# 119534510_d52b3781a3 person sitting on concrete landing next to body of water
# 241347460_81d5d62bf6 the football player in red kicks off the ball
# 3540416981_4e74f08cbb the white dog is running in the green grass
# 2333816000_7105d0ffac the man climbing the rock is wearing blue helmet
# 2533642917_a5eace85e6 little boy kneedeep in water
# 521658170_a837af87e9 three dogs trying to get stick from their owner
# 3537201804_ce07aff237 two kids sit in the middle of playground toy that spins around them
# 2170187328_65c2f11891 there is kid jumping off diving board into pool
# 2861100960_457ceda7fa the man is wearing straw hat and smoking cigarette
# 3498240367_cbd8c6efbf two young kids putting their heads in the bodies of king and queen
# 1288909046_d2b2b62607 dog takes leap of faith as he jumps into pool to grab an orange toy
# 3275704430_a75828048f the man with brown hair in the black sweater is covering his face with his hands
# 3315353266_70f0bbb1c3 man plays his guitar with the case open for donations
# 418667611_b9995000f4 waist down picture of surfer riding small wave
# 241347204_007d83e252 the red and white football team is talking with the officials
# 3204686006_88f04547b9 four people in various stage of sledding on snowy hill while dog playfully chases one of them
# 3016178284_ec50a09e8c boy in helmet riding his bike in marathon
# 3364796213_b8948913b5 people ride bikes and carry black flags along road where others are gathered
# 857914283_270d7d1c87 two little boys are playing together on the bed
# 3614542901_29877fc342 old lady with black dress and hat points out something to bride
# 2866696346_4dcccbd3a5 two men skateboards at high speed
# 2098646162_e3b3bbf14c two dogs are staring at grey and white cat
# Out:
# 279

# %%
np.unique(np.asarray(list(new_description.keys()))).shape
# Out:
# (279,)

# %%
# key_list
'''ict_keys(['3242718240_3358f2d6e6', '1355450069_c0675b0706', '724702877_f2a938766b', '3067500667_0fce8f28d4', '1452361926_6d8c535e32', '1525153022_06c48dbe52', '282960970_574aa1ba49', '119534510_d52b3781a3', '241347460_81d5d62bf6', '3540416981_4e74f08cbb', '2333816000_7105d0ffac', '2533642917_a5eace85e6', '521658170_a837af87e9', '3537201804_ce07aff237', '2170187328_65c2f11891', '2861100960_457ceda7fa', '3498240367_cbd8c6efbf', '1288909046_d2b2b62607', '3275704430_a75828048f', '3315353266_70f0bbb1c3', '418667611_b9995000f4', '241347204_007d83e252', '3204686006_88f04547b9', '3016178284_ec50a09e8c', '3364796213_b8948913b5', '857914283_270d7d1c87', '3614542901_29877fc342', '2866696346_4dcccbd3a5', '2098646162_e3b3bbf14c', '3256603992_67312b5a36', '109738763_90541ef30d', '3546474710_903c3c9fd3', '544257613_d9a1fea3f7', '2149982207_5345633bbf', '3321063116_4e5deeac83', '2533414541_362bf043bb', '3356938707_d95ba97430', '3215117062_6e07a86352', '3271385712_ffd34f2de5', '186890605_ddff5b694e', '2268729848_d418451226', '2053777548_108e54c826', '3461049169_e068ae4f25', '2918880895_e61f74f2f0','''

# %%
' '.join(descriptions['1355450069_c0675b0706'])
# Out:
# 'there is rock climber holding on and climbing to the top of very large rock'

# %%
new_desc = dict()
for key in collect_keys:
    add
    if key not in new_desc.keys():
        new_desc[key] = list()
    else:
        new_desc[key].append(add_desc)
# Out:
# {'3242718240_3358f2d6e6': ['the', 'six', 'children', 'are', 'laughing'],
#  '1355450069_c0675b0706': ['there',
#   'is',
#   'rock',
#   'climber',
#   'holding',
#   'on',
#   'and',
#   'climbing',
#   'to',
#   'the',
#   'top',
#   'of',
#   'very',
#   'large',
#   'rock'],
#  '724702877_f2a938766b': ['small',
#   'dog',
#   'catches',
#   'tennis',
#   'ball',
#   'in',
#   'its',
#   'mouth',
#   'indoors'],
#  '3067500667_0fce8f28d4': ['player',
#   'hits',
#   'the',
#   'ball',
#   'at',
#   'cricket',
#   'game'],
#  '1452361926_6d8c535e32': ['the',
#   'child',
#   'sits',
#   'in',
#   'toy',
#   'car',
#   'and',
#   'drinks',
#   'from',
#   'sippy',
#   'cup'],
#  '1525153022_06c48dbe52': ['the', 'dog', 'runs', 'through', 'the', 'water'],
#  '282960970_574aa1ba49': ['this', 'person', 'is', 'sitting', 'in', 'saddle'],
#  '119534510_d52b3781a3': ['person',
#   'sitting',
#   'on',
#   'concrete',
#   'landing',
#   'next',
#   'to',
#   'body',
#   'of',
#   'water'],
#  '241347460_81d5d62bf6': ['the',
#   'football',
#   'player',
#   'in',
#   'red',
#   'kicks',
#   'off',
#   'the',
#   'ball'],
#  '3540416981_4e74f08cbb': ['the',
#   'white',
#   'dog',
#   'is',
#   'running',
#   'in',
#   'the',
#   'green',
#   'grass'],
#  '2333816000_7105d0ffac': ['the',
#   'man',
#   'climbing',
#   'the',
#   'rock',
#   'is',
#   'wearing',
#   'blue',
#   'helmet'],
#  '2533642917_a5eace85e6': ['little', 'boy', 'kneedeep', 'in', 'water'],
#  '521658170_a837af87e9': ['three',
#   'dogs',
#   'trying',
#   'to',
#   'get',
#   'stick',
#   'from',
#   'their',
#   'owner'],
#  '3537201804_ce07aff237': ['two',
#   'kids',
#   'sit',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'playground',
#   'toy',
#   'that',
#   'spins',
#   'around',
#   'them'],
#  '2170187328_65c2f11891': ['there',
#   'is',
#   'kid',
#   'jumping',
#   'off',
#   'diving',
#   'board',
#   'into',
#   'pool'],
#  '2861100960_457ceda7fa': ['the',
#   'man',
#   'is',
#   'wearing',
#   'straw',
#   'hat',
#   'and',
#   'smoking',
#   'cigarette'],
#  '3498240367_cbd8c6efbf': ['two',
#   'young',
#   'kids',
#   'putting',
#   'their',
#   'heads',
#   'in',
#   'the',
#   'bodies',
#   'of',
#   'king',
#   'and',
#   'queen'],
#  '1288909046_d2b2b62607': ['dog',
#   'takes',
#   'leap',
#   'of',
#   'faith',
#   'as',
#   'he',
#   'jumps',
#   'into',
#   'pool',
#   'to',
#   'grab',
#   'an',
#   'orange',
#   'toy'],
#  '3275704430_a75828048f': ['the',
#   'man',
#   'with',
#   'brown',
#   'hair',
#   'in',
#   'the',
#   'black',
#   'sweater',
#   'is',
#   'covering',
#   'his',
#   'face',
#   'with',
#   'his',
#   'hands'],
#  '3315353266_70f0bbb1c3': ['man',
#   'plays',
#   'his',
#   'guitar',
#   'with',
#   'the',
#   'case',
#   'open',
#   'for',
#   'donations'],
#  '418667611_b9995000f4': ['waist',
#   'down',
#   'picture',
#   'of',
#   'surfer',
#   'riding',
#   'small',
#   'wave'],
#  '241347204_007d83e252': ['the',
#   'red',
#   'and',
#   'white',
#   'football',
#   'team',
#   'is',
#   'talking',
#   'with',
#   'the',
#   'officials'],
#  '3204686006_88f04547b9': ['four',
#   'people',
#   'in',
#   'various',
#   'stage',
#   'of',
#   'sledding',
#   'on',
#   'snowy',
#   'hill',
#   'while',
#   'dog',
#   'playfully',
#   'chases',
#   'one',
#   'of',
#   'them'],
#  '3016178284_ec50a09e8c': ['boy',
#   'in',
#   'helmet',
#   'riding',
#   'his',
#   'bike',
#   'in',
#   'marathon'],
#  '3364796213_b8948913b5': ['people',
#   'ride',
#   'bikes',
#   'and',
#   'carry',
#   'black',
#   'flags',
#   'along',
#   'road',
#   'where',
#   'others',
#   'are',
#   'gathered'],
#  '857914283_270d7d1c87': ['two',
#   'little',
#   'boys',
#   'are',
#   'playing',
#   'together',
#   'on',
#   'the',
#   'bed'],
#  '3614542901_29877fc342': ['old',
#   'lady',
#   'with',
#   'black',
#   'dress',
#   'and',
#   'hat',
#   'points',
#   'out',
#   'something',
#   'to',
#   'bride'],
#  '2866696346_4dcccbd3a5': ['two', 'men', 'skateboards', 'at', 'high', 'speed'],
#  '2098646162_e3b3bbf14c': ['two',
#   'dogs',
#   'are',
#   'staring',
#   'at',
#   'grey',
#   'and',
#   'white',
#   'cat'],
#  '3256603992_67312b5a36': ['man',
#   'standing',
#   'in',
#   'the',
#   'midst',
#   'of',
#   'plants',
#   'is',
#   'giving',
#   'two',
#   'thumbs',
#   'up'],
#  '109738763_90541ef30d': ['the', 'man', 'is', 'up', 'in', 'the', 'air'],
#  '3546474710_903c3c9fd3': ['the',
#   'gutarist',
#   'upfront',
#   'is',
#   'under',
#   'spotlight',
#   'and',
#   'the',
#   'drummer',
#   'in',
#   'the',
#   'back',
#   'is',
#   'under',
#   'one',
#   'too'],
#  '544257613_d9a1fea3f7': ['strawberry',
#   'haired',
#   'guy',
#   'flashes',
#   'his',
#   'blue',
#   'eyes',
#   'and',
#   'big',
#   'smile',
#   'at',
#   'the',
#   'camera'],
#  '2149982207_5345633bbf': ['young', 'boy', 'riding', 'in', 'green', 'boat'],
#  '3321063116_4e5deeac83': ['three',
#   'dogs',
#   'running',
#   'towards',
#   'fence',
#   'in',
#   'the',
#   'snow'],
#  '2533414541_362bf043bb': ['the',
#   'blue',
#   'and',
#   'white',
#   'car',
#   'is',
#   'in',
#   'the',
#   'road',
#   'with',
#   'onlookers',
#   'nearby'],
#  '3356938707_d95ba97430': ['two',
#   'men',
#   'wearing',
#   'eyeglasses',
#   'standing',
#   'together'],
#  '3215117062_6e07a86352': ['two',
#   'people',
#   'watch',
#   'tv',
#   'from',
#   'over',
#   'white',
#   'ledge'],
#  '3271385712_ffd34f2de5': ['two',
#   'people',
#   'looking',
#   'at',
#   'each',
#   'other',
#   'third',
#   'person',
#   'is',
#   'not',
#   'attentive'],
#  '186890605_ddff5b694e': ['there',
#   'is',
#   'man',
#   'swinging',
#   'off',
#   'rope',
#   'swing',
#   'into',
#   'lake'],
#  '2268729848_d418451226': ['kids', 'riding', 'the', 'subway'],
#  '2053777548_108e54c826': ['the',
#   'dog',
#   'jumps',
#   'to',
#   'catch',
#   'the',
#   'ball'],
#  '3461049169_e068ae4f25': ['young',
#   'girl',
#   'standing',
#   'in',
#   'front',
#   'of',
#   'fountain',
#   'with',
#   'woman',
#   'to',
#   'her',
#   'side'],
#  '2918880895_e61f74f2f0': ['two',
#   'men',
#   'each',
#   'have',
#   'one',
#   'arm',
#   'around',
#   'each',
#   'other',
#   'and',
#   'are',
#   'in',
#   'formal',
#   'dresswear'],
#  '1414820925_3504c394e1': ['guy',
#   'in',
#   'red',
#   'shorts',
#   'jumping',
#   'up',
#   'in',
#   'front',
#   'of',
#   'volleyball',
#   'net'],
#  '2947452329_08f2d2a467': ['soccer',
#   'player',
#   'wipes',
#   'face',
#   'with',
#   'blue',
#   'jersey'],
#  '2587846523_b177c9a3e3': ['the',
#   'man',
#   'is',
#   'throwing',
#   'tennis',
#   'ball',
#   'for',
#   'the',
#   'brown',
#   'dog',
#   'to',
#   'fetch'],
#  '400851260_5911898657': ['man',
#   'walking',
#   'through',
#   'the',
#   'deep',
#   'snow',
#   'at',
#   'dusk'],
#  '3176278670_195eea071c': ['people',
#   'standing',
#   'at',
#   'carnival',
#   'game',
#   'of',
#   'balloons',
#   'and',
#   'stuffed',
#   'animals',
#   'on',
#   'wall'],
#  '2632381125_de32bdfdf6': ['two',
#   'large',
#   'dogs',
#   'fighting',
#   'over',
#   'frisbee',
#   'in',
#   'the',
#   'water'],
#  '3051754615_3d6494c2ae': ['rowers', 'racing', 'furiously'],
#  '929679367_ff8c7df2ee': ['whitefooted',
#   'beagle',
#   'plays',
#   'with',
#   'tennis',
#   'ball',
#   'on',
#   'garden',
#   'path'],
#  '3529211822_1dabdb3a9c': ['the',
#   'brown',
#   'dog',
#   'eats',
#   'from',
#   'bowl',
#   'on',
#   'the',
#   'wooden',
#   'table',
#   'as',
#   'black',
#   'dog',
#   'jumps',
#   'off'],
#  '488196964_49159f11fd': ['very',
#   'wet',
#   'dog',
#   'coming',
#   'toward',
#   'the',
#   'camera',
#   'through',
#   'mossy',
#   'pond',
#   'with',
#   'ball'],
#  '1244485675_822e6efe60': ['the',
#   'young',
#   'asian',
#   'boy',
#   'looks',
#   'at',
#   'his',
#   'reflection',
#   'in',
#   'the',
#   'park'],
#  '2119302248_72493d458c': ['the',
#   'woman',
#   'in',
#   'glasses',
#   'is',
#   'wearing',
#   'black',
#   'headdress'],
#  '3126225245_96cd2c053f': ['young',
#   'boy',
#   'with',
#   'blonde',
#   'hair',
#   'swipes',
#   'at',
#   'bubbles',
#   'in',
#   'the',
#   'air'],
#  '2750832671_4b39f06acf': ['black',
#   'dog',
#   'playing',
#   'with',
#   'white',
#   'and',
#   'blue',
#   'toy'],
#  '3518443604_6da641f07d': ['two',
#   'people',
#   'wearing',
#   'jeans',
#   'huddle',
#   'near',
#   'wooden',
#   'door',
#   'sheilding',
#   'their',
#   'faces',
#   'from',
#   'the',
#   'camera'],
#  '2900048238_74bd69d87d': ['young',
#   'man',
#   'in',
#   'blue',
#   'shirt',
#   'sits',
#   'in',
#   'front',
#   'of',
#   'group',
#   'of',
#   'blue',
#   'and',
#   'white',
#   'umbrellas'],
#  '3501206996_477be0f318': ['the',
#   'young',
#   'boy',
#   'wearing',
#   'brown',
#   'coat',
#   'is',
#   'playing',
#   'soccer'],
#  '2766726291_b83eb5d315': ['young',
#   'boy',
#   'blows',
#   'into',
#   'hose',
#   'while',
#   'sitting',
#   'on',
#   'the',
#   'deck'],
#  '3525453732_f74a38f111': ['the',
#   'bird',
#   'has',
#   'its',
#   'wings',
#   'spread',
#   'as',
#   'it',
#   'flies'],
#  '2410153942_ba4a136358': ['this',
#   'offroading',
#   'driver',
#   'has',
#   'tipped',
#   'his',
#   'truck'],
#  '2465691083_894fc48af6': ['black',
#   'and',
#   'tan',
#   'dog',
#   'swimming',
#   'toward',
#   'shore',
#   'of',
#   'pond'],
#  '1377668044_36398401dd': ['the',
#   'dog',
#   'is',
#   'jumping',
#   'for',
#   'the',
#   'item',
#   'the',
#   'man',
#   'is',
#   'holding',
#   'above',
#   'his',
#   'head'],
#  '2539933563_17ff0758c7': ['woman',
#   'standing',
#   'with',
#   'drink',
#   'in',
#   'her',
#   'hand',
#   'next',
#   'to',
#   'tent'],
#  '3533145793_5d69f72e41': ['several',
#   'young',
#   'girls',
#   'on',
#   'colorful',
#   'mats',
#   'stretching',
#   'upwards'],
#  '2305437797_e6c3460190': ['the',
#   'dog',
#   'is',
#   'fetching',
#   'stick',
#   'in',
#   'water'],
#  '3712742641_641282803e': ['the',
#   'black',
#   'and',
#   'white',
#   'dog',
#   'is',
#   'swimming',
#   'in',
#   'the',
#   'river'],
#  '2313230479_13f87c6bf3': ['two',
#   'dogs',
#   'are',
#   'running',
#   'together',
#   'through',
#   'the',
#   'grass'],
#  '3584196366_a4b43d6644': ['group',
#   'of',
#   'white',
#   'birds',
#   'take',
#   'flight',
#   'while',
#   'one',
#   'black',
#   'bird',
#   'stands',
#   'on',
#   'the',
#   'sand'],
#  '2661294481_b86058b504': ['many',
#   'people',
#   'hold',
#   'signs',
#   'and',
#   'march',
#   'down',
#   'the',
#   'street'],
#  '241046599_28b0ca7b9f': ['the', 'dog', 'is', 'wearing', 'purple', 'cape'],
#  '2273038287_3004a72a34': ['black',
#   'dog',
#   'running',
#   'with',
#   'his',
#   'tongue',
#   'out'],
#  '2242863004_3a9f82a31f': ['german',
#   'sheppard',
#   'dog',
#   'bting',
#   'large',
#   'red',
#   'ball'],
#  '3522349685_f046f0e250': ['young',
#   'girl',
#   'in',
#   'ponytail',
#   'pets',
#   'furry',
#   'cat'],
#  '1482960952_95f2d419cb': ['three',
#   'old',
#   'ladies',
#   'walking',
#   'and',
#   'carrying',
#   'purses'],
#  '2732625904_4fbb653434': ['girl',
#   'wearing',
#   'pink',
#   'rides',
#   'yellow',
#   'bike',
#   'near',
#   'white',
#   'fence'],
#  '1115679311_245eff2f4b': ['an',
#   'animal',
#   'is',
#   'running',
#   'on',
#   'the',
#   'beach'],
#  '3497502407_ec566442c9': ['woman',
#   'stands',
#   'on',
#   'circular',
#   'ledge',
#   'surrounding',
#   'tall',
#   'tree'],
#  '2078311270_f01c9eaf4c': ['two',
#   'women',
#   'walking',
#   'near',
#   'some',
#   'trees',
#   'in',
#   'warm',
#   'darkcolored',
#   'garments',
#   'one',
#   'with',
#   'hat',
#   'one',
#   'with',
#   'an',
#   'upraised',
#   'collar'],
#  '3143980056_7a64a94b58': ['the', 'baby', 'pinches', 'the', 'woman', 'cheek'],
#  '3033612929_764d977bd5': ['two', 'dogs', 'walking', 'with', 'their', 'toys'],
#  '1468103286_96a6e07029': ['new', 'york', 'yankee', 'warming', 'up'],
#  '3367053761_8ec5834bf3': ['two',
#   'people',
#   'are',
#   'sitting',
#   'at',
#   'desks',
#   'by',
#   'the',
#   'windows',
#   'in',
#   'library'],
#  '3585487286_ef9a8d4c56': ['two',
#   'white',
#   'dogs',
#   'are',
#   'running',
#   'and',
#   'jumping',
#   'along',
#   'beach',
#   'with',
#   'the',
#   'ocean',
#   'behind',
#   'them'],
#  '2564888404_b57f89d3c7': ['two',
#   'dogs',
#   'running',
#   'side',
#   'by',
#   'side',
#   'in',
#   'water'],
#  '2749124446_d4432787b5': ['two',
#   'horses',
#   'are',
#   'neck',
#   'to',
#   'neck',
#   'at',
#   'race'],
#  '1337792872_d01a390b33': ['the',
#   'little',
#   'girl',
#   'is',
#   'wearing',
#   'denim',
#   'dress',
#   'and',
#   'holding',
#   'brown',
#   'teddy',
#   'bear'],
#  '2684489465_32ba1d0344': ['the',
#   'white',
#   'dog',
#   'is',
#   'leaping',
#   'over',
#   'red',
#   'and',
#   'green',
#   'fence',
#   'on',
#   'an',
#   'obstacle',
#   'course'],
#  '359173181_a75c950aeb': ['the',
#   'brown',
#   'furry',
#   'animal',
#   'is',
#   'walking',
#   'in',
#   'the',
#   'snowy',
#   'grass',
#   'with',
#   'tree',
#   'behind',
#   'him'],
#  '3648988742_888a16f600': ['young',
#   'girl',
#   'in',
#   'pink',
#   'hat',
#   'taking',
#   'pictures'],
#  '3211210739_3dea005fde': ['the',
#   'gymnast',
#   'does',
#   'flip',
#   'over',
#   'the',
#   'bar'],
#  '3028404926_2bd27e3e83': ['young',
#   'boy',
#   'turning',
#   'crank',
#   'in',
#   'the',
#   'street'],
#  '3418504074_083f0bb68d': ['the',
#   'little',
#   'black',
#   'and',
#   'white',
#   'dog',
#   'is',
#   'in',
#   'the',
#   'snow',
#   'whit',
#   'red',
#   'ball'],
#  '3730457171_e66dde8c91': ['little',
#   'girl',
#   'riding',
#   'her',
#   'toy',
#   'on',
#   'the',
#   'sidewalk'],
#  '278002800_3817135105': ['man',
#   'in',
#   'black',
#   'is',
#   'eating',
#   'baked',
#   'good',
#   'near',
#   'two',
#   'elderly',
#   'men'],
#  '3567061016_62768dcce1': ['hawk',
#   'is',
#   'flying',
#   'trailing',
#   'lines',
#   'from',
#   'its',
#   'legs'],
#  '384465370_9918873f9a': ['two',
#   'people',
#   'riding',
#   'their',
#   'bikes',
#   'on',
#   'hill'],
#  '1827560917_c8d3c5627f': ['small',
#   'black',
#   'and',
#   'white',
#   'dog',
#   'in',
#   'harness',
#   'is',
#   'looking',
#   'at',
#   'the',
#   'camera'],
#  '1517807181_ca6588f2a0': ['two',
#   'young',
#   'girls',
#   'run',
#   'across',
#   'field',
#   'as',
#   'they',
#   'fly',
#   'kite',
#   'in',
#   'the',
#   'cloudcovered',
#   'sky'],
#  '3520321387_710ab74cda': ['mother',
#   'and',
#   'son',
#   'grin',
#   'for',
#   'the',
#   'camera'],
#  '1499495021_d295ce577c': ['man',
#   'and',
#   'woman',
#   'fishing',
#   'in',
#   'the',
#   'ocean'],
#  '2396100671_3a9d67f03d': ['young',
#   'boy',
#   'sits',
#   'on',
#   'his',
#   'bike',
#   'wearing',
#   'dragon',
#   'costume'],
#  '2461616306_3ee7ac1b4b': ['the',
#   'young',
#   'boy',
#   'is',
#   'jumping',
#   'into',
#   'the',
#   'pool',
#   'on',
#   'his',
#   'belly'],
#  '3431860810_44277cd360': ['wooly',
#   'dog',
#   'on',
#   'beach',
#   'looks',
#   'toward',
#   'another',
#   'dog',
#   'in',
#   'the',
#   'water'],
#  '2225241766_f1e7132e3e': ['man',
#   'laying',
#   'on',
#   'platform',
#   'outside',
#   'on',
#   'some',
#   'rocks'],
#  '3262075846_5695021d84': ['men', 'play', 'rugby'],
#  '2369840118_a1c4240ab7': ['young',
#   'boy',
#   'dressed',
#   'in',
#   'green',
#   'holds',
#   'baby',
#   'goat',
#   'in',
#   'arms'],
#  '2319808437_bbbdc317c0': ['two',
#   'boys',
#   'watch',
#   'third',
#   'boy',
#   'kicking',
#   'some',
#   'snow'],
#  '536721406_884ab8fece': ['the',
#   'dog',
#   'barks',
#   'madly',
#   'at',
#   'the',
#   'bull',
#   'in',
#   'the',
#   'pen'],
#  '519059913_4906fe4050': ['young',
#   'boy',
#   'jumping',
#   'upsidedown',
#   'into',
#   'pool'],
#  '2258662398_2797d0eca8': ['young', 'surfer', 'rides', 'wave'],
#  '2647229826_e0e0c65ef1': ['six', 'children', 'near', 'water', 'fountain'],
#  '965444691_fe7e85bf0e': ['the',
#   'man',
#   'is',
#   'holding',
#   'baby',
#   'near',
#   'carnival',
#   'game'],
#  '2893374123_087f98d58a': ['motorcyclist',
#   'rides',
#   'down',
#   'ramp',
#   'held',
#   'up',
#   'by',
#   'colorful',
#   'barrels'],
#  '823697339_aadbeef495': ['two',
#   'women',
#   'one',
#   'with',
#   'red',
#   'hair',
#   'stand',
#   'outside',
#   'store'],
#  '263850317_5bb3a18a08': ['girl',
#   'wearing',
#   'mini',
#   'dress',
#   'and',
#   'long',
#   'sleve',
#   'white',
#   'jacket',
#   'with',
#   'pink',
#   'bag',
#   'walking',
#   'through',
#   'crowded',
#   'area'],
#  '3439331800_e71e1d808f': ['four', 'young', 'men', 'dance', 'onstage'],
#  '3326588088_172d1b2584': ['two',
#   'men',
#   'wearing',
#   'white',
#   'suits',
#   'play',
#   'guitar',
#   'onstage'],
#  '2461631708_decc5b8c87': ['young',
#   'boys',
#   'in',
#   'orange',
#   'life',
#   'vests',
#   'sit',
#   'on',
#   'raft'],
#  '1174525839_7c1e6cfa86': ['the',
#   'girls',
#   'is',
#   'jumping',
#   'into',
#   'the',
#   'air',
#   'on',
#   'the',
#   'beach'],
#  '3239021459_a6b71bb400': ['the',
#   'young',
#   'man',
#   'is',
#   'flying',
#   'through',
#   'the',
#   'air',
#   'on',
#   'his',
#   'green',
#   'snowboard'],
#  '3168841415_c0705a327a': ['the',
#   'little',
#   'kid',
#   'runs',
#   'to',
#   'grab',
#   'the',
#   'blue',
#   'frisbee',
#   'that',
#   'is',
#   'flying',
#   'through',
#   'the',
#   'air'],
#  '419116771_642800891d': ['three',
#   'dogs',
#   'look',
#   'on',
#   'as',
#   'two',
#   'dogs',
#   'attack',
#   'third',
#   'dog',
#   'in',
#   'the',
#   'streets'],
#  '746787916_ceb103069f': ['small',
#   'show',
#   'dog',
#   'just',
#   'ran',
#   'through',
#   'an',
#   'orange',
#   'flexible',
#   'tube'],
#  '1975171469_84e425f61b': ['young', 'child', 'plays', 'an', 'arcade', 'game'],
#  '2701603045_6cbdc4ce7c': ['the',
#   'boy',
#   'is',
#   'wading',
#   'through',
#   'the',
#   'blue',
#   'ocean'],
#  '3217187564_0ffd89dec1': ['three',
#   'race',
#   'dogs',
#   'run',
#   'to',
#   'finish',
#   'race'],
#  '3718007650_e5930b4509': ['the',
#   'back',
#   'of',
#   'woman',
#   'in',
#   'costume',
#   'little',
#   'girl',
#   'looks',
#   'at',
#   'her'],
#  '1332823164_c70a5d930e': ['woman',
#   'standing',
#   'on',
#   'the',
#   'shore',
#   'of',
#   'beach'],
#  '2380740486_8cd5d4601a': ['girl',
#   'with',
#   'two',
#   'ducks',
#   'on',
#   'cliff',
#   'overlooking',
#   'the',
#   'water'],
#  '2193980605_4221c6474d': ['six', 'people', 'jump', 'for', 'ball'],
#  '2321466753_5606a10721': ['young',
#   'child',
#   'is',
#   'holding',
#   'onto',
#   'the',
#   'back',
#   'of',
#   'wicker',
#   'chair'],
#  '3225226381_9fe306fb9e': ['two',
#   'dogs',
#   'running',
#   'one',
#   'brown',
#   'and',
#   'one',
#   'grey'],
#  '3613424631_3ae537624f': ['man',
#   'with',
#   'bike',
#   'sitting',
#   'next',
#   'to',
#   'rubble'],
#  '2992808092_5f677085b7': ['two',
#   'teenagers',
#   'participate',
#   'in',
#   'game',
#   'of',
#   'field',
#   'hockey'],
#  '1819261140_6c022f4b1d': ['person',
#   'at',
#   'table',
#   'dressed',
#   'in',
#   'black',
#   'costume'],
#  '3383037991_8f07784b81': ['the',
#   'large',
#   'brown',
#   'dog',
#   'sat',
#   'on',
#   'the',
#   'bed',
#   'surronded',
#   'by',
#   'wrapping',
#   'paper'],
#  '288025239_5e59ba9c3b': ['the',
#   'hiker',
#   'pokes',
#   'out',
#   'of',
#   'her',
#   'tent',
#   'to',
#   'find',
#   'that',
#   'snow',
#   'is',
#   'everywhere'],
#  '3518755601_cebf11e515': ['three',
#   'young',
#   'women',
#   'wearing',
#   'wetsuits',
#   'on',
#   'beach',
#   'two',
#   'gesturing',
#   'at',
#   'camera'],
#  '3409947123_a8d07edecf': ['the',
#   'people',
#   'are',
#   'standing',
#   'around',
#   'at',
#   'carnival'],
#  '2572101672_4d699c8713': ['the',
#   'man',
#   'is',
#   'standing',
#   'next',
#   'to',
#   'bird',
#   'cage'],
#  '3105315670_5f86f73753': ['the',
#   'woman',
#   'is',
#   'wearing',
#   'brown',
#   'hat',
#   'and',
#   'black',
#   'coat',
#   'and',
#   'is',
#   'on',
#   'sidewalk'],
#  '479807465_cf42f39d00': ['young',
#   'dirt',
#   'bikers',
#   'try',
#   'to',
#   'get',
#   'dirt',
#   'bike',
#   'up',
#   'sandy',
#   'hill'],
#  '3561433412_3985208d53': ['wolflike',
#   'dog',
#   'chasing',
#   'white',
#   'wiffle',
#   'ball',
#   'through',
#   'green',
#   'field'],
#  '2449289139_08fc1092c1': ['the', 'dog', 'runs', 'in', 'the', 'park'],
#  '3295671644_0e10891b6d': ['the',
#   'little',
#   'dog',
#   'with',
#   'big',
#   'ears',
#   'is',
#   'in',
#   'the',
#   'field'],
#  '124195430_d14028660f': ['thin',
#   'brown',
#   'horse',
#   'standing',
#   'and',
#   'small',
#   'black',
#   'horse',
#   'sitting',
#   'on',
#   'sand'],
#  '2258951972_92763fddab': ['two',
#   'large',
#   'gray',
#   'dogs',
#   'running',
#   'through',
#   'grassy',
#   'field'],
#  '2500567791_101d5ddee3': ['dog',
#   'chasing',
#   'brown',
#   'cow',
#   'and',
#   'black',
#   'cow'],
#  '3203908917_53e53c03d1': ['the',
#   'man',
#   'is',
#   'wearing',
#   'red',
#   'shirt',
#   'and',
#   'red',
#   'flannel',
#   'handkerchief',
#   'while',
#   'watching',
#   'flag',
#   'burn'],
#  '2229509318_be3fef006b': ['woman',
#   'is',
#   'standing',
#   'in',
#   'front',
#   'of',
#   'dog',
#   'that',
#   'standing',
#   'on',
#   'its',
#   'hind',
#   'legs'],
#  '252578659_9e404b6430': ['three',
#   'sheep',
#   'graze',
#   'on',
#   'the',
#   'grassy',
#   'field',
#   'with',
#   'dog',
#   'walking',
#   'behind',
#   'them'],
#  '2832978253_8fcc72da3b': ['person',
#   'wearing',
#   'red',
#   'and',
#   'white',
#   'climbs',
#   'foggy',
#   'mountain'],
#  '1082252566_8c79beef93': ['three', 'dogs', 'of', 'various', 'sizes'],
#  '3148647065_2d6cd88cf6': ['pale',
#   'brown',
#   'dog',
#   'runs',
#   'in',
#   'blurred',
#   'rural',
#   'scene'],
#  '3710674892_857b8056f7': ['child',
#   'with',
#   'green',
#   'apple',
#   'in',
#   'his',
#   'mouth',
#   'is',
#   'wearing',
#   'red',
#   'life',
#   'jacket'],
#  '3561537309_e271d57492': ['the',
#   'young',
#   'boy',
#   'opens',
#   'his',
#   'arms',
#   'as',
#   'waves',
#   'come',
#   'crashing',
#   'near',
#   'him'],
#  '2991771557_d98fa0a69f': ['snowboarder',
#   'wearing',
#   'green',
#   'hat',
#   'is',
#   'riding',
#   'along',
#   'metal',
#   'railing'],
#  '3454355269_6185e29f95': ['man',
#   'in',
#   'safety',
#   'gear',
#   'riding',
#   'bike',
#   'on',
#   'rocky',
#   'trail'],
#  '2423085253_6c19149855': ['the',
#   'girl',
#   'is',
#   'running',
#   'on',
#   'the',
#   'grass',
#   'next',
#   'to',
#   'colorful',
#   'toy'],
#  '3483140026_e14f64fdf5': ['smiling',
#   'construction',
#   'worker',
#   'with',
#   'white',
#   'helmet'],
#  '387830531_e89c192b92': ['two', 'dogs', 'playing', 'with', 'each', 'other'],
#  '3533451027_b078e4631b': ['the',
#   'man',
#   'in',
#   'the',
#   'black',
#   'and',
#   'white',
#   'shirt',
#   'is',
#   'running',
#   'with',
#   'ball'],
#  '3726168984_1fa2c8965b': ['two', 'dogs', 'play', 'with', 'bottle'],
#  '2693425189_47740c22ed': ['little',
#   'boy',
#   'wearing',
#   'blue',
#   'shorts',
#   'is',
#   'holding',
#   'yellow',
#   'noodle',
#   'over',
#   'pool'],
#  '1019604187_d087bf9a5f': ['white',
#   'dog',
#   'running',
#   'after',
#   'yellow',
#   'ball'],
#  '510531976_90bbee22a2': ['the',
#   'break',
#   'dancer',
#   'is',
#   'wearing',
#   'white',
#   'shirt',
#   'and',
#   'grey',
#   'pants'],
#  '3404870997_7b0cd755de': ['people',
#   'are',
#   'watching',
#   'boy',
#   'on',
#   'skateboard',
#   'at',
#   'the',
#   'top',
#   'of',
#   'skate',
#   'ramp'],
#  '2918653119_f535fc25c4': ['rollerblader',
#   'in',
#   'green',
#   'shirt',
#   'and',
#   'hat',
#   'slides',
#   'down',
#   'green',
#   'handrail',
#   'next',
#   'to',
#   'steps'],
#  '2521770311_3086ca90de': ['young',
#   'boy',
#   'with',
#   'samll',
#   'cardboard',
#   'box',
#   'atop',
#   'his',
#   'head'],
#  '525538142_7348f0bce7': ['two',
#   'young',
#   'boys',
#   'are',
#   'wrestling',
#   'in',
#   'sand',
#   'pit'],
#  '310260324_7f941814bc': ['several',
#   'men',
#   'in',
#   'front',
#   'of',
#   'white',
#   'building'],
#  '3682428916_69ce66d375': ['small',
#   'plane',
#   'with',
#   'spinning',
#   'propeller',
#   'on',
#   'ground',
#   'pilot',
#   'seen',
#   'through',
#   'windows'],
#  '3564312955_716e86c48b': ['little',
#   'girl',
#   'in',
#   'swimsuit',
#   'lies',
#   'on',
#   'stomach',
#   'in',
#   'water',
#   'smiles',
#   'at',
#   'camera'],
#  '3622929632_26fb800000': ['the', 'dog', 'has', 'ball', 'in', 'its', 'mouth'],
#  '2801851082_8c3c480c0f': ['young',
#   'blond',
#   'boy',
#   'with',
#   'long',
#   'hair',
#   'with',
#   'large',
#   'innertube',
#   'drapped',
#   'around',
#   'his',
#   'body'],
#  '3442138291_3e75f4bdb8': ['the',
#   'young',
#   'child',
#   'in',
#   'the',
#   'black',
#   'shirt',
#   'and',
#   'jeans',
#   'ran',
#   'down',
#   'the',
#   'path'],
#  '3052196390_c59dd24ca8': ['several',
#   'girls',
#   'in',
#   'swimsuits',
#   'are',
#   'playing',
#   'in',
#   'sprinkler',
#   'fountain'],
#  '571130875_30051ac02d': ['six',
#   'women',
#   'wearing',
#   'matchin',
#   'pink',
#   'dresses',
#   'in',
#   'front',
#   'of',
#   'crowd'],
#  '2518853257_02f30e282e': ['two',
#   'women',
#   'on',
#   'green',
#   'chairs',
#   'are',
#   'looking',
#   'at',
#   'book'],
#  '3272002857_ace031f564': ['person', 'on', 'horse', 'on', 'the', 'beach'],
#  '3560977956_e08d2cd531': ['two',
#   'people',
#   'wear',
#   'life',
#   'jackets',
#   'in',
#   'rowboat'],
#  '2439384468_58934deab6': ['two',
#   'large',
#   'black',
#   'dogs',
#   'one',
#   'with',
#   'ball',
#   'in',
#   'its',
#   'mouth',
#   'are',
#   'running',
#   'through',
#   'tall',
#   'grass'],
#  '468608014_09fd20eb9b': ['two',
#   'dogs',
#   'fighting',
#   'for',
#   'the',
#   'same',
#   'chew',
#   'toy'],
#  '2337377811_8c81b40a64': ['little',
#   'girl',
#   'in',
#   'blue',
#   'coat',
#   'and',
#   'pink',
#   'hat',
#   'makes',
#   'tracks',
#   'in',
#   'the',
#   'snow'],
#  '2827964381_408a310809': ['two',
#   'dogs',
#   'wrestle',
#   'in',
#   'the',
#   'grass',
#   'with',
#   'chain',
#   'link',
#   'fence',
#   'in',
#   'the',
#   'background'],
#  '72218201_e0e9c7d65b': ['the',
#   'young',
#   'runners',
#   'are',
#   'racing',
#   'through',
#   'the',
#   'snow'],
#  '3564907603_14ccc655f1': ['yound',
#   'people',
#   'make',
#   'goofy',
#   'faces',
#   'for',
#   'the',
#   'camera'],
#  '2423550887_ffc9bbcf71': ['man',
#   'in',
#   'red',
#   'jacket',
#   'standing',
#   'in',
#   'front',
#   'of',
#   'lighthouse'],
#  '3229282764_a4a515f4e2': ['man',
#   'and',
#   'child',
#   'playing',
#   'on',
#   'the',
#   'beach'],
#  '247704641_d883902277': ['the',
#   'dog',
#   'walks',
#   'across',
#   'the',
#   'stream',
#   'on',
#   'fallen',
#   'log'],
#  '3549464203_8ab9c6160b': ['the',
#   'girl',
#   'is',
#   'at',
#   'the',
#   'park',
#   'playing',
#   'on',
#   'the',
#   'jungle',
#   'gym'],
#  '3606093421_eddd46c2c7': ['two',
#   'men',
#   'ride',
#   'an',
#   'orange',
#   'raft',
#   'to',
#   'shore'],
#  '3356369156_074750c6cc': ['the',
#   'solitude',
#   'boat',
#   'floats',
#   'on',
#   'the',
#   'lake'],
#  '2268109835_d6edbe1c2b': ['person',
#   'uses',
#   'longhandled',
#   'net',
#   'to',
#   'catch',
#   'something',
#   'in',
#   'the',
#   'air'],
#  '2172493537_128bc8b187': ['three',
#   'people',
#   'are',
#   'wading',
#   'in',
#   'shallow',
#   'water',
#   'near',
#   'stone',
#   'path',
#   'and',
#   'spraying',
#   'fountains'],
#  '2655196158_5c878a4af0': ['the',
#   'gray',
#   'blue',
#   'eyed',
#   'hound',
#   'puppy',
#   'is',
#   'laying',
#   'on',
#   'blue',
#   'carpet',
#   'chewing',
#   'on',
#   'toy'],
#  '2623496164_68ffeb5067': ['the',
#   'person',
#   'on',
#   'the',
#   'bicycle',
#   'is',
#   'wearing',
#   'red'],
#  '2269795781_46a296aa21': ['miami',
#   'tennis',
#   'player',
#   'hits',
#   'the',
#   'ball',
#   'with',
#   'forehand'],
#  '275401000_8829250eb3': ['two',
#   'fluffy',
#   'dogs',
#   'jumping',
#   'to',
#   'catch',
#   'tennis',
#   'ball'],
#  '3108378861_d2214d971e': ['woman',
#   'standing',
#   'next',
#   'to',
#   'man',
#   'who',
#   'is',
#   'sitting',
#   'on',
#   'rock'],
#  '1160441615_fe6b3c5277': ['three',
#   'women',
#   'walk',
#   'through',
#   'plant',
#   'covered',
#   'atrium',
#   'hallway'],
#  '1689658980_0074d81d28': ['two',
#   'dogs',
#   'run',
#   'out',
#   'of',
#   'the',
#   'ocean',
#   'lake'],
#  '2966552760_e65b22cd26': ['little',
#   'girl',
#   'sitting',
#   'down',
#   'eating',
#   'ice',
#   'cream'],
#  '3304556387_203b9d4db0': ['the',
#   'man',
#   'is',
#   'playing',
#   'in',
#   'the',
#   'yard',
#   'with',
#   'two',
#   'dogs'],
#  '3150380412_7021e5444a': ['wet',
#   'blonde',
#   'dog',
#   'running',
#   'through',
#   'water'],
#  '2788945468_74a9618cfa': ['pictures',
#   'on',
#   'white',
#   'brick',
#   'wall',
#   'with',
#   'smiling',
#   'man',
#   'standing',
#   'in',
#   'front',
#   'of',
#   'the',
#   'wall'],
#  '1659358133_95cd1027bd': ['the',
#   'dog',
#   'is',
#   'standing',
#   'outside',
#   'on',
#   'tree',
#   'stump'],
#  '3619630328_2d0865b6f4': ['large',
#   'brown',
#   'dog',
#   'jumps',
#   'over',
#   'red',
#   'hurdle'],
#  '3156406419_38fbd52007': ['skier',
#   'is',
#   'falling',
#   'down',
#   'snowy',
#   'mountain'],
#  '2896483502_6f807bae9e': ['the',
#   'dog',
#   'jumps',
#   'to',
#   'catch',
#   'flying',
#   'disc'],
#  '3537520829_aab733e16c': ['skateboarder', 'riding', 'rail'],
#  '246231741_882b45c4e1': ['two',
#   'german',
#   'sheppard',
#   'dogs',
#   'are',
#   'fighting'],
#  '2473738924_eca928d12f': ['two',
#   'young',
#   'girls',
#   'sparring',
#   'in',
#   'white',
#   'martial',
#   'arts',
#   'outfits',
#   'while',
#   'third',
#   'person',
#   'watches',
#   'from',
#   'the',
#   'side'],
#  '3185645793_49de805194': ['one',
#   'person',
#   'jumping',
#   'his',
#   'bike',
#   'towards',
#   'the',
#   'camera',
#   'while',
#   'another',
#   'one',
#   'in',
#   'the',
#   'background',
#   'is',
#   'walking',
#   'his',
#   'bike',
#   'away',
#   'from',
#   'the',
#   'camera'],
#  '2714699748_c9270dd5aa': ['two', 'dogs', 'wrestle'],
#  '3183060123_ea3af6278b': ['the',
#   'helmeted',
#   'man',
#   'rides',
#   'green',
#   'kawasaki'],
#  '3410902181_b2a3c6eec9': ['girl',
#   'is',
#   'performing',
#   'onstage',
#   'with',
#   'hula',
#   'hoop',
#   'surrounded',
#   'by',
#   'many',
#   'balloons'],
#  '2662816021_ac474e0fde': ['the',
#   'white',
#   'dog',
#   'is',
#   'standing',
#   'in',
#   'the',
#   'water',
#   'with',
#   'stick',
#   'in',
#   'its',
#   'mouth'],
#  '765298136_7805fbb079': ['the',
#   'man',
#   'in',
#   'red',
#   'is',
#   'propelling',
#   'down',
#   'the',
#   'waterfall'],
#  '3154813159_58a195236d': ['the',
#   'brown',
#   'and',
#   'white',
#   'dog',
#   'is',
#   'standing',
#   'up',
#   'on',
#   'its',
#   'hind',
#   'legs'],
#  '2216695423_1362cb25f3': ['the',
#   'dogs',
#   'are',
#   'playing',
#   'with',
#   'stick',
#   'outside'],
#  '2374570771_c395fc224a': ['dog', 'runs', 'through', 'the', 'water'],
#  '3552796830_2dd2aa9c2c': ['two',
#   'soldiers',
#   'are',
#   'running',
#   'down',
#   'track'],
#  '1287073593_f3d2a62455': ['the',
#   'man',
#   'is',
#   'mushing',
#   'his',
#   'dogs',
#   'on',
#   'snow',
#   'trail'],
#  '496971341_22782195f0': ['two',
#   'dogs',
#   'playing',
#   'with',
#   'blue',
#   'and',
#   'green',
#   'ball'],
#  '2875528143_94d9480fdd': ['the',
#   'girl',
#   'in',
#   'pink',
#   'does',
#   'midair',
#   'leg',
#   'splits'],
#  '2426781076_e3f4d2685c': ['the',
#   'boy',
#   'is',
#   'coming',
#   'down',
#   'the',
#   'amusement',
#   'slide',
#   'on',
#   'his',
#   'knees'],
#  '3394654132_9a8659605c': ['woman', 'holding', 'dog', 'on', 'street'],
#  '3102363657_dc95fe6850': ['small',
#   'boy',
#   'hugged',
#   'by',
#   'person',
#   'in',
#   'bee',
#   'costume',
#   'blurry',
#   'urban',
#   'background'],
#  '373394550_1b2296b8c4': ['small',
#   'boy',
#   'sleeping',
#   'on',
#   'seats',
#   'and',
#   'sucking',
#   'his',
#   'thumb'],
#  '3595408539_a7d8aabc24': ['three',
#   'young',
#   'people',
#   'drink',
#   'beer',
#   'at',
#   'an',
#   'outdoor',
#   'party'],
#  '3134387321_3a253224c1': ['two',
#   'women',
#   'and',
#   'man',
#   'pose',
#   'for',
#   'the',
#   'camera'],
#  '241347760_d44c8d3a01': ['the',
#   'american',
#   'footballer',
#   'is',
#   'wearing',
#   'red',
#   'and',
#   'white',
#   'strip'],
#  '3517040752_debec03376': ['two', 'girls', 'are', 'playing', 'softball'],
#  '2892995070_39f3c9a56e': ['two', 'dogs', 'are', 'playing', 'together'],
#  '3546027589_253553252a': ['the',
#   'children',
#   'are',
#   'talking',
#   'and',
#   'playing',
#   'in',
#   'the',
#   'street'],
#  '3569284680_44fef444ef': ['two',
#   'young',
#   'kids',
#   'walk',
#   'up',
#   'some',
#   'stairs'],
#  '2788652511_4f10060e07': ['the',
#   'child',
#   'is',
#   'on',
#   'boogie',
#   'board',
#   'with',
#   'waves',
#   'splashing',
#   'around'],
#  '3452411712_5b42d2a1b5': ['the',
#   'boy',
#   'is',
#   'pushing',
#   'girl',
#   'on',
#   'swing',
#   'outside'],
#  '3198237818_cb5eb302f0': ['muscular',
#   'man',
#   'in',
#   'speedo',
#   'and',
#   'curvy',
#   'blond',
#   'in',
#   'bikini',
#   'walk',
#   'together',
#   'at',
#   'the',
#   'beach'],
#  '2865703567_52de2444f2': ['young',
#   'man',
#   'jumps',
#   'from',
#   'one',
#   'balcony',
#   'to',
#   'another'],
#  '2451285022_59255e7fd9': ['the',
#   'man',
#   'wearing',
#   'tan',
#   'hat',
#   'and',
#   'white',
#   'shirt',
#   'holds',
#   'his',
#   'brown',
#   'dog',
#   'which',
#   'is',
#   'wearing',
#   'an',
#   'orange',
#   'collar'],
#  '3450874870_c4dcf58fb3': ['two',
#   'people',
#   'wearing',
#   'skis',
#   'on',
#   'chairlift'],
#  '3490736665_38710f4b91': ['dog',
#   'stands',
#   'on',
#   'his',
#   'hind',
#   'legs',
#   'amid',
#   'shower',
#   'of',
#   'tennis',
#   'balls'],
#  '2496236371_61dec88113': ['the',
#   'red',
#   'motorcycle',
#   'pulls',
#   'wheelie',
#   'on',
#   'the',
#   'racetrack'],
#  '2493974889_50ae29f1e1': ['two',
#   'kids',
#   'are',
#   'walking',
#   'on',
#   'path',
#   'in',
#   'the',
#   'woods'],
#  '2819254573_9ecb5f4d5e': ['the',
#   'blonde',
#   'boy',
#   'is',
#   'riding',
#   'rollercoaster',
#   'with',
#   'his',
#   'mouth',
#   'wide',
#   'open'],
#  '3649387275_75295baa28': ['the',
#   'white',
#   'dog',
#   'with',
#   'brown',
#   'spots',
#   'is',
#   'walking',
#   'through',
#   'shallow',
#   'water'],
#  '3545427060_c16a8b7dfd': ['three',
#   'indian',
#   'children',
#   'playing',
#   'in',
#   'water'],
#  '3706356018_28f62290e8': ['little',
#   'kids',
#   'are',
#   'on',
#   'an',
#   'amusement',
#   'park',
#   'ride'],
#  '2060031241_a3ae7a06bb': ['baby',
#   'sitting',
#   'on',
#   'floor',
#   'and',
#   'holding',
#   'game',
#   'controller',
#   'over',
#   'its',
#   'head'],
#  '2710416789_555180e399': ['there',
#   'is',
#   'child',
#   'with',
#   'glasses',
#   'and',
#   'tan',
#   'skin',
#   'staring',
#   'at',
#   'the',
#   'camera'],
#  '2275029674_6d4891c20e': ['two', 'white', 'puppies', 'play', 'near', 'pool'],
#  '225909073_25c3c33a29': ['the',
#   'german',
#   'shepherd',
#   'is',
#   'walking',
#   'in',
#   'the',
#   'body',
#   'of',
#   'water'],
#  '3424927725_c4d1fcfac3': ['person',
#   'sitting',
#   'on',
#   'the',
#   'edge',
#   'of',
#   'rock',
#   'outcropping',
#   'looking',
#   'down'],
#  '3648081498_76ec091495': ['the',
#   'skateboarder',
#   'rides',
#   'the',
#   'pipe',
#   'wall',
#   'at',
#   'skater',
#   'park'],
#  '2839807428_efe42423f2': ['dog',
#   'jumping',
#   'high',
#   'in',
#   'the',
#   'air',
#   'to',
#   'catch',
#   'frisbee'],
#  '2324917982_f3db8c11e9': ['toddler',
#   'on',
#   'hardwood',
#   'floor',
#   'playing',
#   'with',
#   'toys'],
#  '241031670_e60f59b8e4': ['three',
#   'girls',
#   'take',
#   'cover',
#   'under',
#   'their',
#   'umbrellas'],
#  '3689355450_fd559b816d': ['the',
#   'person',
#   'wearing',
#   'flannel',
#   'shorts',
#   'is',
#   'jumping',
#   'over',
#   'fountain'],
#  '2495394666_2ef6c37519': ['the',
#   'brown',
#   'dog',
#   'is',
#   'swimming',
#   'in',
#   'the',
#   'water'],
#  '2561849813_ff9caa52ac': ['the',
#   'baby',
#   'sits',
#   'on',
#   'the',
#   'sandy',
#   'beach'],
#  '1784309115_0ad6791146': ['woman',
#   'in',
#   'pink',
#   'bikini',
#   'next',
#   'to',
#   'man',
#   'in',
#   'brown'],
#  '406901451_7eafd7568a': ['tan',
#   'and',
#   'black',
#   'dog',
#   'opens',
#   'its',
#   'mouth',
#   'for',
#   'red',
#   'ball'],
#  '1211015912_9f3ee3a995': ['children', 'at', 'park'],
#  '3256456935_664a7a5bba': ['the',
#   'girl',
#   'with',
#   'the',
#   'red',
#   'belt',
#   'is',
#   'kicking',
#   'pad',
#   'that',
#   'the',
#   'person',
#   'in',
#   'black',
#   'is',
#   'holding'],
#  '3659686168_49c3abcee1': ['two', 'young', 'women', 'sit', 'by', 'fountain'],
#  '2187503678_fd743e0a00': ['white',
#   'dog',
#   'running',
#   'away',
#   'from',
#   'the',
#   'orange',
#   'colored',
#   'house'],
#  '2915538325_59e11276dd': ['the',
#   'crowd',
#   'is',
#   'watching',
#   'the',
#   'fiery',
#   'explosion'],
#  '2148991939_3b9fd6c439': ['the',
#   'black',
#   'dog',
#   'leaps',
#   'off',
#   'the',
#   'dock',
#   'and',
#   'into',
#   'the',
#   'water'],
#  '1253264731_e7c689eca5': ['two',
#   'girls',
#   'one',
#   'in',
#   'overalls',
#   'holding',
#   'on',
#   'to',
#   'fence',
#   'with',
#   'water',
#   'behind',
#   'them'],
#  '2971298546_dd595cf297': ['runner',
#   'is',
#   'running',
#   'past',
#   'an',
#   'outdoor',
#   'flower',
#   'stall'],
#  '2242178517_2325b85e5f': ['young', 'child', 'shovels', 'snow'],
#  '3497238310_2abde3965d': ['some', 'young', 'men', 'playing', 'basketball'],
#  '3119887967_271a097464': ['the',
#   'man',
#   'in',
#   'the',
#   'black',
#   'hat',
#   'stands',
#   'behind',
#   'the',
#   'man',
#   'who',
#   'is',
#   'pointing',
#   'his',
#   'finger']}

# %%
data = dict()
data = {key1:'a', key2:'b', key1:'c'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-bd9bcc41121f> in <module>()
#       1 data = dict()
# ----> 2 data = {key1:'a', key2:'b', key1:'c'}
#
# NameError: name 'key1' is not defined

# %%
del image_identifiers

# %%
# descriptions = dict()
image_identifiers = []
for line in doc.split('\n'):
    tokens = line.split()
    image_id,_ = tokens[0], tokens[1:]
    image_identifiers.append(image_id)

# %%
len(image_identifiers)
# Out:
# 40460

# %%
temp = image_identifiers
image_ids_list = np.unique(np.asarray(image_identifiers))

# %%
del temp,image_identifiers
image_identifiers = image_ids_list
del image_ids_list

# %%
image_identifiers.shape
# Out:
# (8092,)

# %%
doc = doc[:1000000-17]
doc
# Out:
# '3242718240_3358f2d6e6 group of children dressed in costume pose for picture\n3242718240_3358f2d6e6 group of children stand against building and smile\n3242718240_3358f2d6e6 group of six children stands smiling and laughing in front of wall\n3242718240_3358f2d6e6 group of young children standing in row leaning against wall\n3242718240_3358f2d6e6 the six children are laughing\n1355450069_c0675b0706 man is climbing up wall\n1355450069_c0675b0706 man wearing no shirt climbs the side of large rock\n1355450069_c0675b0706 shirtless man climbing up the rock wall with rope safety lines\n1355450069_c0675b0706 man without shirt is climbing rock\n1355450069_c0675b0706 there is rock climber holding on and climbing to the top of very large rock\n724702877_f2a938766b dog has jumped in the air to catch tennis ball\n724702877_f2a938766b small brown dog jumping up to catch tennis ball\n724702877_f2a938766b small brown dog jumps and catches tennis ball\n724702877_f2a938766b small dog jumping with ball in its mouth\n724702877_f2a938766b small dog catches tennis ball in its mouth indoors\n3067500667_0fce8f28d4 cricket batsman has been bowled out middle stump\n3067500667_0fce8f28d4 cricket player swings his bat but misses\n3067500667_0fce8f28d4 man is standing in front of some red sticks trying to hit ball\n3067500667_0fce8f28d4 man is swinging paddle at unique ball game\n3067500667_0fce8f28d4 player hits the ball at cricket game\n1452361926_6d8c535e32 boy sits in toy car while drinking from his sippy cup\n1452361926_6d8c535e32 toddler drinking from cup in toy car\n1452361926_6d8c535e32 toddler in red toy car drinks from juice cup\n1452361926_6d8c535e32 the boy sits in his toy car sipping from cup\n1452361926_6d8c535e32 the child sits in toy car and drinks from sippy cup\n1525153022_06c48dbe52 black dog is running through the shallow edge of large body of water\n1525153022_06c48dbe52 black dog is running through the water\n1525153022_06c48dbe52 black dog jumps high out of the water\n1525153022_06c48dbe52 black and tan dobbermen running through the ocean\n1525153022_06c48dbe52 the dog runs through the water\n282960970_574aa1ba49 person wearing jeans sits on top of horse saddle\n282960970_574aa1ba49 woman in jeans is sitting on the saddle of horse\n282960970_574aa1ba49 the girl is sitting on top of saddle\n282960970_574aa1ba49 the person is sitting on top of horse\n282960970_574aa1ba49 this person is sitting in saddle\n119534510_d52b3781a3 man in brown shirt sitting on dock and reading\n119534510_d52b3781a3 man is sitting next to the water reading\n119534510_d52b3781a3 man reading book on the dock near post\n119534510_d52b3781a3 person in brown jacket is sitting on pier by the water reading\n119534510_d52b3781a3 person sitting on concrete landing next to body of water\n241347460_81d5d62bf6 football player kicks the ball\n241347460_81d5d62bf6 an oklahoma football player attempts to kick the ball\n241347460_81d5d62bf6 player for the oklahoma sooners football team punts the ball during game\n241347460_81d5d62bf6 oklahoma university kicker kicking the football\n241347460_81d5d62bf6 the football player in red kicks off the ball\n3540416981_4e74f08cbb dog chases stuffed animal attached to string\n3540416981_4e74f08cbb white and black dog chases after decoyanimal on string\n3540416981_4e74f08cbb white dog is chasing stuffed animal being pulled on string\n3540416981_4e74f08cbb the white dog is chasing toy that is attached to string across the grass\n3540416981_4e74f08cbb the white dog is running in the green grass\n2333816000_7105d0ffac man climbing rock face\n2333816000_7105d0ffac man climbs up rock\n2333816000_7105d0ffac man wearing blue helmet is rock climbing\n2333816000_7105d0ffac rock climber scaling stone wall\n2333816000_7105d0ffac the man climbing the rock is wearing blue helmet\n2533642917_a5eace85e6 boy in bathing suit stands in water\n2533642917_a5eace85e6 little boy stands in creek on sunny day\n2533642917_a5eace85e6 toddler wearing colorful sh ...

# %%
descriptions = dict()
for line in doc.split('\n'):
#     print(line)
    tokens = line.split()
#     print(tokens)
#     break
    image_id, image_description = tokens[0],tokens[1:]
    for image_id in image_identifiers:
        if image_id not in descriptions:
            descriptions[image_id] = list()
        # break sentences by the dot and add ssss and eeee and join them
        desc = 'ssss ' + ' '.join(image_description) + ' eeee'
        descriptions[image_id].append(desc)

# %%
descriptions = dict()
for line in doc.split('\n'):
#     print(line)
    tokens = line.split()
#     print(tokens)
#     break
    image_id, image_description = tokens[0],tokens[1:]
    for image_id in images_list:
        if image_id not in descriptions:
            descriptions[image_id] = list()
        # break sentences by the dot and add ssss and eeee and join them
        desc = 'ssss ' + ' '.join(image_description) + ' eeee'
        descriptions[image_id].append(desc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-989accd55b96> in <module>()
#       5 #     print(tokens)
#       6 #     break
# ----> 7     image_id, image_description = tokens[0],tokens[1:]
#       8     for image_id in images_list:
#       9         if image_id not in descriptions:
#
# IndexError: list index out of range

# %%
del descriptions

# %%
len(descriptions['2']), descriptions['2']
# Out:
# (1048929,
#  ['ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
#   'ssss group of children dressed in costume pose for picture eeee',
# ...
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   'ssss group of children stand against building and smile eeee',
#   ...])

# %%
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))

# %%
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
 
# define the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
epochs = 20
steps = len(train_descriptions)
for i in range(epochs):
	# create the data generator
	generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
	# fit for one epoch
	model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
	# save model
	model.save('model_' + str(i) + '.h5')
